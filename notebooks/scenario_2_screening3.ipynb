# %% [markdown]
# # Scenario 2

# %%
import sys, types, time, os, inspect, shutil, pprint, cPickle, gzip, tarfile, pprint, datetime, pdb, copy
import numpy as np
import numpy.random as npr
import pandas as pd
from scipy.interpolate import griddata
from matplotlib import rc, font_manager
import matplotlib.pyplot as plt
from IPython.core.display import Image
# wspec moduls:
import core, storage, analytical
import visualization as viz
import utilities as utils
for mod in [core,storage,analytical,utils,viz]:     # reload the wspec modules in case the code has changed
    reload(mod)
    
#np.set_printoptions(precision=4, suppress=True, linewidth=100)
np.set_printoptions(suppress=True, linewidth=100)
npr.seed(230985)

# %% [markdown]
# ## 1. Scenario features
#
# * Two populations linked by migration
#
# * Initial state:
#
#     * Trait T1 adaptive and fixed in population 1, T2 in population 2
#
#     * Preference allele P0 (non-discriminating) fixed in both populations
#
# * Population 1 is uninfected, *Wolbachia* infection in population 2
#
# * Order of events:
#
#     1.  Secondary contact
#         $\rightarrow$  selection-migration equilibrium
#
#     2.  Introduction of a preference for T1 in population 1, P1 (T1), and of a preference for T2 in population 2, P2 (T2)
#         $\rightarrow$  new equilibrium
#
# <img src="https://docs.google.com/drawings/d/1PI65vCcdE8Yv5Sa5cS_NrZ3QZzjU8nMVnLLMJycal04/pub?w=691&h=577">

# %% [markdown]
# ## 2. Configuration
#
# To configure the simulation scenario, we need to specify gene loci, alleles, and parameters.
#
# ### 2.1 Loci and alleles
#
# Populations are treated as loci, as would be the cytotype. In numpy terms, each locus is represented by an array axis.
#
# We keep separate lists rather than a dictionary because we need to preserve the locus and allele orders.

# %%
LOCI = ['population', 'trait', 'preference', 'cytotype']
ALLELES = [['pop1', 'pop2'],
           ['T1', 'T2'],
           ['P0', 'P1', 'P2'],
           ['U', 'W']
          ]
print utils.loci2string(LOCI, ALLELES)
# Out:
# locus           alleles
# --------------------------
# population      pop1, pop2
# trait           T1, T2
# preference      P0, P1, P2
# cytotype        U, W

# %%
def popdiff(metapop):
    """
    Measure frequency differences between populations. This function returns a NxN matrix containing 
    values between 0 and L-1 where N is the number of populations and L is the number of loci.
    """
    n = metapop.n_pops
    d = np.zeros((n,n), float)
    for i in range(n):
        for j in range(i,n):
            for loc in metapop.loci[1:]:
                sums = metapop.get_sums(loc)
                d[i,j] += np.max( np.abs(sums[i] - sums[j]) )
                d[j,i] = d[i,j]
    return d

# %% [markdown]
# ### 2.2 Parameters

# %% [markdown]
# Beware of the `step` parameter as the size of the HDF5 database is strongly affected by its value. If we are not interested in every single dynamical process but rather in the final outcome then might set `step = 1e6` which will only record special states like initial frequencies, equilibria, or when new alleles have been introduced.

# %%
sid = '2screen3'     # scenario id
PARAMETERS = {
    'lCI': (0.9, 'CI level'),                   # level of cytoplasmic incompatibility
    't': (0.9, 'transmission rate'),            # transmission of Wolbachia
    'f': (0.1, 'fecundity reduction'),          # Wolbachia-infected females are less fecund
    'm': (0.01, 'migration rate'),              # symmetric migration
    'intro': (0.001, 'introduction frequency'), # introduction frequency of preference mutant allele
    'eq': (1e-6, 'equilibrium threshold'),      # equilibrium threshold (total frequency change)
    'nmin': (1000, 'min generation'),            # run at least `nmin` generations in search of equilibrium
    'nmax': (300000, 'max generation'),         # max number of generations to iterate for each stage of the simulation
    'step': (10, 'storage stepsize')            # store metapopulation state every `step` generations
}
# For mating preference parameters, we use a different notation:
pr = 0.8
trait_preferences = {                        # female mating preferences (rejection probabilities)
    'P0': {'baseline': 0.},
    'P1': {'baseline': pr, 'T1': 0.},
    'P2': {'baseline': pr, 'T2': 0.}
}
PARAMETERS = utils.add_preferences(PARAMETERS, trait_preferences)
# make parameter names locally available:
config = utils.configure_locals(LOCI, ALLELES, PARAMETERS)
locals().update(config)

print 'Parameters that are the same for all runs in the screening:\n'
print utils.params2string(PARAMETERS)
# Out:
# Parameters that are the same for all runs in the screening:
#
# parameter         value       description
# ----------------------------------------------------
# eq                1e-06       equilibrium threshold
# f                 0.1         fecundity reduction
# intro             0.001       introduction frequency
# lCI               0.9         CI level
# m                 0.01        migration rate
# nmax              300000      max generation
# nmin              1000        min generation
# pr_p0_baseline    0.0         rejection probability
# pr_p1_baseline    0.8         rejection probability
# pr_p1_t1          0.0         rejection probability
# pr_p2_baseline    0.8         rejection probability
# pr_p2_t2          0.0         rejection probability
# step              10          storage stepsize
# t                 0.9         transmission rate

# %% [markdown]
# Critical migration rate for these *Wolbachia* parameters:

# %%
print 'm_crit =', np.min(analytical.mcrit_IMA(f, lCI, s, t), analytical.mcrit_UMA(f, lCI, s, t))
# Out:
# m_crit = 0.0152511358816

# %% [markdown]
# We'll generate random transition and rejection probabilities, run the simulation, and check the outcome via the `popdiff` function the results of which are stored as well.

# %%
n = 4000

screening_dtype = np.dtype([('pt', 'f'), ('s', 'f'), ('diff', 'f')])
rstore = storage.RunStore('/extra/flor/data/notebook_data/scenario_{0}.h5'.format(sid))
# select existing scenario, initialize a new one if this fails:
try:
    scenario = rstore.select_scenario(sid, verbose=False)
    count = scenario['counter'][()]
    maxcount = len(scenario['screening'])
except:
    scenario = rstore.create_scenario(sid, labels=(LOCI,ALLELES))
    # scenario = rstore['current']['scenario']
    scenario.create_dataset('counter', (), 'i')    # integer counter for the screening runs; initialized at 0
    count = 0
    maxcount = max(n, 10)
    scenario.create_dataset('screening', (maxcount,), screening_dtype, maxshape=(None,))
    
if n >= maxcount:
    scenario['screening'].resize((n,))

# %% [markdown]
# The actual screening:

# %%
for i in range(n):
    # we use a U-shaped beta function (low and high values more likely than intermediate ones)
    # to better explore the corners:
    if i <= 2000:
        pt = npr.beta(a=0.7, b=0.7)
        s  = 0.5*npr.beta(a=0.7, b=0.7)
    elif (2000 < i < 2500) or (3500 < i <= 4000):
        s  = 0.5*npr.random()
        pt_min = (s + 4.)/5.
        pt = pt_min + (1.-pt_min)*npr.random()
    elif 2500 <= i <= 3500:
        s  = 0.5*npr.random()
        pt_min = 0.85 - np.sqrt(s/1.6)
        pt = pt_min + np.min(0.2, 1.-pt_min)*npr.random()
        
    PARAMETERS['s'] = (s, 'selection coefficient')        # selection advantage for adaptive trait
    PARAMETERS['pt'] = (pt, 'transition probability')       # probability of transition into another mating round
    
    rid = 'pt{0:.12f}_s{1:.12f}'.format(pt,s)      # generate id of simulation run based on pr and pt values
    
    # make parameter names locally available again:
    config = utils.configure_locals(LOCI, ALLELES, PARAMETERS)
    locals().update(config)

    max_figwidth = 15
    figheight = 5
    w = min( N_POPS*(N_LOCI-1), max_figwidth )    # figure width: npops*(nloci-1) but at most 15
    figsize = [w, figheight]
    show_progressbar = False          # BEWARE: enabling progressbar slows down the simulation significantly!
    
    overwrite_run = False
    data_available = False
    
    # select existing run, initialize a new one if this fails:
    try:   
        rstore.select_run(rid, verbose=False)
        data_available = True
        special_states = list( rstore.get_special_states()[::-1] )
    except:
        rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    # check whether parameters are identical:
    pars = rstore.get_parameters()
    if not utils.parameters_equal(pars, PARAMETERS, verbose=False):
        data_available = False
        if not overwrite_run:
            raise ValueError('parameter values differ from stored values; set `overwrite_run` to `True` in order to overwrite run')
        else:
            # print 'overwriting run...'
            rstore.remove_run(rid, sid)
            rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    
    if data_available:
        pass
    else:
        weights = {
            'migration': None,
            'viability_selection': None,
            'constant_reproduction': None,
            'dynamic_reproduction': []
        }
        mig = np.array(
            [[1-m,      m ],
             [  m,    1-m ]], float)
        M = core.MigrationWeight(
            name='migration',
            axes=['target', 'source'],
            config=config,
            arr=mig,
            m=m
        )
        weights['migration'] = M.extended()
        # print M
        
        vsarr = np.array(
            [[ 1+s,  1  ],
             [   1,  1+s]], float
        )
        VS = core.ViabilityWeight(
            name='viability selection',
            axes=['population','trait'],
            config=config,
            arr=vsarr,
            s=s
        )
        weights['viability_selection'] = VS.extended()
        # print VS
        
        TP = core.GeneralizedPreferenceWeight(
            name='trait preference',
            axes=['population', 'female_preference', 'male_trait'],
            pref_desc = trait_preferences,
            config=config,
            unstack_levels=[2],
            pt=pt
        )
        weights['dynamic_reproduction'].append( (TP, ['trait']) )
        # print TP
        
        CI = core.ReproductionWeight(
            name='cytoplasmic incompatibility',
            axes=['male_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            lCI=lCI
        )
        CI.set( np.array([[1, 1], [1-lCI, 1]], float ) )
        CI_ = CI.extended()
        # print CI
    
        T = core.ReproductionWeight(
            name='cytotype inheritance',
            axes=['female_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            t=t
        )
        T.set( np.array( [[1, 0], [1-t, t]], float ) )
        T_ = T.extended()
        # print T
        
        F = core.ReproductionWeight(
            name='fecundity reduction',
            axes=['female_cytotype'],
            config=config,
            f=f
        )
        F.set( np.array([1, 1-f], float) )
        F_ = F.extended()
        # print F
        
        IP = core.ReproductionWeight(
            name='preference inheritance',
            axes=['female_preference', 'male_preference', 'offspring_preference'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('preference')])
        IP.set( utils.nuclear_inheritance(n_alleles) )
        IP_ = IP.extended()
        # print IP
        
        IT = core.ReproductionWeight(
            name='trait inheritance',
            axes=['female_trait', 'male_trait', 'offspring_trait'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('trait')])
        IT.set( utils.nuclear_inheritance(n_alleles) )
        IT_ = IT.extended()
        # print IT
        
        R_ = CI_ * T_ * F_ * IP_ * IT_
        weights['constant_reproduction'] = R_
        
        # INITIAL STATE:
        starttime = time.time()                  # take time for timing report after simulation run
        startfreqs = np.zeros(FSHAPE)
        startfreqs[0,0,0,0] = 1.                   # pop1-T1-P0-U
        startfreqs[1,1,0,1] = 1.                   # pop2-T2-P0-W
        metapop = core.MetaPopulation(
            startfreqs,
            config=config,
            generation=0,
            name='metapopulation'
        )
        rstore.record_special_state(metapop.generation, 'start')
        rstore.dump_data(metapop)
        
        # MIGRATION-SELECTION EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        # make a copy of the metapopulation for later calculation of frequency differences:
        #initial = copy.copy(metapop)
        # frequency difference score before introduction of preference alleles:
        base_diff = popdiff(metapop)[0,1]
        
        # INTRODUCTION OF PREFERENCE MUTANTS:
        intro_allele = 'P1'
        metapop.introduce_allele('pop1', intro_allele, intro_freq=intro, advance_generation_count=False)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        intro_allele = 'P2'
        metapop.introduce_allele('pop2', intro_allele, intro_freq=intro, advance_generation_count=True)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        # FINAL EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        
        #diff = popdiff2(metapop, initial)[0,1]
        diff = popdiff(metapop)[0,1] - base_diff
        scenario['screening'][i] = (pt, s, diff)
        scenario['counter'][()] += 1
        
        print '\n^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^'
        print 'i = {0}\npt = {1}\ns = {2}\ndiff = {3}\n'.format(i,pt,s,diff)
        print metapop
        print metapop.overview()
        print
        print utils.timing_report(starttime, metapop.generation)
        rstore.flush()
        
        # fig = viz.plot_overview(metapop, show_generation=False, figsize=figsize)
        # fig = rstore.plot_sums(figsize=[max_figwidth, figheight])
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3000
# pt = 0.707122109194
# s = 0.137507933104
# diff = 0.679442239071
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3006  0.0142  0.0013  0.0370
#       P1          0.6545  0.0220  0.0005  0.0032
#       P2             ---     ---     ---     ---
# T2    P0          0.0015  0.0035  0.0145  0.9331
#       P1          0.0012  0.0024  0.0005  0.0098
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 11674
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9913  0.0087
# pop2        0.0421  0.9579
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3198  0.6802   0
# pop2        0.9860  0.0140   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9579  0.0421
# pop2        0.0169  0.9831
# Name: cytotype
#
# Simulation run completed.
# Generation: 11674
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3001
# pt = 0.555070689117
# s = 0.376416962515
# diff = 0.562720563512
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4181  0.0128  0.0009  0.0120
#       P1          0.5501  0.0127  0.0003  0.0015
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0030  0.0149  0.9653
#       P1          0.0006  0.0014  0.0003  0.0048
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 21359
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9937  0.0063
# pop2        0.0147  0.9853
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4352  0.5648   0
# pop2        0.9931  0.0069   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9701  0.0299
# pop2        0.0163  0.9837
# Name: cytotype
#
# Simulation run completed.
# Generation: 21359
# Elapsed Time (hours:minutes:seconds): 0:00:13
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3002
# pt = 0.544889087836
# s = 0.233085335513
# diff = 0.507100466907
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4705  0.0171  0.0011  0.0206
#       P1          0.4903  0.0140  0.0003  0.0017
#       P2             ---     ---     ---     ---
# T2    P0          0.0019  0.0037  0.0149  0.9561
#       P1          0.0009  0.0016  0.0003  0.0050
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 37051
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9919  0.0081
# pop2        0.0237  0.9763
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4933  0.5067   0
# pop2        0.9928  0.0072   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9636  0.0364
# pop2        0.0166  0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 37051
# Elapsed Time (hours:minutes:seconds): 0:00:24
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3003
# pt = 0.580302765225
# s = 0.283987222949
# diff = 0.582190356347
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3978  0.0139  0.0010  0.0163
#       P1          0.5663  0.0148  0.0003  0.0018
#       P2             ---     ---     ---     ---
# T2    P0          0.0014  0.0032  0.0149  0.9598
#       P1          0.0008  0.0017  0.0003  0.0056
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 19446
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9928  0.0072
# pop2        0.0194  0.9806
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4164  0.5836   0
# pop2        0.9919  0.0081   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9664  0.0336
# pop2        0.0165  0.9835
# Name: cytotype
#
# Simulation run completed.
# Generation: 19446
# Elapsed Time (hours:minutes:seconds): 0:00:13
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3004
# pt = 0.420102812006
# s = 0.372559190593
# diff = 0.000859150733576
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9645  0.0261  0.0013  0.0149
#       P1          0.0008     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0040  0.0046  0.0155  0.9683
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9914  0.0086
# pop2        0.0163  0.9837
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9991  0.0009   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9693  0.0307
# pop2        0.0168  0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00068
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3005
# pt = 0.633808483826
# s = 0.219895322453
# diff = 0.633055401004
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3473  0.0138  0.0011  0.0214
#       P1          0.6134  0.0178  0.0004  0.0023
#       P2             ---     ---     ---     ---
# T2    P0          0.0014  0.0033  0.0148  0.9526
#       P1          0.0010  0.0020  0.0004  0.0071
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 14945
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9923  0.0077
# pop2        0.0251  0.9749
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3658  0.6342   0
# pop2        0.9899  0.0101   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9632  0.0368
# pop2        0.0166  0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 14945
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3006
# pt = 0.356648173448
# s = 0.43195727167
# diff = 0.000480887272724
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9676  0.0242  0.0012  0.0128
#       P1          0.0005     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0034  0.0043  0.0154  0.9705
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 3047
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9923  0.0077
# pop2        0.0140  0.9860
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9995  0.0005   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9715  0.0285
# pop2        0.0167  0.9833
# Name: cytotype
#
# Simulation run completed.
# Generation: 3047
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.0007
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3007
# pt = 0.673131245233
# s = 0.070151236684
# diff = 0.000214844799474
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9259  0.0432  0.0027  0.0809
#       P1          0.0002     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0231  0.0076  0.0148  0.9016
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2797
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9693  0.0307
# pop2        0.0836  0.9164
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9998  0.0002   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9492  0.0508
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 2797
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3008
# pt = 0.506442721354
# s = 0.380898195734
# diff = 0.475503602032
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5037  0.0147  0.0009  0.0122
#       P1          0.4645  0.0107  0.0002  0.0013
#       P2             ---     ---     ---     ---
# T2    P0          0.0015  0.0032  0.0150  0.9663
#       P1          0.0006  0.0012  0.0002  0.0038
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 32894
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9935  0.0065
# pop2        0.0147  0.9853
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5231  0.4769   0
# pop2        0.9944  0.0056   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9702  0.0298
# pop2        0.0164  0.9836
# Name: cytotype
#
# Simulation run completed.
# Generation: 32894
# Elapsed Time (hours:minutes:seconds): 0:00:21
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3009
# pt = 0.728724427853
# s = 0.0850896909788
# diff = 0.671057873629
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3058  0.0160  0.0019  0.0672
#       P1          0.6444  0.0244  0.0006  0.0044
#       P2             ---     ---     ---     ---
# T2    P0          0.0017  0.0037  0.0141  0.9000
#       P1          0.0015  0.0026  0.0005  0.0113
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 15721
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9906  0.0094
# pop2        0.0741  0.9259
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3273  0.6727   0
# pop2        0.9832  0.0168   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9533  0.0467
# pop2        0.0171  0.9829
# Name: cytotype
#
# Simulation run completed.
# Generation: 15721
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3010
# pt = 0.800909030448
# s = 0.00702588192905
# diff = -0.000122318227898
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8642  0.0526  0.0120  0.6429
#       P1             0.0     ---     ---     ---
#       P2             ---     ---     ---     ---
# T2    P0          0.0763  0.0070  0.0057  0.3394
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6399
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9167  0.0833
# pop2        0.6549  0.3451
# Name: trait
#
# preference  P0  P1  P2
# population
# pop1         1   0   0
# pop2         1   0   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9405  0.0595
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 6399
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3011
# pt = 0.57165612978
# s = 0.356294165714
# diff = 0.582481401211
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3985  0.0126  0.0009  0.0127
#       P1          0.5690  0.0134  0.0003  0.0016
#       P2             ---     ---     ---     ---
# T2    P0          0.0012  0.0030  0.0149  0.9642
#       P1          0.0007  0.0015  0.0003  0.0052
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 19366
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9936  0.0064
# pop2        0.0155  0.9845
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4153  0.5847   0
# pop2        0.9926  0.0074   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9694  0.0306
# pop2        0.0163  0.9837
# Name: cytotype
#
# Simulation run completed.
# Generation: 19366
# Elapsed Time (hours:minutes:seconds): 0:00:12
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3012
# pt = 0.431015902664
# s = 0.424983073963
# diff = 0.000996151152277
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9668  0.0244  0.0012  0.0130
#       P1          0.0010     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0035  0.0043  0.0154  0.9703
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9922  0.0078
# pop2        0.0143  0.9857
# Name: trait
#
# preference     P0     P1  P2
# population
# pop1        0.999  0.001   0
# pop2        1.000  0.000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9712  0.0288
# pop2        0.0167  0.9833
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3013
# pt = 0.643715666096
# s = 0.187228499675
# diff = 0.637062260529
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3433  0.0144  0.0011  0.0256
#       P1          0.6153  0.0189  0.0004  0.0025
#       P2             ---     ---     ---     ---
# T2    P0          0.0015  0.0034  0.0147  0.9476
#       P1          0.0011  0.0021  0.0004  0.0076
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 14997
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9918  0.0082
# pop2        0.0297  0.9703
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3627  0.6373   0
# pop2        0.9892  0.0108   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9612  0.0388
# pop2        0.0167  0.9833
# Name: cytotype
#
# Simulation run completed.
# Generation: 14997
# Elapsed Time (hours:minutes:seconds): 0:00:09
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3014
# pt = 0.756526589447
# s = 0.0909344144882
# diff = 0.690163327841
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2844  0.0150  0.0018  0.0637
#       P1          0.6666  0.0248  0.0007  0.0046
#       P2             ---     ---     ---     ---
# T2    P0          0.0016  0.0036  0.0141  0.9021
#       P1          0.0014  0.0026  0.0005  0.0125
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 10848
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9908  0.0092
# pop2        0.0708  0.9292
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3045  0.6955   0
# pop2        0.9817  0.0183   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9540  0.0460
# pop2        0.0171  0.9829
# Name: cytotype
#
# Simulation run completed.
# Generation: 10848
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3015
# pt = 0.419382674599
# s = 0.384155757014
# diff = 0.000876379219272
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9650  0.0257  0.0013  0.0145
#       P1          0.0009     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0039  0.0045  0.0155  0.9688
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9916  0.0084
# pop2        0.0158  0.9842
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9991  0.0009   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9698  0.0302
# pop2        0.0167  0.9833
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3016
# pt = 0.502075482153
# s = 0.466108779039
# diff = 0.487056355064
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4938  0.0131  0.0008  0.0098
#       P1          0.4775  0.0099  0.0002  0.0012
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0029  0.0150  0.9692
#       P1          0.0005  0.0011  0.0002  0.0036
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 30723
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9942  0.0058
# pop2        0.0120  0.9880
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5111  0.4889   0
# pop2        0.9948  0.0052   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9730  0.0270
# pop2        0.0162  0.9838
# Name: cytotype
#
# Simulation run completed.
# Generation: 30723
# Elapsed Time (hours:minutes:seconds): 0:00:21
# Time per generation (seconds): 0.00069
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3017
# pt = 0.728632649257
# s = 0.114955010074
# diff = 0.687019601545
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2919  0.0145  0.0015  0.0463
#       P1          0.6613  0.0233  0.0006  0.0037
#       P2             ---     ---     ---     ---
# T2    P0          0.0015  0.0035  0.0144  0.9221
#       P1          0.0013  0.0025  0.0005  0.0109
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 11226
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9911  0.0089
# pop2        0.0521  0.9479
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3116  0.6884   0
# pop2        0.9844  0.0156   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9561  0.0439
# pop2        0.0170  0.9830
# Name: cytotype
#
# Simulation run completed.
# Generation: 11226
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3018
# pt = 0.436349477186
# s = 0.275482533267
# diff = 0.000494488839503
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9589  0.0298  0.0015  0.0204
#       P1          0.0005     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0056  0.0052  0.0155  0.9626
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 3013
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9892  0.0108
# pop2        0.0219  0.9781
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9995  0.0005   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype        U      W
# population
# pop1        0.965  0.035
# pop2        0.017  0.983
# Name: cytotype
#
# Simulation run completed.
# Generation: 3013
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3019
# pt = 0.392298784833
# s = 0.351782097786
# diff = 0.000488901431555
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9637  0.0268  0.0013  0.0158
#       P1          0.0005     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0043  0.0047  0.0155  0.9673
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 3028
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9910  0.0090
# pop2        0.0172  0.9828
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9995  0.0005   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9685  0.0315
# pop2        0.0168  0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 3028
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3020
# pt = 0.811671336333
# s = 0.038082682726
# diff = 0.000479385710351
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9046  0.0465  0.0038  0.1464
#       P1          0.0004     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0401  0.0085  0.0138  0.8359
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3075
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9514  0.0486
# pop2        0.1503  0.8497
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9996  0.0004   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9450  0.0550
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 3075
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3021
# pt = 0.685753435418
# s = 0.114063395502
# diff = 0.656123197232
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3246  0.0158  0.0015  0.0457
#       P1          0.6283  0.0222  0.0005  0.0033
#       P2             ---     ---     ---     ---
# T2    P0          0.0017  0.0037  0.0145  0.9247
#       P1          0.0013  0.0024  0.0004  0.0094
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 16343
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9908  0.0092
# pop2        0.0510  0.9490
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3457  0.6543   0
# pop2        0.9863  0.0137   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9559  0.0441
# pop2        0.0169  0.9831
# Name: cytotype
#
# Simulation run completed.
# Generation: 16343
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3022
# pt = 0.457196253834
# s = 0.292819352772
# diff = 0.000860007869736
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9598  0.0290  0.0015  0.0191
#       P1          0.0008     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0053  0.0051  0.0155  0.9639
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9897  0.0103
# pop2        0.0206  0.9794
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9991  0.0009   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9659  0.0341
# pop2        0.0169  0.9831
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00068
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3023
# pt = 0.652743573327
# s = 0.0726503221279
# diff = 0.000177130825157
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9270  0.0430  0.0027  0.0782
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0223  0.0075  0.0148  0.9043
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2662
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9701  0.0299
# pop2        0.0808  0.9192
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9998  0.0002   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9495  0.0505
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 2662
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3024
# pt = 0.615377045708
# s = 0.141101784214
# diff = 0.590635862255
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3895  0.0172  0.0014  0.0353
#       P1          0.5652  0.0190  0.0004  0.0025
#       P2             ---     ---     ---     ---
# T2    P0          0.0020  0.0038  0.0147  0.9382
#       P1          0.0012  0.0021  0.0004  0.0072
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 40317
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9909  0.0091
# pop2        0.0396  0.9604
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4125  0.5875   0
# pop2        0.9896  0.0104   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9579  0.0421
# pop2        0.0168  0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 40317
# Elapsed Time (hours:minutes:seconds): 0:00:26
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3025
# pt = 0.3496765263
# s = 0.480721680895
# diff = 0.000556417549143
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9694  0.0229  0.0012  0.0115
#       P1          0.0005     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0030  0.0041  0.0154  0.9719
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 2895
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9929  0.0071
# pop2        0.0126  0.9874
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9994  0.0006   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9730  0.0270
# pop2        0.0166  0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 2895
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3026
# pt = 0.338869259444
# s = 0.44719008427
# diff = 0.000413054478668
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9683  0.0238  0.0012  0.0124
#       P1          0.0004     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0033  0.0042  0.0154  0.9710
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 3127
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9925  0.0075
# pop2        0.0136  0.9864
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9996  0.0004   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9720  0.0280
# pop2        0.0166  0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 3127
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3027
# pt = 0.815690797357
# s = 0.0431518666157
# diff = 0.41142712914
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3939  0.0230  0.0055  0.2789
#       P1          0.5499  0.0247  0.0010  0.0166
#       P2             ---     ---     ---     ---
# T2    P0          0.0021  0.0033  0.0106  0.6699
#       P1          0.0013  0.0019  0.0005  0.0169
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 31440
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9914  0.0086
# pop2        0.3021  0.6979
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4222  0.5778   0
# pop2        0.9650  0.0350   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9471  0.0529
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 31440
# Elapsed Time (hours:minutes:seconds): 0:00:20
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3028
# pt = 0.61111160999
# s = 0.275695139478
# diff = 0.617921297819
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3626  0.0131  0.0010  0.0167
#       P1          0.6012  0.0159  0.0004  0.0020
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0032  0.0149  0.9586
#       P1          0.0008  0.0018  0.0003  0.0063
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 16061
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9929  0.0071
# pop2        0.0200  0.9800
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3802  0.6198   0
# pop2        0.9911  0.0089   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9660  0.0340
# pop2        0.0165  0.9835
# Name: cytotype
#
# Simulation run completed.
# Generation: 16061
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3029
# pt = 0.46020355742
# s = 0.264051008582
# diff = 0.000712887028135
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9578  0.0303  0.0015  0.0213
#       P1          0.0007     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0059  0.0053  0.0155  0.9617
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 2394
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9888  0.0112
# pop2        0.0228  0.9772
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9993  0.0007   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9644  0.0356
# pop2        0.0170  0.9830
# Name: cytotype
#
# Simulation run completed.
# Generation: 2394
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3030
# pt = 0.55749543435
# s = 0.265744171422
# diff = 0.543388747106
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4356  0.0153  0.0010  0.0177
#       P1          0.5274  0.0142  0.0003  0.0017
#       P2             ---     ---     ---     ---
# T2    P0          0.0016  0.0034  0.0149  0.9588
#       P1          0.0008  0.0016  0.0003  0.0052
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 24845
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9925  0.0075
# pop2        0.0208  0.9792
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4560  0.5440   0
# pop2        0.9925  0.0075   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9654  0.0346
# pop2        0.0165  0.9835
# Name: cytotype
#
# Simulation run completed.
# Generation: 24845
# Elapsed Time (hours:minutes:seconds): 0:00:15
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3031
# pt = 0.4411928059
# s = 0.403654372043
# diff = 0.00101618638834
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9658  0.0251  0.0013  0.0137
#       P1          0.0010     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0037  0.0044  0.0154  0.9695
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9919  0.0081
# pop2        0.0150  0.9850
# Name: trait
#
# preference     P0     P1  P2
# population
# pop1        0.999  0.001   0
# pop2        1.000  0.000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9705  0.0295
# pop2        0.0167  0.9833
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3032
# pt = 0.60672883983
# s = 0.105334255856
# diff = 0.000303810625023
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9372  0.0401  0.0022  0.0540
#       P1          0.0003     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0155  0.0069  0.0152  0.9285
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3044
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9776  0.0224
# pop2        0.0563  0.9437
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9997  0.0003   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9530  0.0470
# pop2        0.0174  0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 3044
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3033
# pt = 0.384015560426
# s = 0.353910924792
# diff = 0.00043829536334
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9639  0.0267  0.0013  0.0158
#       P1          0.0004     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0043  0.0047  0.0155  0.9674
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 3098
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9910  0.0090
# pop2        0.0171  0.9829
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9996  0.0004   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9686  0.0314
# pop2        0.0168  0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 3098
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3034
# pt = 0.409661210129
# s = 0.460511311474
# diff = 0.000941656777046
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9683  0.0234  0.0012  0.0120
#       P1          0.0009     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0032  0.0041  0.0154  0.9714
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9927  0.0073
# pop2        0.0132  0.9868
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9991  0.0009   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9724  0.0276
# pop2        0.0166  0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3035
# pt = 0.811118011608
# s = 0.0813730154773
# diff = 0.695797385475
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2631  0.0146  0.0021  0.0821
#       P1          0.6871  0.0262  0.0008  0.0063
#       P2             ---     ---     ---     ---
# T2    P0          0.0015  0.0034  0.0137  0.8781
#       P1          0.0015  0.0027  0.0006  0.0162
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 8450
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9909  0.0091
# pop2        0.0914  0.9086
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2825  0.7175   0
# pop2        0.9762  0.0238   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9531  0.0469
# pop2        0.0173  0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 8450
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3036
# pt = 0.411190074831
# s = 0.395254779122
# diff = 0.000857618863469
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9656  0.0253  0.0013  0.0141
#       P1          0.0008     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0038  0.0045  0.0154  0.9692
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9918  0.0082
# pop2        0.0153  0.9847
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9991  0.0009   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9702  0.0298
# pop2        0.0167  0.9833
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3037
# pt = 0.689663307026
# s = 0.0535352545932
# diff = 0.000128615817899
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9172  0.0449  0.0031  0.1054
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0298  0.0080  0.0144  0.8770
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2356
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9622  0.0378
# pop2        0.1086  0.8914
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9999  0.0001   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9471  0.0529
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 2356
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3038
# pt = 0.337651843108
# s = 0.452854925476
# diff = 0.000417555980915
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9685  0.0237  0.0012  0.0122
#       P1          0.0004     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0033  0.0042  0.0154  0.9712
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 3124
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9926  0.0074
# pop2        0.0134  0.9866
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9996  0.0004   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9722  0.0278
# pop2        0.0166  0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 3124
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3039
# pt = 0.527027233685
# s = 0.180224157362
# diff = 0.00063605851471
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9498  0.0347  0.0018  0.0314
#       P1          0.0006     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0089  0.0060  0.0154  0.9513
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2675
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9851  0.0149
# pop2        0.0332  0.9668
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9994  0.0006   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9593  0.0407
# pop2        0.0172  0.9828
# Name: cytotype
#
# Simulation run completed.
# Generation: 2675
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3040
# pt = 0.612134708506
# s = 0.251992888592
# diff = 0.615467620581
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3649  0.0136  0.0010  0.0184
#       P1          0.5977  0.0164  0.0004  0.0021
#       P2             ---     ---     ---     ---
# T2    P0          0.0014  0.0033  0.0148  0.9565
#       P1          0.0009  0.0019  0.0003  0.0064
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 16341
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9926  0.0074
# pop2        0.0218  0.9782
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3831  0.6169   0
# pop2        0.9908  0.0092   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9648  0.0352
# pop2        0.0165  0.9835
# Name: cytotype
#
# Simulation run completed.
# Generation: 16341
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3041
# pt = 0.495587120212
# s = 0.469484251868
# diff = 0.473902981429
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5067  0.0133  0.0008  0.0098
#       P1          0.4646  0.0096  0.0002  0.0011
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0029  0.0150  0.9694
#       P1          0.0005  0.0011  0.0002  0.0035
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 32641
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9942  0.0058
# pop2        0.0119  0.9881
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5243  0.4757   0
# pop2        0.9950  0.0050   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9731  0.0269
# ...
# Generation: 5247
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3986
# pt = 0.974724998682
# s = 0.296221303951
# diff = 0.68606587823
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1728  0.0076  0.0012  0.0365
#       P1          0.7924  0.0210  0.0012  0.0142
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0007  0.0022  0.0132  0.8471
#       P1          0.0009  0.0024  0.0019  0.0847
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6183
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9939  0.0061
# pop2        0.0532  0.9468
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1834  0.8166   0
# pop2        0.8981  0.1019   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9667  0.0333
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 6183
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3987
# pt = 0.9437879102
# s = 0.0277831783382
# diff = -0.740836411801
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8068  0.0514  0.0152  0.8430
#       P1          0.1333  0.0085  0.0025  0.1393
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4682
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.8582  0.1418   0
# pop2        0.8582  0.1418   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4682
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3988
# pt = 0.952579478243
# s = 0.22282401762
# diff = 0.730130263059
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1856  0.0089  0.0013  0.0362
#       P1          0.7761  0.0226  0.0010  0.0088
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0008  0.0026  0.0139  0.8902
#       P1          0.0010  0.0025  0.0012  0.0474
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6043
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9931  0.0069
# pop2        0.0473  0.9527
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1978  0.8022   0
# pop2        0.9415  0.0585   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9634  0.0366
# pop2        0.0174  0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 6043
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3989
# pt = 0.993675148692
# s = 0.197799913289
# diff = -0.976668294776
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4791  0.0305  0.0090  0.5006
#       P1          0.4610  0.0293  0.0087  0.4816
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4112
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5097  0.4903   0
# pop2        0.5097  0.4903   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4112
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3990
# pt = 0.975365706107
# s = 0.237019065125
# diff = -0.985928568507
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3141  0.0200  0.0059  0.3282
#       P1          0.6260  0.0399  0.0118  0.6540
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6472
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3341  0.6659   0
# pop2        0.3342  0.6658   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 6472
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3991
# pt = 0.984944650625
# s = 0.184415933169
# diff = -0.972796116422
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4303  0.0274  0.0081  0.4496
#       P1          0.5098  0.0325  0.0096  0.5327
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4358
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4577  0.5423   0
# pop2        0.4577  0.5423   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4358
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3992
# pt = 0.874083994651
# s = 0.0821210586009
# diff = 0.669797324444
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2457  0.0140  0.0026  0.1084
#       P1          0.7045  0.0272  0.0010  0.0104
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0032  0.0132  0.8396
#       P1          0.0014  0.0027  0.0007  0.0241
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6687
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9913  0.0087
# pop2        0.1224  0.8776
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2642  0.7358   0
# pop2        0.9638  0.0362   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9529  0.0471
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 6687
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3993
# pt = 0.963733829152
# s = 0.0782713509803
# diff = -0.90675144133
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5838  0.0372  0.0110  0.6100
#       P1          0.3564  0.0227  0.0067  0.3723
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4165
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference     P0     P1  P2
# population
# pop1        0.621  0.379   0
# pop2        0.621  0.379   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4165
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3994
# pt = 0.908350966407
# s = 0.250277155904
# diff = 0.762178236649
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1983  0.0089  0.0010  0.0222
#       P1          0.7651  0.0210  0.0007  0.0044
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0008  0.0026  0.0145  0.9331
#       P1          0.0010  0.0024  0.0008  0.0232
#       P2             ---     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6648
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9932  0.0068
# pop2        0.0284  0.9716
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2106  0.7894   0
# pop2        0.9709  0.0291   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9651  0.0349
# pop2        0.0170  0.9830
# Name: cytotype
#
# Simulation run completed.
# Generation: 6648
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3995
# pt = 0.907592044676
# s = 0.168796858496
# diff = 0.745877589283
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2034  0.0103  0.0014  0.0390
#       P1          0.7547  0.0239  0.0009  0.0062
#       P2             ---     ---     ---     ---
# T2    P0          0.0010  0.0029  0.0142  0.9110
#       P1          0.0012  0.0026  0.0008  0.0266
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 6273
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9923  0.0077
# pop2        0.0474  0.9526
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2176  0.7824   0
# pop2        0.9656  0.0344   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9603  0.0397
# pop2        0.0173  0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 6273
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3996
# pt = 0.956973185128
# s = 0.409663383233
# diff = 0.764228593624
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1800  0.0068  0.0008  0.0136
#       P1          0.7903  0.0174  0.0007  0.0044
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0006  0.0022  0.0143  0.9267
#       P1          0.0007  0.0020  0.0010  0.0384
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6983
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9945  0.0055
# pop2        0.0196  0.9804
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1896  0.8104   0
# pop2        0.9554  0.0445   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9716  0.0284
# pop2        0.0169  0.9831
# Name: cytotype
#
# Simulation run completed.
# Generation: 6983
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3997
# pt = 0.8369665151
# s = 0.171579944409
# diff = 0.743583771452
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2274  0.0110  0.0012  0.0315
#       P1          0.7309  0.0229  0.0007  0.0041
#       P2             ---     ---     ---     ---
# T2    P0          0.0011  0.0030  0.0145  0.9317
#       P1          0.0011  0.0026  0.0006  0.0157
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 7267
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9922  0.0078
# pop2        0.0375  0.9625
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2425  0.7575   0
# pop2        0.9789  0.0211   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9605  0.0395
# pop2        0.0170  0.9830
# Name: cytotype
#
# Simulation run completed.
# Generation: 7267
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3998
# pt = 0.984381674771
# s = 0.457115174054
# diff = 0.686120137442
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1601  0.0060  0.0009  0.0203
#       P1          0.8114  0.0175  0.0011  0.0117
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0005  0.0019  0.0130  0.8389
#       P1          0.0007  0.0021  0.0023  0.1118
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6965
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9949  0.0051
# pop2        0.0339  0.9661
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.1684  0.8316  0.0000
# pop2        0.8731  0.1268  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9727  0.0273
# pop2        0.0173  0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 6965
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3999
# pt = 0.951544592253
# s = 0.259917464713
# diff = 0.745759514326
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1837  0.0084  0.0011  0.0269
#       P1          0.7800  0.0212  0.0009  0.0069
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0008  0.0025  0.0141  0.9060
#       P1          0.0009  0.0024  0.0012  0.0430
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6243
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9934  0.0066
# pop2        0.0358  0.9642
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1954  0.8046   0
# pop2        0.9481  0.0519   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9655  0.0345
# pop2        0.0173  0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 6243
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065

# %% [markdown]
# Collecting and printing outcomes for all parameter combinations:

# %%
c = scenario['counter'][()]
diffs = np.array( [[x,y,z] for (x,y,z) in scenario['screening'][:c]] )    # convert lenght n array of 3-tuples to array of shape (n,3)
print '   pt      s       diff   '
print '--------------------------'
print diffs
# Out:
#    pt      s       diff
# --------------------------
# [[ 0.05045759  0.4979949   0.00010466]
#  [ 0.65142274  0.03467745  0.00001295]
#  [ 0.62064064  0.44992477  0.64303583]
#  ...,
#  [ 0.83696651  0.17157994  0.7435838 ]
#  [ 0.98438168  0.45711517  0.68612015]
#  [ 0.95154458  0.25991747  0.74575949]]

# %% [markdown]
# ## Plot

# %% [markdown]
# We use a custom colormap which changes from dark to light red, then from light to dark blue, and which has a small segment of white where red and blue touch each other.

# %%
from matplotlib.colors import LinearSegmentedColormap, hex2color

rd = hex2color('#960F27')   # dark red
rl = hex2color('#FBE6DA')   # light red
bl = hex2color('#DEEBF2')   # light blue
bd = hex2color('#15508D')   # dark blue

w = 0.005  # width of the white segment
v1 = 0.5 - w/2.
v2 = 0.5 + w/2.

cdict = {'red':   [(0.,  rd[0],  rd[0]),
                   (v1,  rl[0],     1.),
                   (v2,     1.,  bl[0]),
                   (1.,  bd[0],  bd[0])],
         'green': [(0.,  rd[1],  rd[1]),
                   (v1,  rl[1],     1.),
                   (v2,     1.,  bl[1]),
                   (1.,  bd[1],  bd[1])],
         'blue':  [(0.,  rd[2],  rd[2]),
                   (v1,  rl[2],     1.),
                   (v2,     1.,  bl[2]),
                   (1.,  bd[2],  bd[2])]}
mycmap = LinearSegmentedColormap('MyCmap', cdict)

# plot the colormap:
a=outer(ones(10),arange(0,1,0.001))
figure(figsize=(10,0.4))
grid(False)
axis('off')
imshow(a,aspect='auto',cmap=mycmap,origin="lower")

# %%
# set up figure environment:
fig_width_pt = 500.0                    # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height =fig_width *0.75             # height in inches
fig_size = [fig_width,fig_height]
params = {'backend': 'ps',
          'text.usetex': True,
          'text.family': 'sans-serif',
          'text.latex.preamble': [r"\usepackage{mathtools}"],
          'axes.labelsize': 10,
          'text.fontsize': 12,
          'legend.fontsize': 10,
          'xtick.labelsize': 10,
          'ytick.labelsize': 10,
          'figure.figsize': fig_size}
plt.rcParams.update(params)
ticks_font = font_manager.FontProperties(
    family='Helvetica',
    style='normal',
    size=10,
    weight='normal',
    stretch='normal')

# actual data:
X = diffs[:,0]
Y = diffs[:,1]
Z = diffs[:,2]

xmin, xmax = 0., 1.
ymin, ymax = 0., 0.5

# generate griddata for contour plot:
numspaces = 2*int(math.sqrt(n))
xi = linspace(xmin, xmax, numspaces)
yi = linspace(ymin, ymax, numspaces)
zi = griddata((X, Y), Z, (xi[None,:], yi[:,None]), method='nearest')

figure(1, figsize=fig_size)
plt.imshow(zi, extent=(xmin,xmax,ymin,ymax), 
    cmap=mycmap, 
    norm = matplotlib.colors.Normalize(vmin = -1.0, vmax = 1.0, clip = False), 
    vmin=-1., vmax=1., 
    origin='lower', 
    aspect='auto', 
    interpolation=None)  # use default interpolation
plt.clim(-1., 1.)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
ax = gca()
ax.grid(False)
ax.set_aspect(2.)

# add a colorbar:
cbar = plt.colorbar(ticks=[-1., -0.75, -0.5, -0.25, -0.01, 0.01, 0.25, 0.5, 0.75, 1.])
cax = cbar.ax
cax.set_yticklabels(['--1.0', '--0.75', '--0.5', '--0.25', '0.0', '', '0.25', '0.5', '0.75', '1.0'])
cax.set_ylabel(r'$\xleftarrow{\mathmakebox[8em]{\textstyle\text{decreasing}}}$ {\large Divergence} $\xrightarrow{\mathmakebox[8em]{\textstyle\text{increasing}}}$')
plt.setp(cax.yaxis.get_ticklines(minor=False), markersize=0)

# uncomment the following line to show screening data points:
#plt.scatter(X, Y, marker='o', color='k', alpha=0.2, s=0.5)

plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
ax.xaxis.labelpad = 17
ax.yaxis.labelpad = 17
ax.set_xticklabels(ax.get_xticks(), ticks_font)
ax.set_yticklabels(ax.get_yticks(), ticks_font)
plt.xlabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{high}}}$ {\large Preference costs} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{low}}}$',
    multialignment='left')
plt.ylabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{weak}}}$ {\large Viability selection} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{strong}}}$',
    multialignment='center')
plt.text(0.1, 0.15, r'No spread of\\mating preferences', color='0.4', size=12, ha='left', multialignment='center')
plt.text(0.55, 0.4, r'\textbf{Reinforcement}', color='w', size=14, ha='left')
plt.text(0.99, 0.02, r'\textbf{Runaway}', color='w', size=14, ha='right', va='bottom', rotation='vertical')
plt.text(0., -0.025, r'Transition probability, $\ p$', ha='left', va='top')
plt.text(-0.1, 0., r'Selection coefficient, $\ s$', ha='left', va='bottom', rotation='vertical')
#plt.savefig('/home/flor/Documents/Manuscripts/Runaways and reinforcement/Screening_costs_vs_preferencestrength.pdf')
plt.savefig('images/costly_s_vs_p.pdf')

# %%
len(diffs)
# Out:
# 4000

# %%
rstore.close()

# %%
# set up figure environment:
fig_width_pt = 500.0                    # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height =fig_width *0.75             # height in inches
fig_size = [fig_width,fig_height]
params = {'backend': 'ps',
          'text.usetex': True,
          'text.family': 'sans-serif',
          'text.latex.preamble': [r"\usepackage{mathtools}"],
          'axes.labelsize': 10,
          'text.fontsize': 12,
          'legend.fontsize': 10,
          'xtick.labelsize': 10,
          'ytick.labelsize': 10,
          'figure.figsize': fig_size}
plt.rcParams.update(params)
ticks_font = font_manager.FontProperties(
    family='Helvetica',
    style='normal',
    size=10,
    weight='normal',
    stretch='normal')

# actual data:
X = diffs[:,0]
Y = diffs[:,1]
Z = diffs[:,2]

xmin, xmax = 0.5, 1.
ymin, ymax = 0., 0.5

# generate griddata for contour plot:
numspaces = 2*int(math.sqrt(n))
xi = linspace(xmin, xmax, numspaces)
yi = linspace(ymin, ymax, numspaces)
zi = griddata((X, Y), Z, (xi[None,:], yi[:,None]), method='nearest')

figure(1, figsize=fig_size)
plt.imshow(zi, extent=(xmin,xmax,ymin,ymax), 
    cmap=mycmap, 
    norm = matplotlib.colors.Normalize(vmin = -1.0, vmax = 1.0, clip = False), 
    vmin=-1., vmax=1., 
    origin='lower', 
    aspect='auto', 
    interpolation=None)  # use default interpolation
plt.clim(-1., 1.)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
ax = gca()
ax.grid(False)
ax.set_aspect(1.)

# add a colorbar:
cbar = plt.colorbar(ticks=[-1., -0.75, -0.5, -0.25, -0.01, 0.01, 0.25, 0.5, 0.75, 1.])
cax = cbar.ax
cax.set_yticklabels(['--1.0', '--0.75', '--0.5', '--0.25', '0.0', '', '0.25', '0.5', '0.75', '1.0'])
cax.set_ylabel(r'$\xleftarrow{\mathmakebox[8em]{\textstyle\text{decreasing}}}$ {\large Divergence} $\xrightarrow{\mathmakebox[8em]{\textstyle\text{increasing}}}$')
plt.setp(cax.yaxis.get_ticklines(minor=False), markersize=0)

# uncomment the following line to show screening data points:
#plt.scatter(X, Y, marker='o', color='k', alpha=0.2, s=0.5)

plt.xlim(xmin, xmax)
ax.set_xlim(ax.get_xlim()[::-1])
plt.ylim(ymin, ymax)
ax.xaxis.labelpad = 17
ax.yaxis.labelpad = 17
ax.set_xticklabels(ax.get_xticks(), ticks_font)
ax.set_yticklabels(ax.get_yticks(), ticks_font)
plt.xlabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{small}}}$ {\large Preference costs} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{large}}}$',
    multialignment='left')
plt.ylabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{weak}}}$ {\large Viability selection} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{strong}}}$',
    multialignment='center')
plt.text(0.52, 0.03, r'No spread of\\mating preferences', color='0.4', size=12, ha='right', multialignment='center')
plt.text(0.85, 0.35, r'\textbf{Reinforcement}', color='w', size=14, ha='left')
plt.text(0.98, 0.03, r'\textbf{Runaway}', color='w', size=14, ha='left', va='bottom', rotation='vertical')
plt.text(1., -0.025, r'Transition probability, $\ p$', ha='left', va='top')
plt.text(1.05, 0., r'Selection coefficient, $\ s$', ha='left', va='bottom', rotation='vertical')
#plt.savefig('/home/flor/Documents/Manuscripts/Runaways and reinforcement/Screening_costs_vs_preferencestrength.pdf')
plt.savefig('images/costly_s_vs_p.pdf')
