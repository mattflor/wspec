# %% [markdown]
# # Scenario 2

# %%
import sys, types, time, os, inspect, shutil, pprint, cPickle, gzip, tarfile, pprint, datetime, pdb, copy
import numpy as np
import numpy.random as npr
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.display import Image
# wspec moduls:
import core, storage, analytical
import visualization as viz
import utilities as utils
for mod in [core,storage,analytical,utils,viz]:     # reload the wspec modules in case the code has changed
    reload(mod)
    
#np.set_printoptions(precision=4, suppress=True, linewidth=100)
np.set_printoptions(suppress=True, linewidth=100)
npr.seed(94832)

# %% [markdown]
# ## 1. Scenario features
#
# * Two populations linked by migration
#
# * Initial state:
#
#     * Trait T1 adaptive and fixed in population 1, T2 in population 2
#
#     * Preference allele P0 (non-discriminating) fixed in both populations
#
# * Population 1 is uninfected, *Wolbachia* infection in population 2
#
# * Order of events:
#
#     1.  Secondary contact
#         $\rightarrow$  selection-migration equilibrium
#
#     2.  Introduction of a preference for T1 in population 1, P1 (T1), and of a preference for T2 in population 2, P2 (T2)
#         $\rightarrow$  new equilibrium
#
# <img src="https://docs.google.com/drawings/d/1PI65vCcdE8Yv5Sa5cS_NrZ3QZzjU8nMVnLLMJycal04/pub?w=691&h=577">

# %% [markdown]
# ## 2. Configuration
#
# To configure the simulation scenario, we need to specify gene loci, alleles, and parameters.
#
# ### 2.1 Loci and alleles
#
# Populations are treated as loci, as would be the cytotype. In numpy terms, each locus is represented by an array axis.
#
# We keep separate lists rather than a dictionary because we need to preserve the locus and allele orders.

# %%
LOCI = ['population', 'trait', 'preference', 'cytotype']
ALLELES = [['pop1', 'pop2'],
           ['T1', 'T2'],
           ['P0', 'P1', 'P2'],
           ['U', 'W']
          ]
print utils.loci2string(LOCI, ALLELES)
# Out:
# locus           alleles
# --------------------------
# population      pop1, pop2
# trait           T1, T2
# preference      P0, P1, P2
# cytotype        U, W

# %%
def popdiff(metapop):
    """
    Measure frequency differences between populations. This function returns a NxN matrix containing 
    values between 0 and L-1 where N is the number of populations and L is the number of loci.
    """
    n = metapop.n_pops
    d = np.zeros((n,n), float)
    for i in range(n):
        for j in range(i,n):
            for loc in metapop.loci[1:]:
                sums = metapop.get_sums(loc)
                d[i,j] += np.max( np.abs(sums[i] - sums[j]) )
                d[j,i] = d[i,j]
    return d

def popdiff2(current, initial):
    """
    Measure frequency differences between populations. This function returns a NxN matrix containing 
    values between 0 and L-1 where N is the number of populations and L is the number of loci.
    In this version, the change from the initial equilibrium is also taken into account.
    """
    n = current.n_pops
    d = np.zeros((n,n), float)
    for i in range(n):
        d[i] += np.sum( np.abs(current.freqs-initial.freqs) )
        for j in range(i,n):
            for loc in current.loci[1:]:
                sums = current.get_sums(loc)
                d[i,j] += np.max( np.abs(sums[i] - sums[j]) )
                d[j,i] = d[i,j]
    return d

def classify(diff, difftype=2, thresh=1e-4):
    if diff < thresh:
        return 'nothing'
    elif thresh < diff < 2:
        return 'runaway'
    else:
        return 'reinforcement'

# %% [markdown]
# ### 2.2 Parameters

# %%
sid = '2screen2'     # scenario id
PARAMETERS = {
    'lCI': (0.9, 'CI level'),                   # level of cytoplasmic incompatibility
    't': (0.9, 'transmission rate'),            # transmission of Wolbachia
    'f': (0.1, 'fecundity reduction'),          # Wolbachia-infected females are less fecund
    'm': (0.01, 'migration rate'),              # symmetric migration
    'pt': (0.9, 'transition probability'),       # probability of transition into another mating round
    'intro': (0.001, 'introduction frequency'), # introduction frequency of preference mutant allele
    'eq': (1e-6, 'equilibrium threshold'),      # equilibrium threshold (total frequency change)
    'nmin': (1000, 'min generation'),            # run at least `nmin` generations in search of equilibrium
    'nmax': (300000, 'max generation'),         # max number of generations to iterate for each stage of the simulation
    'step': (10, 'storage stepsize')            # store metapopulation state every `step` generations
}
print 'Parameters that are the same for all runs in the screening:\n'
print utils.params2string(PARAMETERS)
# Out:
# Parameters that are the same for all runs in the screening:
#
# parameter    value       description
# -----------------------------------------------
# eq           1e-06       equilibrium threshold
# f            0.1         fecundity reduction
# intro        0.001       introduction frequency
# lCI          0.9         CI level
# m            0.01        migration rate
# nmax         300000      max generation
# nmin         1000        min generation
# pt           0.9         transition probability
# step         10          storage stepsize
# t            0.9         transmission rate

# %% [markdown]
# We'll generate random transition and rejection probabilities, run the simulation, and check the outcome via the `popdiff` function the results of which are stored as well.

# %%
n = 10000

screening_dtype = np.dtype([('pr', 'f'), ('s', 'f'), ('diff', 'f')])
rstore = storage.RunStore('/extra/flor/data/notebook_data/scenario_{0}.h5'.format(sid))
# select existing scenario, initialize a new one if this fails:
try:
    scenario = rstore.select_scenario(sid, verbose=False)
    count = scenario['counter'][()]
    maxcount = len(scenario['screening'])
except:
    scenario = rstore.create_scenario(sid, labels=(LOCI,ALLELES))
    # scenario = rstore['current']['scenario']
    scenario.create_dataset('counter', (), 'i')    # integer counter for the screening runs; initialized at 0
    count = 0
    maxcount = max(n, 10)
    scenario.create_dataset('screening', (maxcount,), screening_dtype, maxshape=(None,))
    
if n >= maxcount:
    scenario['screening'].resize((n,))

# %%
for i in range(n):
    # s = npr.random()                      # draw from a uniform distribution [0,1)
    # pr = npr.random()                     # draw from a uniform distribution [0,1)
    # we use a U-shaped beta function (low and high values more likely than intermediate ones)
    # to better explore the corners:
    s  = npr.beta(a=0.7, b=0.7)
    pr = npr.beta(a=0.7, b=0.7)
    PARAMETERS['s'] = (s, 'selection coefficient')        # selection advantage for adaptive trait
    PARAMETERS['pr'] = (pr, 'rejection probability')
    # For mating preference parameters, we use a different notation:
    trait_preferences = {                        # female mating preferences (rejection probabilities)
        'P0': {'baseline': 0.},
        'P1': {'baseline': pr, 'T1': 0.},
        'P2': {'baseline': pr, 'T2': 0.}
    }
    rid = 'pr{0:.12f}_s{1:.12f}'.format(pr,s)      # generate id of simulation run based on pr and pt values
    PARAMETERS = utils.add_preferences(PARAMETERS, trait_preferences)
    # make parameter names locally available:
    config = utils.configure_locals(LOCI, ALLELES, PARAMETERS)
    locals().update(config)

    max_figwidth = 15
    figheight = 5
    w = min( N_POPS*(N_LOCI-1), max_figwidth )    # figure width: npops*(nloci-1) but at most 15
    figsize = [w, figheight]
    show_progressbar = False          # BEWARE: enabling progressbar slows down the simulation significantly!
    
    overwrite_run = False
    data_available = False
    
    # select existing run, initialize a new one if this fails:
    try:   
        rstore.select_run(rid, verbose=False)
        data_available = True
        special_states = list( rstore.get_special_states()[::-1] )
    except:
        rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    # check whether parameters are identical:
    pars = rstore.get_parameters()
    if not utils.parameters_equal(pars, PARAMETERS, verbose=False):
        data_available = False
        if not overwrite_run:
            raise ValueError('parameter values differ from stored values; set `overwrite_run` to `True` in order to overwrite run')
        else:
            # print 'overwriting run...'
            rstore.remove_run(rid, sid)
            rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    
    if data_available:
        pass
    else:
        weights = {
            'migration': None,
            'viability_selection': None,
            'constant_reproduction': None,
            'dynamic_reproduction': []
        }
        mig = np.array(
            [[1-m,      m ],
             [  m,    1-m ]], float)
        M = core.MigrationWeight(
            name='migration',
            axes=['target', 'source'],
            config=config,
            arr=mig,
            m=m
        )
        weights['migration'] = M.extended()
        # print M
        
        vsarr = np.array(
            [[ 1+s,  1  ],
             [   1,  1+s]], float
        )
        VS = core.ViabilityWeight(
            name='viability selection',
            axes=['population','trait'],
            config=config,
            arr=vsarr,
            s=s
        )
        weights['viability_selection'] = VS.extended()
        # print VS
        
        TP = core.GeneralizedPreferenceWeight(
            name='trait preference',
            axes=['population', 'female_preference', 'male_trait'],
            pref_desc = trait_preferences,
            config=config,
            unstack_levels=[2],
            pt=pt
        )
        weights['dynamic_reproduction'].append( (TP, ['trait']) )
        # print TP
        
        CI = core.ReproductionWeight(
            name='cytoplasmic incompatibility',
            axes=['male_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            lCI=lCI
        )
        CI.set( np.array([[1, 1], [1-lCI, 1]], float ) )
        CI_ = CI.extended()
        # print CI
    
        T = core.ReproductionWeight(
            name='cytotype inheritance',
            axes=['female_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            t=t
        )
        T.set( np.array( [[1, 0], [1-t, t]], float ) )
        T_ = T.extended()
        # print T
        
        F = core.ReproductionWeight(
            name='fecundity reduction',
            axes=['female_cytotype'],
            config=config,
            f=f
        )
        F.set( np.array([1, 1-f], float) )
        F_ = F.extended()
        # print F
        
        IP = core.ReproductionWeight(
            name='preference inheritance',
            axes=['female_preference', 'male_preference', 'offspring_preference'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('preference')])
        IP.set( utils.nuclear_inheritance(n_alleles) )
        IP_ = IP.extended()
        # print IP
        
        IT = core.ReproductionWeight(
            name='trait inheritance',
            axes=['female_trait', 'male_trait', 'offspring_trait'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('trait')])
        IT.set( utils.nuclear_inheritance(n_alleles) )
        IT_ = IT.extended()
        # print IT
        
        R_ = CI_ * T_ * F_ * IP_ * IT_
        weights['constant_reproduction'] = R_
        
        # INITIAL STATE:
        starttime = time.time()                  # take time for timing report after simulation run
        startfreqs = np.zeros(FSHAPE)
        startfreqs[0,0,0,0] = 1.                   # pop1-T1-P0-U
        startfreqs[1,1,0,1] = 1.                   # pop2-T2-P0-W
        metapop = core.MetaPopulation(
            startfreqs,
            config=config,
            generation=0,
            name='metapopulation'
        )
        rstore.record_special_state(metapop.generation, 'start')
        rstore.dump_data(metapop)
        
        # MIGRATION-SELECTION EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        # make a copy of the metapopulation for later calculation of frequency differences:
        #initial = copy.copy(metapop)
        # frequency difference score before introduction of preference alleles:
        base_diff = popdiff(metapop)[0,1]
        
        # INTRODUCTION OF PREFERENCE MUTANTS:
        intro_allele = 'P1'
        metapop.introduce_allele('pop1', intro_allele, intro_freq=intro, advance_generation_count=False)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        intro_allele = 'P2'
        metapop.introduce_allele('pop2', intro_allele, intro_freq=intro, advance_generation_count=True)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        # FINAL EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        
        #diff = popdiff2(metapop, initial)[0,1]
        diff = popdiff(metapop)[0,1] - base_diff
        scenario['screening'][i] = (pr, s, diff)
        scenario['counter'][()] += 1
        
        print '\n^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^'
        print 'i = {0}\npr = {1}\ns  = {2}\ndiff = {3}\n'.format(i,pr,s,diff)
        print metapop
        print metapop.overview()
        print
        print utils.timing_report(starttime, metapop.generation)
        rstore.flush()
        
        # fig = viz.plot_overview(metapop, show_generation=False, figsize=figsize)
        # fig = rstore.plot_sums(figsize=[max_figwidth, figheight])
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 20
# pr = 0.887886060275
# s  = 0.782587858046
# diff = 0.812867431079
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1716  0.0048  0.0005  0.0051
#       P1          0.8079  0.0121  0.0004  0.0018
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0004  0.0016  0.0147  0.9692
#       P1          0.0004  0.0014  0.0004  0.0080
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 8728
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9963  0.0037
# pop2        0.0078  0.9922
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1784  0.8216   0
# pop2        0.9894  0.0106   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9801  0.0199
# pop2        0.0160  0.9840
# Name: cytotype
#
# Simulation run completed.
# Generation: 8728
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 21
# pr = 0.33694430617
# s  = 0.506290465522
# diff = 0.368516750632
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5644  0.0139  0.0009  0.0097
#       P1          0.4071  0.0082  0.0003  0.0016
#       P2             ---     ---     ---     ---
# T2    P0          0.0016  0.0029  0.0145  0.9261
#       P1          0.0007  0.0010  0.0009  0.0460
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 28331
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9938  0.0062
# pop2        0.0125  0.9875
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5829  0.4171   0
# pop2        0.9512  0.0488   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9739  0.0261
# pop2        0.0166  0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 28331
# Elapsed Time (hours:minutes:seconds): 0:00:18
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 22
# pr = 0.238204892805
# s  = 0.230547731424
# diff = 0.135135673911
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.7889  0.0268  0.0015  0.0238
#       P1          0.1676  0.0051  0.0002  0.0016
#       P2             ---     ---     ---     ---
# T2    P0          0.0052  0.0048  0.0148  0.9210
#       P1          0.0009  0.0007  0.0007  0.0365
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 62060
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9884  0.0116
# pop2        0.0270  0.9730
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.8258  0.1742   0
# pop2        0.9610  0.0390   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9626  0.0374
# pop2        0.0171  0.9829
# Name: cytotype
#
# Simulation run completed.
# Generation: 62060
# Elapsed Time (hours:minutes:seconds): 0:00:40
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 23
# pr = 0.0856235754189
# s  = 0.528260247534
# diff = 0.000412156618177
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9709  0.0218  0.0011  0.0104
#       P1          0.0007     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0027  0.0039  0.0154  0.9728
#       P1             0.0     0.0     0.0  0.0003
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2497
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9934  0.0066
# pop2        0.0115  0.9885
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9993  0.0007   0
# pop2        0.9997  0.0003   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9744  0.0256
# pop2        0.0165  0.9835
# Name: cytotype
#
# Simulation run completed.
# Generation: 2497
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 24
# pr = 0.507985560579
# s  = 0.58574167536
# diff = 0.59128182709
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3590  0.0091  0.0007  0.0079
#       P1          0.6155  0.0113  0.0004  0.0020
#       P2             ---     ---     ---     ---
# T2    P0          0.0009  0.0023  0.0145  0.9387
#       P1          0.0007  0.0013  0.0008  0.0350
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 15183
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9948  0.0052
# pop2        0.0109  0.9891
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3712  0.6288   0
# pop2        0.9618  0.0382   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9761  0.0239
# pop2        0.0164  0.9836
# Name: cytotype
#
# Simulation run completed.
# Generation: 15183
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 25
# pr = 0.953323250057
# s  = 0.221528825834
# diff = 0.824049451984
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1548  0.0080  0.0010  0.0238
#       P1          0.8078  0.0228  0.0009  0.0041
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0007  0.0026  0.0145  0.9452
#       P1          0.0008  0.0026  0.0005  0.0099
#       P2             ---     0.0     0.0     0.0
# Name: metapopulation
# Generation: 5487
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9934  0.0066
# pop2        0.0299  0.9701
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1660  0.8340   0
# pop2        0.9845  0.0155   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9640  0.0360
# pop2        0.0169  0.9831
# Name: cytotype
#
# Simulation run completed.
# Generation: 5487
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 26
# pr = 0.123330444219
# s  = 0.241205498909
# diff = 0.000486283303514
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9559  0.0314  0.0016  0.0234
#       P1          0.0007     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0065  0.0054  0.0155  0.9593
#       P1             0.0     0.0     0.0  0.0003
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2050
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9880  0.0120
# pop2        0.0249  0.9751
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9992  0.0008   0
# pop2        0.9997  0.0003   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9632  0.0368
# pop2        0.0171  0.9829
# Name: cytotype
#
# Simulation run completed.
# Generation: 2050
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.0007
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 27
# pr = 0.831427372511
# s  = 0.302896617928
# diff = 0.780599776079
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1890  0.0081  0.0009  0.0168
#       P1          0.7771  0.0196  0.0007  0.0036
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0007  0.0025  0.0146  0.9455
#       P1          0.0008  0.0022  0.0007  0.0174
#       P2             ---     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6736
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9937  0.0063
# pop2        0.0219  0.9781
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2003  0.7997   0
# pop2        0.9777  0.0223   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9677  0.0323
# pop2        0.0168  0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 6736
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 28
# pr = 0.538888229619
# s  = 5.90887587074e-05
# diff = -6.6941179148e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9387  0.0598  0.0177  0.9807
#       P1          0.0003     0.0     0.0  0.0004
#       P2             ---     ---     ---     ---
# T2    P0          0.0011     0.0     0.0  0.0012
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 147904
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9988  0.0012
# pop2        0.9988  0.0012
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9996  0.0004   0
# pop2        0.9996  0.0004   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 147904
# Elapsed Time (hours:minutes:seconds): 0:01:35
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 29
# pr = 0.87822212167
# s  = 0.404270183757
# diff = 0.8038191725
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1737  0.0068  0.0007  0.0114
#       P1          0.7967  0.0174  0.0006  0.0029
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0006  0.0022  0.0147  0.9570
#       P1          0.0006  0.0020  0.0005  0.0121
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6866
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9946  0.0054
# pop2        0.0156  0.9844
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1833  0.8167   0
# pop2        0.9839  0.0161   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9716  0.0284
# pop2        0.0166  0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 6866
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 30
# pr = 0.389467629465
# s  = 0.674184146832
# diff = 0.45891513162
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4857  0.0105  0.0007  0.0069
#       P1          0.4906  0.0083  0.0003  0.0015
#       P2             ---     ---     ---     ---
# T2    P0          0.0011  0.0023  0.0145  0.9361
#       P1          0.0005  0.0010  0.0008  0.0392
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 24290
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9950  0.0050
# pop2        0.0094  0.9906
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4996  0.5004   0
# pop2        0.9582  0.0418   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9779  0.0221
# pop2        0.0163  0.9837
# Name: cytotype
#
# Simulation run completed.
# Generation: 24290
# Elapsed Time (hours:minutes:seconds): 0:00:15
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 31
# pr = 0.995116616416
# s  = 0.490236470622
# diff = 0.845744319632
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1427  0.0056  0.0005  0.0081
#       P1          0.8308  0.0163  0.0007  0.0023
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0004  0.0020  0.0146  0.9687
#       P1          0.0004  0.0019  0.0003  0.0047
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6427
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9953  0.0047
# pop2        0.0117  0.9883
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1506  0.8494   0
# pop2        0.9920  0.0080   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9743  0.0257
# pop2        0.0161  0.9839
# Name: cytotype
#
# Simulation run completed.
# Generation: 6427
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 32
# pr = 0.949052169581
# s  = 0.574081138924
# diff = 0.831540420469
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1543  0.0054  0.0005  0.0071
#       P1          0.8211  0.0148  0.0006  0.0022
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0004  0.0019  0.0147  0.9681
#       P1          0.0004  0.0017  0.0004  0.0064
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 7142
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9956  0.0044
# pop2        0.0104  0.9896
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1619  0.8381   0
# pop2        0.9904  0.0096   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9763  0.0237
# pop2        0.0161  0.9839
# Name: cytotype
#
# Simulation run completed.
# Generation: 7142
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 33
# pr = 0.0216494698144
# s  = 0.100905745059
# diff = 0.00010541170919
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9356  0.0404  0.0023  0.0564
#       P1          0.0006     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0162  0.0070  0.0151  0.9255
#       P1             0.0     0.0     0.0  0.0005
#       P2             0.0     0.0     0.0  0.0001
# Name: metapopulation
# Generation: 2202
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9768  0.0232
# pop2        0.0587  0.9413
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9992  0.0007  0.0001
# pop2        0.9993  0.0006  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9525  0.0475
# pop2        0.0174  0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2202
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 34
# pr = 0.577358933062
# s  = 0.35250538188
# diff = 0.636450527651
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3079  0.0104  0.0009  0.0143
#       P1          0.6591  0.0158  0.0005  0.0031
#       P2             ---     ---     ---     ---
# T2    P0          0.0011  0.0027  0.0144  0.9277
#       P1          0.0010  0.0019  0.0010  0.0380
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 10775
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9933  0.0067
# pop2        0.0189  0.9811
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3222  0.6778   0
# pop2        0.9574  0.0426   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9692  0.0308
# pop2        0.0168  0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 10775
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 35
# pr = 0.336996386175
# s  = 0.764495207134
# diff = 0.378893864063
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5677  0.0110  0.0007  0.0062
#       P1          0.4102  0.0064  0.0002  0.0011
#       P2             ---     ---     ---     ---
# T2    P0          0.0011  0.0023  0.0145  0.9395
#       P1          0.0004  0.0008  0.0007  0.0370
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 33607
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9954  0.0046
# pop2        0.0082  0.9918
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5822  0.4178   0
# pop2        0.9609  0.0391   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9795  0.0205
# pop2        0.0162  0.9838
# Name: cytotype
#
# Simulation run completed.
# Generation: 33607
# Elapsed Time (hours:minutes:seconds): 0:00:21
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 36
# pr = 0.0542755056021
# s  = 0.365422359098
# diff = 0.000269209666271
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9643  0.0263  0.0013  0.0152
#       P1          0.0006     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0041  0.0046  0.0155  0.9676
#       P1             0.0     0.0     0.0  0.0003
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2614
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9913  0.0087
# pop2        0.0166  0.9834
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9994  0.0006   0
# pop2        0.9996  0.0004   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9691  0.0309
# pop2        0.0168  0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 2614
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 37
# pr = 0.0761419918486
# s  = 0.979135847701
# diff = 0.000465448153038
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9804  0.0148  0.0008  0.0055
#       P1          0.0007     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0014  0.0027  0.0152  0.9782
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2565
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9959  0.0041
# pop2        0.0063  0.9937
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9993  0.0007  0.0000
# pop2        0.9997  0.0002  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9825  0.0175
# pop2        0.0160  0.9840
# Name: cytotype
#
# Simulation run completed.
# Generation: 2565
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 38
# pr = 0.422631951219
# s  = 0.430708377751
# diff = 0.489834826511
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4429  0.0125  0.0009  0.0114
#       P1          0.5264  0.0116  0.0004  0.0023
#       P2             ---     ---     ---     ---
# T2    P0          0.0015  0.0028  0.0144  0.9223
#       P1          0.0009  0.0014  0.0010  0.0473
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 17917
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9934  0.0066
# pop2        0.0150  0.9850
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4597  0.5403   0
# pop2        0.9490  0.0510   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9717  0.0283
# pop2        0.0167  0.9833
# Name: cytotype
#
# Simulation run completed.
# Generation: 17917
# Elapsed Time (hours:minutes:seconds): 0:00:11
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 39
# pr = 0.0352029522788
# s  = 0.513968419336
# diff = 0.000231389014621
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9705  0.0221  0.0011  0.0107
#       P1          0.0006     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0028  0.0039  0.0154  0.9723
#       P1             0.0     0.0     0.0  0.0004
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2627
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9933  0.0067
# pop2        0.0118  0.9882
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9993  0.0006  0.0000
# pop2        0.9995  0.0004  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9740  0.0260
# pop2        0.0165  0.9835
# Name: cytotype
#
# Simulation run completed.
# Generation: 2627
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 40
# pr = 0.817745315153
# s  = 0.0830634502923
# diff = 0.612813583759
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2456  0.0142  0.0032  0.1465
#       P1          0.7044  0.0277  0.0012  0.0163
#       P2             ---     ---     ---     ---
# T2    P0          0.0012  0.0030  0.0124  0.7904
#       P1          0.0013  0.0026  0.0008  0.0292
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5808
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9919  0.0081
# pop2        0.1672  0.8328
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2641  0.7359   0
# pop2        0.9526  0.0474   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9525  0.0475
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 5808
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 41
# pr = 0.945380735865
# s  = 0.628391038249
# diff = 0.830789039565
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1554  0.0051  0.0005  0.0064
#       P1          0.8212  0.0140  0.0005  0.0021
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0004  0.0018  0.0147  0.9692
#       P1          0.0004  0.0016  0.0004  0.0063
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 7432
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9958  0.0042
# pop2        0.0095  0.9905
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1627  0.8373   0
# pop2        0.9907  0.0092   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9774  0.0226
# pop2        0.0161  0.9839
# Name: cytotype
#
# Simulation run completed.
# Generation: 7432
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 42
# pr = 0.52436900634
# s  = 0.35851241779
# diff = 0.59232740094
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3461  0.0113  0.0009  0.0141
#       P1          0.6209  0.0149  0.0005  0.0030
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0028  0.0144  0.9234
#       P1          0.0011  0.0018  0.0010  0.0427
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 12318
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9931  0.0069
# pop2        0.0185  0.9815
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3614  0.6386   0
# pop2        0.9528  0.0472   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9693  0.0307
# pop2        0.0168  0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 12318
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 43
# pr = 0.640567187297
# s  = 0.0147296308744
# diff = -2.40334711132e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8646  0.0492  0.0072  0.3496
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0770  0.0093  0.0106  0.6327
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3559
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9138  0.0862
# pop2        0.3567  0.6433
# Name: trait
#
# preference  P0  P1  P2
# population
# pop1         1   0   0
# pop2         1   0   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9416  0.0584
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3559
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 44
# pr = 0.992807537938
# s  = 0.661690610922
# diff = 0.845827810946
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1437  0.0048  0.0004  0.0057
#       P1          0.8337  0.0138  0.0006  0.0019
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0004  0.0017  0.0146  0.9724
#       P1          0.0003  0.0016  0.0003  0.0040
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 7222
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9960  0.0040
# pop2        0.0086  0.9914
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.1506  0.8494  0.0000
# pop2        0.9932  0.0068  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9781  0.0219
# pop2        0.0159  0.9841
# Name: cytotype
#
# Simulation run completed.
# Generation: 7222
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 45
# pr = 0.0381194630934
# s  = 0.410798222726
# diff = 0.000224387577672
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9665  0.0248  0.0013  0.0135
#       P1          0.0006     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0036  0.0044  0.0154  0.9693
#       P1             0.0     0.0     0.0  0.0004
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2612
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9920  0.0080
# pop2        0.0148  0.9852
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9993  0.0006  0.0000
# pop2        0.9995  0.0004  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9708  0.0292
# pop2        0.0167  0.9833
# Name: cytotype
#
# Simulation run completed.
# Generation: 2612
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00069
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 46
# pr = 0.898933994004
# s  = 0.893613680205
# diff = 0.817450623282
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1687  0.0044  0.0004  0.0043
#       P1          0.8124  0.0111  0.0004  0.0016
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0003  0.0015  0.0147  0.9713
#       P1          0.0003  0.0013  0.0003  0.0069
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 9177
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9966  0.0034
# pop2        0.0068  0.9932
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1749  0.8251   0
# pop2        0.9907  0.0092   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9818  0.0182
# pop2        0.0158  0.9842
# Name: cytotype
#
# Simulation run completed.
# Generation: 9177
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 47
# pr = 0.249983421388
# s  = 0.994416698299
# diff = 0.00105316763854
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9802  0.0147  0.0008  0.0054
#       P1          0.0012     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0013  0.0027  0.0152  0.9784
#       P1             0.0     0.0     0.0  0.0001
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2358
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9960  0.0040
# pop2        0.0062  0.9938
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9988  0.0012  0.0000
# pop2        0.9998  0.0001  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9827  0.0173
# pop2        0.0160  0.9840
# Name: cytotype
#
# Simulation run completed.
# Generation: 2358
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 48
# pr = 0.956802732848
# s  = 0.0322674302084
# diff = -0.773666444582
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.7101  0.0452  0.0134  0.7419
#       P1          0.2301  0.0146  0.0043  0.2403
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5031
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.7553  0.2447   0
# pop2        0.7553  0.2447   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5031
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 49
# pr = 0.703644491318
# s  = 0.664355091684
# diff = 0.73210158862
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2381  0.0064  0.0006  0.0065
#       P1          0.7387  0.0124  0.0004  0.0020
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0006  0.0019  0.0146  0.9561
#       P1          0.0005  0.0014  0.0006  0.0192
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 10532
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9956  0.0044
# pop2        0.0095  0.9905
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2470  0.7530   0
# pop2        0.9778  0.0222   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9779  0.0221
# pop2        0.0163  0.9837
# Name: cytotype
#
# Simulation run completed.
# Generation: 10532
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 50
# pr = 0.113378794173
# s  = 0.324082866558
# diff = 0.000472344067578
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9619  0.0278  0.0014  0.0172
#       P1          0.0007     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0047  0.0049  0.0155  0.9656
#       P1             0.0     0.0     0.0  0.0003
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2183
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9904  0.0096
# pop2        0.0186  0.9814
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9992  0.0008   0
# pop2        0.9997  0.0003   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9673  0.0327
# pop2        0.0169  0.9831
# Name: cytotype
#
# Simulation run completed.
# Generation: 2183
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 51
# pr = 0.670306848463
# s  = 0.325766118504
# diff = 0.698817539838
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2547  0.0095  0.0009  0.0157
#       P1          0.7117  0.0176  0.0006  0.0034
#       P2             ---     ---     ---     ---
# T2    P0          0.0010  0.0026  0.0145  0.9336
#       P1          0.0010  0.0020  0.0009  0.0304
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 8758
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9934  0.0066
# pop2        0.0206  0.9794
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2677  0.7323   0
# pop2        0.9648  0.0352   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9683  0.0317
# pop2        0.0169  0.9831
# Name: cytotype
#
# Simulation run completed.
# Generation: 8758
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 52
# pr = 0.664028719819
# s  = 0.962859727218
# diff = 0.716105228397
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2577  0.0053  0.0005  0.0042
#       P1          0.7240  0.0095  0.0003  0.0015
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0005  0.0016  0.0146  0.9611
#       P1          0.0004  0.0011  0.0005  0.0172
#       P2             ---     0.0     0.0     0.0
# Name: metapopulation
# Generation: 13458
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9965  0.0035
# pop2        0.0065  0.9935
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2651  0.7349   0
# pop2        0.9805  0.0195   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9825  0.0175
# pop2        0.0159  0.9841
# Name: cytotype
#
# Simulation run completed.
# Generation: 13458
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 53
# pr = 0.51398816251
# s  = 0.000120900723524
# diff = -6.32002097978e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9389  0.0598  0.0177  0.9809
#       P1          0.0006     0.0     0.0  0.0006
#       P2             ---     ---     ---     ---
# T2    P0          0.0007     0.0     0.0  0.0007
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 86502
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9993  0.0007
# pop2        0.9993  0.0007
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9994  0.0006   0
# pop2        0.9994  0.0006   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 86502
# Elapsed Time (hours:minutes:seconds): 0:00:56
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 54
# pr = 0.46166439705
# s  = 0.0148564482507
# diff = -3.09842853667e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8649  0.0491  0.0071  0.3470
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0767  0.0093  0.0106  0.6353
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3506
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9140  0.0860
# pop2        0.3541  0.6459
# Name: trait
#
# preference  P0  P1  P2
# population
# pop1         1   0   0
# pop2         1   0   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9416  0.0584
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3506
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 55
# pr = 0.977871593098
# s  = 0.988103361187
# diff = 0.842391847036
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1484  0.0038  0.0003  0.0036
#       P1          0.8341  0.0106  0.0004  0.0015
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0003  0.0014  0.0146  0.9755
#       P1          0.0003  0.0012  0.0002  0.0036
#       P2             0.0     0.0     0.0  0.0001
# Name: metapopulation
# Generation: 8848
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9969  0.0031
# pop2        0.0059  0.9941
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.1539  0.8461  0.0000
# pop2        0.9941  0.0057  0.0002
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9830  0.0170
# pop2        0.0156  0.9844
# Name: cytotype
#
# Simulation run completed.
# Generation: 8848
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 56
# pr = 0.952637211809
# s  = 0.624483064372
# diff = 0.833095429101
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1535  0.0051  0.0005  0.0064
#       P1          0.8231  0.0141  0.0006  0.0021
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0004  0.0018  0.0147  0.9695
#       P1          0.0004  0.0016  0.0003  0.0060
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 7355
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9958  0.0042
# pop2        0.0095  0.9905
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1608  0.8392   0
# pop2        0.9910  0.0089   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9774  0.0226
# pop2        0.0161  0.9839
# Name: cytotype
#
# Simulation run completed.
# Generation: 7355
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 57
# pr = 0.22293561489
# s  = 0.669869478346
# diff = 0.00092442998997
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9745  0.0190  0.0010  0.0081
#       P1          0.0011     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0021  0.0034  0.0153  0.9753
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2166
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9945  0.0055
# pop2        0.0091  0.9909
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9989  0.0011  0.0000
# pop2        0.9998  0.0002  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9776  0.0224
# pop2        0.0163  0.9837
# Name: cytotype
#
# Simulation run completed.
# Generation: 2166
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 58
# pr = 0.764356951774
# s  = 0.00529414097697
# diff = -0.000320798595528
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8906  0.0555  0.0146  0.7991
#       P1             0.0     ---     ---     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0497  0.0042  0.0031  0.1832
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 15556
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9461  0.0539
# pop2        0.8137  0.1863
# Name: trait
#
# preference  P0  P1  P2
# population
# pop1         1   0   0
# pop2         1   0   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9403  0.0597
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 15556
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 59
# pr = 0.808482024826
# s  = 0.159805561052
# diff = 0.748816367767
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2037  0.0104  0.0014  0.0408
#       P1          0.7539  0.0242  0.0009  0.0060
#       P2             ---     ---     ---     ---
# T2    P0          0.0010  0.0029  0.0142  0.9116
#       P1          0.0012  0.0027  0.0008  0.0242
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 6256
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9922  0.0078
# pop2        0.0491  0.9509
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2181  0.7819   0
# pop2        0.9681  0.0319   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9597  0.0403
# pop2        0.0173  0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 6256
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 60
# pr = 0.308621581342
# s  = 0.188143466831
# diff = 0.281229183368
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6210  0.0233  0.0015  0.0296
#       P1          0.3329  0.0108  0.0003  0.0036
#       P2             ---     ---     ---     ---
# T2    P0          0.0045  0.0044  0.0142  0.8896
#       P1          0.0017  0.0013  0.0012  0.0599
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 28473
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9880  0.0120
# pop2        0.0351  0.9649
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6532  0.3468   0
# pop2        0.9349  0.0651   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9601  0.0399
# pop2        0.0172  0.9828
# Name: cytotype
#
# Simulation run completed.
# Generation: 28473
# Elapsed Time (hours:minutes:seconds): 0:00:18
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 61
# pr = 0.39782736472
# s  = 0.908321156066
# diff = 0.47821286524
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4760  0.0086  0.0006  0.0049
#       P1          0.5045  0.0070  0.0002  0.0012
#       P2             ---     ---     ---     ---
# T2    P0          0.0008  0.0020  0.0145  0.9453
#       P1          0.0004  0.0008  0.0007  0.0326
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 26996
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9960  0.0040
# pop2        0.0069  0.9931
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4873  0.5127   0
# pop2        0.9653  0.0347   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9817  0.0183
# ...
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9575  0.0303  0.0015  0.0213
#       P1          0.0011     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0059  0.0053  0.0155  0.9614
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9888  0.0112
# pop2        0.0228  0.9772
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9989  0.0011   0
# pop2        0.9997  0.0002   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9644  0.0356
# pop2        0.0170  0.9830
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 87
# pr = 0.323311440187
# s  = 0.54359946762
# diff = 0.345933802315
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5894  0.0139  0.0009  0.0090
#       P1          0.3833  0.0075  0.0002  0.0015
#       P2             ---     ---     ---     ---
# T2    P0          0.0016  0.0029  0.0145  0.9291
#       P1          0.0006  0.0009  0.0009  0.0439
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 31644
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9940  0.0060
# pop2        0.0116  0.9884
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6078  0.3922   0
# pop2        0.9535  0.0465   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9749  0.0251
# pop2        0.0165  0.9835
# Name: cytotype
#
# Simulation run completed.
# Generation: 31644
# Elapsed Time (hours:minutes:seconds): 0:00:20
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 88
# pr = 0.911911778711
# s  = 0.88796010222
# diff = 0.821696970924
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1651  0.0043  0.0004  0.0043
#       P1          0.8160  0.0112  0.0004  0.0016
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0003  0.0015  0.0147  0.9718
#       P1          0.0003  0.0013  0.0003  0.0064
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 9011
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9966  0.0034
# pop2        0.0068  0.9932
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.1713  0.8287  0.0000
# pop2        0.9912  0.0087  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9817  0.0183
# pop2        0.0158  0.9842
# Name: cytotype
#
# Simulation run completed.
# Generation: 9011
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.00068
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 89
# pr = 0.31134604836
# s  = 0.3659842328
# diff = 0.312653404548
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6097  0.0175  0.0011  0.0140
#       P1          0.3562  0.0086  0.0003  0.0020
#       P2             ---     ---     ---     ---
# T2    P0          0.0024  0.0035  0.0145  0.9161
#       P1          0.0009  0.0011  0.0010  0.0511
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 30301
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9921  0.0079
# pop2        0.0174  0.9826
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6332  0.3668   0
# pop2        0.9456  0.0544   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9693  0.0307
# pop2        0.0168  0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 30301
# Elapsed Time (hours:minutes:seconds): 0:00:20
# Time per generation (seconds): 0.00069
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 90
# pr = 0.378225113765
# s  = 0.151531376281
# diff = 0.383639137601
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5113  0.0212  0.0016  0.0392
#       P1          0.4403  0.0152  0.0005  0.0057
#       P2             ---     ---     ---     ---
# T2    P0          0.0038  0.0042  0.0139  0.8715
#       P1          0.0022  0.0018  0.0013  0.0663
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 18529
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9879  0.0121
# pop2        0.0469  0.9531
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5405  0.4595   0
# pop2        0.9262  0.0738   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9577  0.0423
# pop2        0.0173  0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 18529
# Elapsed Time (hours:minutes:seconds): 0:00:12
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 91
# pr = 0.113974415252
# s  = 0.677949093418
# diff = 0.00054989183815
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9750  0.0188  0.0010  0.0080
#       P1          0.0008     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0021  0.0034  0.0153  0.9754
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2309
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9946  0.0054
# pop2        0.0090  0.9910
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9992  0.0008  0.0000
# pop2        0.9997  0.0002  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9778  0.0222
# pop2        0.0163  0.9837
# Name: cytotype
#
# Simulation run completed.
# Generation: 2309
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.0007
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 92
# pr = 0.81955123235
# s  = 0.721914994674
# diff = 0.786726107709
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1928  0.0054  0.0005  0.0057
#       P1          0.7855  0.0124  0.0004  0.0019
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0005  0.0017  0.0147  0.9645
#       P1          0.0004  0.0014  0.0005  0.0117
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 9178
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9960  0.0040
# pop2        0.0086  0.9914
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2003  0.7997   0
# pop2        0.9855  0.0145   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9791  0.0209
# pop2        0.0161  0.9839
# Name: cytotype
#
# Simulation run completed.
# Generation: 9178
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.00069
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 93
# pr = 0.226933915027
# s  = 0.951878025891
# diff = 0.000961040064211
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9797  0.0151  0.0008  0.0056
#       P1          0.0011     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0014  0.0027  0.0152  0.9781
#       P1             0.0     0.0     0.0  0.0001
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2330
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9959  0.0041
# pop2        0.0065  0.9935
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9989  0.0011  0.0000
# pop2        0.9998  0.0001  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9822  0.0178
# pop2        0.0160  0.9840
# Name: cytotype
#
# Simulation run completed.
# Generation: 2330
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 94
# pr = 0.289414925398
# s  = 0.164491330866
# diff = 0.236041118567
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6653  0.0259  0.0016  0.0343
#       P1          0.2857  0.0097  0.0003  0.0037
#       P2             ---     ---     ---     ---
# T2    P0          0.0055  0.0048  0.0143  0.8881
#       P1          0.0018  0.0012  0.0011  0.0566
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 33891
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9866  0.0134
# pop2        0.0399  0.9601
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.7016  0.2984   0
# pop2        0.9383  0.0617   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9584  0.0416
# pop2        0.0173  0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 33891
# Elapsed Time (hours:minutes:seconds): 0:00:22
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 95
# pr = 0.275986269993
# s  = 0.0384453136958
# diff = 0.000525410683626
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9045  0.0464  0.0038  0.1452
#       P1          0.0007     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0398  0.0085  0.0138  0.8370
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9517  0.0483
# pop2        0.1490  0.8510
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9992  0.0008   0
# pop2        0.9998  0.0002   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9451  0.0549
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00068
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 96
# pr = 0.0832389200164
# s  = 0.693454726581
# diff = 0.000440741095159
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9754  0.0186  0.0010  0.0078
#       P1          0.0007     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0020  0.0033  0.0153  0.9756
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2498
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9947  0.0053
# pop2        0.0088  0.9912
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9993  0.0007  0.0000
# pop2        0.9997  0.0003  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9781  0.0219
# pop2        0.0163  0.9837
# Name: cytotype
#
# Simulation run completed.
# Generation: 2498
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 97
# pr = 0.463117194865
# s  = 0.529072794796
# diff = 0.543292790028
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3997  0.0104  0.0008  0.0089
#       P1          0.5731  0.0112  0.0004  0.0021
#       P2             ---     ---     ---     ---
# T2    P0          0.0011  0.0025  0.0145  0.9322
#       P1          0.0007  0.0013  0.0009  0.0403
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 16691
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9943  0.0057
# pop2        0.0121  0.9879
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4137  0.5863   0
# pop2        0.9564  0.0436   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9747  0.0253
# pop2        0.0165  0.9835
# Name: cytotype
#
# Simulation run completed.
# Generation: 16691
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 98
# pr = 0.947341469769
# s  = 0.354218463195
# diff = 0.827923599713
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1545  0.0067  0.0007  0.0129
#       P1          0.8143  0.0189  0.0008  0.0030
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0006  0.0023  0.0146  0.9591
#       P1          0.0006  0.0022  0.0004  0.0084
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 6113
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9944  0.0056
# pop2        0.0174  0.9826
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.1641  0.8359   0
# pop2        0.9874  0.0126   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9699  0.0301
# pop2        0.0166  0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 6113
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 99
# pr = 0.225519579649
# s  = 0.643105303833
# diff = 0.000931750265812
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9738  0.0194  0.0010  0.0085
#       P1          0.0011     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0022  0.0035  0.0153  0.9749
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2149
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9943  0.0057
# pop2        0.0095  0.9905
# Name: trait
#
# preference      P0      P1      P2
# population
# pop1        0.9989  0.0011  0.0000
# pop2        0.9998  0.0002  0.0001
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9771  0.0229
# pop2        0.0163  0.9837
# Name: cytotype
#
# Simulation run completed.
# Generation: 2149
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065

# %%
c = scenario['counter'][()]
diffs = np.array( [[x,y,z] for (x,y,z) in scenario['screening'][:c]] )    # convert lenght n array of 3-tuples to array of shape (n,3)
print '   pr      s       diff   '
print '--------------------------'
print diffs
# Out:
#    pr      s       diff
# --------------------------
# [[ 0.15784141  0.98174948  0.00072793]
#  [ 0.35697407  0.77765834  0.41325319]
#  [ 0.27522349  0.99282277  0.25436258]
#  [ 0.17295013  0.13668765  0.00058832]
#  [ 0.35688737  0.13715616  0.34450188]
#  [ 0.08956756  0.06139265  0.00022335]
#  [ 0.96543664  0.28573808  0.83237892]
#  [ 0.40246877  0.2558386   0.44485795]
#  [ 0.03602086  0.67618972  0.0002614 ]
#  [ 0.45470336  0.90065819  0.54816419]
#  [ 0.88994831  0.76220512  0.81340528]
#  [ 0.2774792   0.80004543  0.25739762]
#  [ 0.05354117  0.5679031   0.00030716]
#  [ 0.96022648  0.76936007  0.83632743]
#  [ 0.05373753  0.15462476  0.00021577]
#  [ 0.74576056  0.14578252  0.70960182]
#  [ 0.62343729  0.47824106  0.67773789]
#  [ 0.75304496  0.27885598  0.74164557]
#  [ 0.0040224   0.93897861  0.00011212]
#  [ 0.50697136  0.77676362  0.59743667]
#  [ 0.88788605  0.78258789  0.8128674 ]
#  [ 0.33694431  0.50629044  0.36851674]
#  [ 0.2382049   0.23054773  0.13513568]
#  [ 0.08562358  0.52826023  0.00041216]
#  [ 0.50798553  0.5857417   0.59128183]
#  [ 0.95332325  0.22152883  0.82404947]
#  [ 0.12333044  0.2412055   0.00048628]
#  [ 0.8314274   0.30289662  0.78059977]
#  [ 0.53888822  0.00005909 -0.00006694]
#  [ 0.87822211  0.40427017  0.80381918]
#  [ 0.38946763  0.67418414  0.45891514]
#  [ 0.99511659  0.49023646  0.84574431]
#  [ 0.94905216  0.57408112  0.83154041]
#  [ 0.02164947  0.10090575  0.00010541]
#  [ 0.57735896  0.35250539  0.63645053]
#  [ 0.33699638  0.76449519  0.37889385]
#  [ 0.05427551  0.36542237  0.00026921]
#  [ 0.07614199  0.97913587  0.00046545]
#  [ 0.42263195  0.43070838  0.48983482]
#  [ 0.03520295  0.51396841  0.00023139]
#  [ 0.81774533  0.08306345  0.61281359]
#  [ 0.94538075  0.62839103  0.83078903]
#  [ 0.524369    0.35851243  0.59232742]
#  [ 0.64056718  0.01472963 -0.00002403]
#  [ 0.99280757  0.66169059  0.84582782]
#  [ 0.03811946  0.41079822  0.00022439]
#  [ 0.89893401  0.8936137   0.81745064]
#  [ 0.24998342  0.99441671  0.00105317]
#  [ 0.95680273  0.03226743 -0.77366644]
#  [ 0.70364451  0.6643551   0.73210156]
#  [ 0.11337879  0.32408288  0.00047234]
#  [ 0.67030686  0.32576612  0.69881755]
#  [ 0.6640287   0.96285975  0.71610522]
#  [ 0.51398814  0.0001209  -0.0000632 ]
#  [ 0.46166441  0.01485645 -0.00003098]
#  [ 0.9778716   0.98810339  0.84239185]
#  [ 0.9526372   0.62448305  0.83309543]
#  [ 0.22293562  0.66986948  0.00092443]
#  [ 0.76435697  0.00529414 -0.0003208 ]
#  [ 0.80848205  0.15980557  0.74881637]
#  [ 0.30862159  0.18814346  0.2812292 ]
#  [ 0.39782736  0.90832114  0.47821286]
#  [ 0.00173932  0.5278762   0.00003914]
#  [ 0.74700963  0.23067799  0.73318547]
#  [ 0.10752457  0.24561805  0.00041873]
#  [ 0.31718868  0.11911158  0.26636785]
#  [ 0.8522644   0.39056507  0.79317671]
#  [ 0.44252282  0.09291679  0.41619208]
#  [ 0.99844849  0.87913126  0.84811634]
#  [ 0.84360707  0.96597135  0.79856008]
#  [ 0.51187372  0.53190547  0.59231651]
#  [ 0.04973735  0.27241203  0.00023515]
#  [ 0.43264818  0.73886919  0.51774478]
#  [ 0.52317882  0.935206    0.6162203 ]
#  [ 0.19694901  0.03284191  0.00020377]
#  [ 0.65221006  0.86005008  0.70741487]
#  [ 0.9814254   0.82567316  0.84296501]
#  [ 0.17579122  0.44674528  0.00072079]
#  [ 0.48579335  0.16720322  0.52218378]
#  [ 0.08514444  0.12273442  0.00028169]
#  [ 0.33362395  0.27170825  0.34266418]
#  [ 0.59629846  0.26808327  0.64247543]
#  [ 0.28536692  0.74329245  0.2747125 ]
#  [ 0.75770003  0.03547319 -0.79264075]
#  [ 0.86777496  0.55585724  0.80296499]
#  [ 0.62280101  0.11897337  0.61121416]
#  [ 0.22383282  0.26389435  0.00086153]
#  [ 0.32331145  0.54359949  0.34593379]
#  [ 0.91191179  0.88796008  0.821697  ]
#  [ 0.31134605  0.36598423  0.31265339]
#  [ 0.37822512  0.15153138  0.38363913]
#  [ 0.11397441  0.67794907  0.00054989]
#  [ 0.81955123  0.72191501  0.78672612]
#  [ 0.22693391  0.95187801  0.00096104]
#  [ 0.28941491  0.16449133  0.23604111]
#  [ 0.27598628  0.03844531  0.00052541]
#  [ 0.08323892  0.69345474  0.00044074]
#  [ 0.46311718  0.52907282  0.54329276]
#  [ 0.94734144  0.35421845  0.8279236 ]
#  [ 0.22551958  0.64310533  0.00093175]]

# %%
from matplotlib.mlab import griddata

X = diffs[:,0]
Y = diffs[:,1]
Z = diffs[:,2]

xi = linspace(min(X), max(X), 200)
#xi = linspace(-0.1,1.1,100)
yi = linspace(min(Y), max(Y), 200)
#yi = linspace(-0.1,1.1,100)
zi = griddata(X, Y, Z, xi, yi)
plt.contourf(xi, yi, zi, cmap=plt.cm.PRGn, vmin=-1., vmax=1.)
plt.clim(-1., 1.)
plt.colorbar() # draw colorbar
plt.xlim(0,1)
plt.ylim(0,1)
plt.xlabel('rejection probability')
plt.ylabel('selection coefficient')

# %%
len(diffs)
# Out:
# 100

# %%
rstore.close()
