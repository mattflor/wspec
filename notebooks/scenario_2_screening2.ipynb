# %% [markdown]
# # Scenario 2

# %%
import sys, types, time, os, inspect, shutil, pprint, cPickle, gzip, tarfile, pprint, datetime, pdb, copy
import numpy as np
import numpy.random as npr
import pandas as pd
from scipy.interpolate import griddata
from matplotlib import rc, font_manager
import matplotlib.pyplot as plt
from IPython.core.display import Image
# wspec moduls:
import core, storage, analytical
import visualization as viz
import utilities as utils
for mod in [core,storage,analytical,utils,viz]:     # reload the wspec modules in case the code has changed
    reload(mod)
    
#np.set_printoptions(precision=4, suppress=True, linewidth=100)
np.set_printoptions(suppress=True, linewidth=100)
npr.seed(94832)

# %% [markdown]
# ## 1. Scenario features
#
# * Two populations linked by migration
#
# * Initial state:
#
#     * Trait T1 adaptive and fixed in population 1, T2 in population 2
#
#     * Preference allele P0 (non-discriminating) fixed in both populations
#
# * Population 1 is uninfected, *Wolbachia* infection in population 2
#
# * Order of events:
#
#     1.  Secondary contact
#         $\rightarrow$  selection-migration equilibrium
#
#     2.  Introduction of a preference for T1 in population 1, P1 (T1), and of a preference for T2 in population 2, P2 (T2)
#         $\rightarrow$  new equilibrium
#
# <img src="https://docs.google.com/drawings/d/1PI65vCcdE8Yv5Sa5cS_NrZ3QZzjU8nMVnLLMJycal04/pub?w=691&h=577">

# %% [markdown]
# ## 2. Configuration
#
# To configure the simulation scenario, we need to specify gene loci, alleles, and parameters.
#
# ### 2.1 Loci and alleles
#
# Populations are treated as loci, as would be the cytotype. In numpy terms, each locus is represented by an array axis.
#
# We keep separate lists rather than a dictionary because we need to preserve the locus and allele orders.

# %%
LOCI = ['population', 'trait', 'preference', 'cytotype']
ALLELES = [['pop1', 'pop2'],
           ['T1', 'T2'],
           ['P0', 'P1', 'P2'],
           ['U', 'W']
          ]
print utils.loci2string(LOCI, ALLELES)
# Out:
# locus           alleles
# --------------------------
# population      pop1, pop2
# trait           T1, T2
# preference      P0, P1, P2
# cytotype        U, W

# %%
def popdiff(metapop):
    """
    Measure frequency differences between populations. This function returns a NxN matrix containing 
    values between 0 and L-1 where N is the number of populations and L is the number of loci.
    """
    n = metapop.n_pops
    d = np.zeros((n,n), float)
    for i in range(n):
        for j in range(i,n):
            for loc in metapop.loci[1:]:
                sums = metapop.get_sums(loc)
                d[i,j] += np.max( np.abs(sums[i] - sums[j]) )
                d[j,i] = d[i,j]
    return d

def popdiff2(current, initial):
    """
    Measure frequency differences between populations. This function returns a NxN matrix containing 
    values between 0 and L-1 where N is the number of populations and L is the number of loci.
    In this version, the change from the initial equilibrium is also taken into account.
    """
    n = current.n_pops
    d = np.zeros((n,n), float)
    for i in range(n):
        d[i] += np.sum( np.abs(current.freqs-initial.freqs) )
        for j in range(i,n):
            for loc in current.loci[1:]:
                sums = current.get_sums(loc)
                d[i,j] += np.max( np.abs(sums[i] - sums[j]) )
                d[j,i] = d[i,j]
    return d

def classify(diff, difftype=2, thresh=1e-4):
    if diff < thresh:
        return 'nothing'
    elif thresh < diff < 2:
        return 'runaway'
    else:
        return 'reinforcement'

# %% [markdown]
# ### 2.2 Parameters

# %%
sid = '2screen2'     # scenario id
PARAMETERS = {
    'lCI': (0.9, 'CI level'),                   # level of cytoplasmic incompatibility
    't': (0.9, 'transmission rate'),            # transmission of Wolbachia
    'f': (0.1, 'fecundity reduction'),          # Wolbachia-infected females are less fecund
    'm': (0.01, 'migration rate'),              # symmetric migration
    'pt': (0.9, 'transition probability'),       # probability of transition into another mating round
    'intro': (0.001, 'introduction frequency'), # introduction frequency of preference mutant allele
    'eq': (1e-6, 'equilibrium threshold'),      # equilibrium threshold (total frequency change)
    'nmin': (1000, 'min generation'),            # run at least `nmin` generations in search of equilibrium
    'nmax': (300000, 'max generation'),         # max number of generations to iterate for each stage of the simulation
    'step': (10, 'storage stepsize')            # store metapopulation state every `step` generations
}
print 'Parameters that are the same for all runs in the screening:\n'
print utils.params2string(PARAMETERS)
# Out:
# Parameters that are the same for all runs in the screening:
#
# parameter    value       description
# -----------------------------------------------
# eq           1e-06       equilibrium threshold
# f            0.1         fecundity reduction
# intro        0.001       introduction frequency
# lCI          0.9         CI level
# m            0.01        migration rate
# nmax         300000      max generation
# nmin         1000        min generation
# pt           0.9         transition probability
# step         10          storage stepsize
# t            0.9         transmission rate

# %% [markdown]
# We'll generate random transition and rejection probabilities, run the simulation, and check the outcome via the `popdiff` function the results of which are stored as well.

# %%
n = 11000

screening_dtype = np.dtype([('pr', 'f'), ('s', 'f'), ('diff', 'f')])
rstore = storage.RunStore('/extra/flor/data/notebook_data/scenario_{0}.h5'.format(sid))
# select existing scenario, initialize a new one if this fails:
try:
    scenario = rstore.select_scenario(sid, verbose=False)
    count = scenario['counter'][()]
    maxcount = len(scenario['screening'])
except:
    scenario = rstore.create_scenario(sid, labels=(LOCI,ALLELES))
    # scenario = rstore['current']['scenario']
    scenario.create_dataset('counter', (), 'i')    # integer counter for the screening runs; initialized at 0
    count = 0
    maxcount = max(n, 10)
    scenario.create_dataset('screening', (maxcount,), screening_dtype, maxshape=(None,))
    
if n >= maxcount:
    scenario['screening'].resize((n,))

# %%
for i in range(n):
    if i <= 10000:
        # we use a U-shaped beta function (low and high values more likely than intermediate ones)
        # to better explore the corners:
        s  = npr.beta(a=0.7, b=0.7)
        pr = npr.beta(a=0.7, b=0.7)
    elif 10000 < i <= 10500:
        s  = npr.random()                      # draw from a uniform distribution [0, 1)
        pr = 0.2 + 0.1*npr.random()            # draw from a uniform distribution [0.2, 0.3)
    else:
        s  = 0.1*npr.random()                  # draw from a uniform distribution [0, 0.1)
        pr = 0.3 + 0.7*npr.random()            # draw from a uniform distribution [0.3, 1.)
    
    PARAMETERS['s'] = (s, 'selection coefficient')        # selection advantage for adaptive trait
    PARAMETERS['pr'] = (pr, 'rejection probability')
    # For mating preference parameters, we use a different notation:
    trait_preferences = {                        # female mating preferences (rejection probabilities)
        'P0': {'baseline': 0.},
        'P1': {'baseline': pr, 'T1': 0.},
        'P2': {'baseline': pr, 'T2': 0.}
    }
    rid = 'pr{0:.12f}_s{1:.12f}'.format(pr,s)      # generate id of simulation run based on pr and pt values
    PARAMETERS = utils.add_preferences(PARAMETERS, trait_preferences)
    # make parameter names locally available:
    config = utils.configure_locals(LOCI, ALLELES, PARAMETERS)
    locals().update(config)

    max_figwidth = 15
    figheight = 5
    w = min( N_POPS*(N_LOCI-1), max_figwidth )    # figure width: npops*(nloci-1) but at most 15
    figsize = [w, figheight]
    show_progressbar = False          # BEWARE: enabling progressbar slows down the simulation significantly!
    
    overwrite_run = False
    data_available = False
    
    # select existing run, initialize a new one if this fails:
    try:   
        rstore.select_run(rid, verbose=False)
        data_available = True
        special_states = list( rstore.get_special_states()[::-1] )
    except:
        rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    # check whether parameters are identical:
    pars = rstore.get_parameters()
    if not utils.parameters_equal(pars, PARAMETERS, verbose=False):
        data_available = False
        if not overwrite_run:
            raise ValueError('parameter values differ from stored values; set `overwrite_run` to `True` in order to overwrite run')
        else:
            # print 'overwriting run...'
            rstore.remove_run(rid, sid)
            rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    
    if data_available:
        pass
    else:
        weights = {
            'migration': None,
            'viability_selection': None,
            'constant_reproduction': None,
            'dynamic_reproduction': []
        }
        mig = np.array(
            [[1-m,      m ],
             [  m,    1-m ]], float)
        M = core.MigrationWeight(
            name='migration',
            axes=['target', 'source'],
            config=config,
            arr=mig,
            m=m
        )
        weights['migration'] = M.extended()
        # print M
        
        vsarr = np.array(
            [[ 1+s,  1  ],
             [   1,  1+s]], float
        )
        VS = core.ViabilityWeight(
            name='viability selection',
            axes=['population','trait'],
            config=config,
            arr=vsarr,
            s=s
        )
        weights['viability_selection'] = VS.extended()
        # print VS
        
        TP = core.GeneralizedPreferenceWeight(
            name='trait preference',
            axes=['population', 'female_preference', 'male_trait'],
            pref_desc = trait_preferences,
            config=config,
            unstack_levels=[2],
            pt=pt
        )
        weights['dynamic_reproduction'].append( (TP, ['trait']) )
        # print TP
        
        CI = core.ReproductionWeight(
            name='cytoplasmic incompatibility',
            axes=['male_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            lCI=lCI
        )
        CI.set( np.array([[1, 1], [1-lCI, 1]], float ) )
        CI_ = CI.extended()
        # print CI
    
        T = core.ReproductionWeight(
            name='cytotype inheritance',
            axes=['female_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            t=t
        )
        T.set( np.array( [[1, 0], [1-t, t]], float ) )
        T_ = T.extended()
        # print T
        
        F = core.ReproductionWeight(
            name='fecundity reduction',
            axes=['female_cytotype'],
            config=config,
            f=f
        )
        F.set( np.array([1, 1-f], float) )
        F_ = F.extended()
        # print F
        
        IP = core.ReproductionWeight(
            name='preference inheritance',
            axes=['female_preference', 'male_preference', 'offspring_preference'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('preference')])
        IP.set( utils.nuclear_inheritance(n_alleles) )
        IP_ = IP.extended()
        # print IP
        
        IT = core.ReproductionWeight(
            name='trait inheritance',
            axes=['female_trait', 'male_trait', 'offspring_trait'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('trait')])
        IT.set( utils.nuclear_inheritance(n_alleles) )
        IT_ = IT.extended()
        # print IT
        
        R_ = CI_ * T_ * F_ * IP_ * IT_
        weights['constant_reproduction'] = R_
        
        # INITIAL STATE:
        starttime = time.time()                  # take time for timing report after simulation run
        startfreqs = np.zeros(FSHAPE)
        startfreqs[0,0,0,0] = 1.                   # pop1-T1-P0-U
        startfreqs[1,1,0,1] = 1.                   # pop2-T2-P0-W
        metapop = core.MetaPopulation(
            startfreqs,
            config=config,
            generation=0,
            name='metapopulation'
        )
        rstore.record_special_state(metapop.generation, 'start')
        rstore.dump_data(metapop)
        
        # MIGRATION-SELECTION EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        # make a copy of the metapopulation for later calculation of frequency differences:
        #initial = copy.copy(metapop)
        # frequency difference score before introduction of preference alleles:
        base_diff = popdiff(metapop)[0,1]
        
        # INTRODUCTION OF PREFERENCE MUTANTS:
        intro_allele = 'P1'
        metapop.introduce_allele('pop1', intro_allele, intro_freq=intro, advance_generation_count=False)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        intro_allele = 'P2'
        metapop.introduce_allele('pop2', intro_allele, intro_freq=intro, advance_generation_count=True)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        # FINAL EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        
        #diff = popdiff2(metapop, initial)[0,1]
        diff = popdiff(metapop)[0,1] - base_diff
        scenario['screening'][i] = (pr, s, diff)
        scenario['counter'][()] += 1
        
        print '\n^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^'
        print 'i = {0}\npr = {1}\ns  = {2}\ndiff = {3}\n'.format(i,pr,s,diff)
        print metapop
        print metapop.overview()
        print
        print utils.timing_report(starttime, metapop.generation)
        rstore.flush()
        
        # fig = viz.plot_overview(metapop, show_generation=False, figsize=figsize)
        # fig = rstore.plot_sums(figsize=[max_figwidth, figheight])
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10499
# pr = 0.262649059565
# s  = 0.188635123963
# diff = 0.185751912329
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.7250  0.0267  0.0016  0.0294
#       P1          0.2280  0.0074  0.0002  0.0026
#       P2             ---     ---     ---     ---
# T2    P0          0.0056  0.0049  0.0145  0.9028
#       P1          0.0014  0.0009  0.0009  0.0480
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 44436
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9872  0.0128
# pop2        0.0338  0.9662
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.7622  0.2378   0
# pop2        0.9483  0.0517   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9600  0.0400
# pop2        0.0172  0.9828
# Name: cytotype
#
# Simulation run completed.
# Generation: 44436
# Elapsed Time (hours:minutes:seconds): 0:00:27
# Time per generation (seconds): 0.00062
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10500
# pr = 0.289543963606
# s  = 0.715879749292
# diff = 0.283477191106
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6624  0.0130  0.0008  0.0068
#       P1          0.3144  0.0052  0.0002  0.0009
#       P2             ---     ---     ---     ---
# T2    P0          0.0014  0.0026  0.0146  0.9405
#       P1          0.0004  0.0006  0.0007  0.0354
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 45625
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9950  0.0050
# pop2        0.0087  0.9913
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6794  0.3206   0
# pop2        0.9628  0.0372   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9786  0.0214
# pop2        0.0163  0.9837
# Name: cytotype
#
# Simulation run completed.
# Generation: 45625
# Elapsed Time (hours:minutes:seconds): 0:00:28
# Time per generation (seconds): 0.00063
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10501
# pr = 0.986134755627
# s  = 0.033466122169
# diff = -0.781134030423
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6952  0.0443  0.0131  0.7263
#       P1          0.2450  0.0156  0.0046  0.2559
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4804
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.7394  0.2606   0
# pop2        0.7395  0.2605   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4804
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10502
# pr = 0.542321158761
# s  = 0.0364813889756
# diff = -0.797998715338
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.7367  0.0469  0.0139  0.7697
#       P1          0.2035  0.0130  0.0038  0.2126
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 12481
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.7836  0.2164   0
# pop2        0.7836  0.2164   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 12481
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10503
# pr = 0.941995009291
# s  = 0.0716384255073
# diff = -0.897217092831
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4308  0.0274  0.0081  0.4502
#       P1          0.5093  0.0324  0.0096  0.5321
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5067
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4583  0.5417   0
# pop2        0.4583  0.5417   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5067
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10504
# pr = 0.650562344953
# s  = 0.0763180246903
# diff = 0.50087918041
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3304  0.0180  0.0034  0.1517
#       P1          0.6168  0.0252  0.0010  0.0191
#       P2             ---     ---     ---     ---
# T2    P0          0.0020  0.0034  0.0121  0.7653
#       P1          0.0018  0.0024  0.0011  0.0464
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 7759
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9904  0.0096
# pop2        0.1751  0.8249
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3538  0.6462   0
# pop2        0.9325  0.0675   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9511  0.0489
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 7759
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10505
# pr = 0.666763513574
# s  = 0.00813423423118
# diff = -8.970206799e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8581  0.0515  0.0108  0.5728
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0826  0.0079  0.0069  0.4095
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5749
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9096  0.0904
# pop2        0.5836  0.4164
# Name: trait
#
# preference  P0  P1  P2
# population
# pop1         1   0   0
# pop2         1   0   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9406  0.0594
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5749
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10506
# pr = 0.336372977672
# s  = 0.0472662742865
# diff = 0.000848068803158
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9121  0.0455  0.0034  0.1191
#       P1          0.0010     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0332  0.0082  0.0142  0.8631
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9586  0.0414
# pop2        0.1225  0.8775
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9989  0.0011   0
# pop2        0.9998  0.0002   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9463  0.0537
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10507
# pr = 0.757026134784
# s  = 0.0437833843314
# diff = -0.83019137626
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6295  0.0401  0.0119  0.6578
#       P1          0.3106  0.0198  0.0059  0.3245
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5918
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6696  0.3304   0
# pop2        0.6697  0.3303   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5918
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10508
# pr = 0.864628063356
# s  = 0.0908055732739
# diff = 0.681293306596
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2146  0.0126  0.0027  0.1171
#       P1          0.7370  0.0279  0.0011  0.0128
#       P2             ---     ---     ---     ---
# T2    P0          0.0011  0.0030  0.0129  0.8289
#       P1          0.0012  0.0027  0.0007  0.0237
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5618
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9921  0.0079
# pop2        0.1337  0.8663
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2312  0.7688   0
# pop2        0.9617  0.0383   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9538  0.0462
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 5618
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10509
# pr = 0.483137128114
# s  = 0.0956329883727
# diff = 0.462386860087
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4147  0.0201  0.0022  0.0798
#       P1          0.5325  0.0207  0.0007  0.0112
#       P2             ---     ---     ---     ---
# T2    P0          0.0032  0.0040  0.0132  0.8282
#       P1          0.0025  0.0023  0.0013  0.0633
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 12392
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9880  0.0120
# pop2        0.0939  0.9061
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4420  0.5580   0
# pop2        0.9234  0.0766   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9530  0.0470
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 12392
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10510
# pr = 0.300360377153
# s  = 0.0148596451799
# diff = -4.16514426207e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8648  0.0491  0.0071  0.3469
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0767  0.0093  0.0106  0.6354
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3530
# EQ: True
#
# trait          T1     T2
# population
# pop1        0.914  0.086
# pop2        0.354  0.646
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9999  0.0001   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9416  0.0584
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3530
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10511
# pr = 0.555680122909
# s  = 0.0419022875081
# diff = -0.822854151889
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6884  0.0438  0.0130  0.7192
#       P1          0.2518  0.0160  0.0047  0.2630
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 10254
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.7322  0.2678   0
# pop2        0.7322  0.2678   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 10254
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10512
# pr = 0.712636646145
# s  = 0.0833886383351
# diff = 0.57514727292
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2848  0.0157  0.0030  0.1318
#       P1          0.6642  0.0262  0.0010  0.0160
#       P2             ---     ---     ---     ---
# T2    P0          0.0016  0.0032  0.0125  0.7950
#       P1          0.0016  0.0025  0.0010  0.0396
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6989
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9910  0.0090
# pop2        0.1518  0.8482
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3054  0.6946   0
# pop2        0.9423  0.0577   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9523  0.0477
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 6989
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10513
# pr = 0.839125932894
# s  = 0.0572947427463
# diff = -0.870001653842
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5200  0.0331  0.0098  0.5433
#       P1          0.4201  0.0267  0.0079  0.4389
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5228
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5531  0.4469   0
# pop2        0.5532  0.4468   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5228
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10514
# pr = 0.674439793909
# s  = 0.0845916086188
# diff = 0.564206071704
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3000  0.0162  0.0029  0.1225
#       P1          0.6488  0.0256  0.0010  0.0154
#       P2             ---     ---     ---     ---
# T2    P0          0.0018  0.0033  0.0127  0.8009
#       P1          0.0018  0.0025  0.0011  0.0436
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 7550
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9906  0.0094
# pop2        0.1418  0.8582
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3213  0.6787   0
# pop2        0.9390  0.0610   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9523  0.0477
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 7550
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10515
# pr = 0.344838942846
# s  = 0.0348765357476
# diff = 0.000626435309669
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9006  0.0468  0.0040  0.1594
#       P1          0.0008     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0431  0.0086  0.0136  0.8228
#       P1             0.0     0.0     0.0  0.0001
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2002
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9482  0.0518
# pop2        0.1634  0.8366
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9992  0.0008   0
# pop2        0.9998  0.0002   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9446  0.0554
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 2002
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10516
# pr = 0.78710845379
# s  = 0.0518650279917
# diff = -0.856239021989
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5643  0.0359  0.0106  0.5896
#       P1          0.3758  0.0239  0.0071  0.3926
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5555
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6003  0.3997   0
# pop2        0.6003  0.3997   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5555
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10517
# pr = 0.5422606099
# s  = 0.0267890798741
# diff = 0.000830761672825
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8897  0.0477  0.0048  0.2045
#       P1          0.0009     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0528  0.0089  0.0129  0.7777
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2326
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9383  0.0617
# pop2        0.2093  0.7907
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9990  0.0010   0
# pop2        0.9999  0.0001   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9434  0.0566
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 2326
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00067
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10518
# pr = 0.790291789562
# s  = 0.0915197897848
# diff = 0.651383896642
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2398  0.0135  0.0027  0.1116
#       P1          0.7112  0.0271  0.0011  0.0130
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0031  0.0130  0.8270
#       P1          0.0014  0.0027  0.0009  0.0308
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6236
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9916  0.0084
# pop2        0.1283  0.8717
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2577  0.7423   0
# pop2        0.9543  0.0457   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9536  0.0464
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 6236
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10519
# pr = 0.334380347193
# s  = 0.0941471803637
# diff = 0.272818889091
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6075  0.0278  0.0022  0.0682
#       P1          0.3350  0.0133  0.0005  0.0078
#       P2             ---     ---     ---     ---
# T2    P0          0.0069  0.0050  0.0136  0.8433
#       P1          0.0028  0.0016  0.0012  0.0632
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 26820
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9836  0.0164
# pop2        0.0786  0.9214
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6473  0.3527   0
# pop2        0.9273  0.0727   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9523  0.0477
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 26820
# Elapsed Time (hours:minutes:seconds): 0:00:17
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10520
# pr = 0.533386667554
# s  = 0.0438722215028
# diff = -0.0777119949344
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6059  0.0350  0.0083  0.4385
#       P1          0.3326  0.0166  0.0014  0.0529
#       P2             ---     ---     ---     ---
# T2    P0          0.0042  0.0030  0.0074  0.4535
#       P1          0.0016  0.0010  0.0007  0.0373
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 301001
# EQ: False
#
# trait           T1      T2
# population
# pop1        0.9902  0.0098
# pop2        0.5011  0.4989
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6482  0.3518   0
# pop2        0.9078  0.0922   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9443  0.0557
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 301001
# Elapsed Time (hours:minutes:seconds): 0:03:25
# Time per generation (seconds): 0.00068
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10521
# pr = 0.982661695542
# s  = 0.0774763257327
# diff = -0.905685285899
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4252  0.0271  0.0080  0.4442
#       P1          0.5150  0.0328  0.0097  0.5380
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5733
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4522  0.5478   0
# pop2        0.4523  0.5477   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5733
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10522
# pr = 0.49111718531
# s  = 0.0973224803425
# diff = 0.472947481866
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4062  0.0197  0.0022  0.0783
#       P1          0.5414  0.0209  0.0007  0.0111
#       P2             ---     ---     ---     ---
# T2    P0          0.0031  0.0039  0.0132  0.8306
#       P1          0.0025  0.0023  0.0013  0.0625
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 12036
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9882  0.0118
# pop2        0.0923  0.9077
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4329  0.5671   0
# pop2        0.9243  0.0757   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9532  0.0468
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 12036
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.00063
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10523
# pr = 0.820940949135
# s  = 0.072273042388
# diff = 0.421056450574
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3078  0.0180  0.0051  0.2562
#       P1          0.6397  0.0271  0.0014  0.0290
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0028  0.0105  0.6666
#       P1          0.0011  0.0021  0.0007  0.0305
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 25206
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9926  0.0074
# pop2        0.2916  0.7084
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3300  0.6700   0
# pop2        0.9384  0.0616   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9500  0.0500
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 25206
# Elapsed Time (hours:minutes:seconds): 0:00:16
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10524
# pr = 0.385827582106
# s  = 0.0366028285899
# diff = 0.000796384756268
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9025  0.0466  0.0039  0.1522
#       P1          0.0009     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0414  0.0085  0.0137  0.8299
#       P1             0.0     0.0     0.0  0.0001
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9501  0.0499
# pop2        0.1562  0.8438
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9990  0.0010   0
# pop2        0.9998  0.0002   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9448  0.0552
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10525
# pr = 0.575915630534
# s  = 0.0131398624607
# diff = -4.27112609829e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8608  0.0495  0.0077  0.3857
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0805  0.0092  0.0100  0.5966
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3678
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9103  0.0897
# pop2        0.3934  0.6066
# Name: trait
#
# preference  P0  P1  P2
# population
# pop1         1   0   0
# pop2         1   0   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9413  0.0587
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3678
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00063
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10526
# pr = 0.854109815924
# s  = 0.0602633940705
# diff = -0.876580983411
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4996  0.0318  0.0094  0.5221
#       P1          0.4405  0.0280  0.0083  0.4602
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5180
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5315  0.4685   0
# pop2        0.5315  0.4685   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5180
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10527
# pr = 0.456585337648
# s  = 0.0162877517323
# diff = -7.10531479031e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8684  0.0489  0.0067  0.3202
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0734  0.0093  0.0110  0.6621
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3460
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9173  0.0827
# pop2        0.3268  0.6732
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9999  0.0001   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9418  0.0582
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3460
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10528
# pr = 0.969638567803
# s  = 0.0252554489072
# diff = -0.71798157381
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.7817  0.0498  0.0147  0.8168
#       P1          0.1584  0.0101  0.0030  0.1655
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6008
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.8315  0.1685   0
# pop2        0.8315  0.1685   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 6008
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10529
# pr = 0.610753949857
# s  = 0.0284832636305
# diff = -0.746547972607
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.7894  0.0503  0.0149  0.8248
#       P1          0.1507  0.0096  0.0028  0.1575
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 14680
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.8397  0.1603   0
# pop2        0.8397  0.1603   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 14680
# Elapsed Time (hours:minutes:seconds): 0:00:09
# Time per generation (seconds): 0.00063
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10530
# pr = 0.767461927095
# s  = 0.059796289732
# diff = -0.87558445826
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5189  0.0330  0.0098  0.5422
#       P1          0.4212  0.0268  0.0079  0.4401
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5811
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference     P0     P1  P2
# population
# pop1        0.552  0.448   0
# pop2        0.552  0.448   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5811
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00063
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10531
# pr = 0.32279034381
# s  = 0.0219912856419
# diff = 9.85516211356e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8811  0.0482  0.0054  0.2447
#       P1          0.0002     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0613  0.0091  0.0122  0.7376
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3090
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9296  0.0704
# pop2        0.2501  0.7499
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9998  0.0002   0
# pop2        0.9999  0.0001   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9427  0.0573
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3090
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10532
# pr = 0.67572579009
# s  = 0.0582668837822
# diff = -0.872222134723
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5513  0.0351  0.0104  0.5760
#       P1          0.3888  0.0248  0.0073  0.4062
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6897
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5864  0.4136   0
# pop2        0.5864  0.4136   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 6897
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00063
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10533
# pr = 0.936371480939
# s  = 0.0851573670663
# diff = 0.674009221949
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2032  0.0124  0.0032  0.1437
#       P1          0.7481  0.0288  0.0013  0.0145
#       P2             ---     ---     ---     ---
# T2    P0          0.0009  0.0029  0.0125  0.8061
#       P1          0.0010  0.0027  0.0006  0.0182
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4990
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9925  0.0075
# pop2        0.1627  0.8373
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2194  0.7806   0
# pop2        0.9655  0.0345   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9533  0.0467
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 4990
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10534
# pr = 0.481756530021
# s  = 0.0641285464443
# diff = 0.344555334962
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4699  0.0245  0.0036  0.1573
#       P1          0.4723  0.0203  0.0009  0.0202
#       P2             ---     ---     ---     ---
# T2    P0          0.0041  0.0041  0.0120  0.7446
#       P1          0.0027  0.0020  0.0012  0.0602
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 13128
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9871  0.0129
# pop2        0.1820  0.8180
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5027  0.4973   0
# pop2        0.9174  0.0826   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9491  0.0509
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 13128
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.00063
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10535
# pr = 0.849411346169
# s  = 0.0811357093407
# diff = 0.603829705548
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2413  0.0142  0.0035  0.1622
#       P1          0.7086  0.0280  0.0012  0.0175
#       P2             ---     ---     ---     ---
# T2    P0          0.0012  0.0030  0.0122  0.7761
#       P1          0.0012  0.0025  0.0007  0.0266
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5447
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9922  0.0078
# pop2        0.1845  0.8155
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2596  0.7404   0
# pop2        0.9540  0.0460   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9523  0.0477
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 5447
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10536
# pr = 0.456572770982
# s  = 0.0789388236576
# diff = 0.397955754103
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4587  0.0228  0.0027  0.1043
#       P1          0.4855  0.0198  0.0008  0.0140
#       P2             ---     ---     ---     ---
# T2    P0          0.0041  0.0042  0.0128  0.7994
#       P1          0.0028  0.0022  0.0013  0.0647
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 14123
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9868  0.0132
# pop2        0.1218  0.8782
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4897  0.5103   0
# pop2        0.9192  0.0808   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9510  0.0490
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 14123
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.00063
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10537
# pr = 0.951510985514
# s  = 0.0505800550493
# diff = -0.852597082341
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5498  0.0350  0.0104  0.5745
#       P1          0.3903  0.0248  0.0074  0.4078
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4633
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.5848  0.4152   0
# pop2        0.5848  0.4152   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4633
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10538
# pr = 0.523228515456
# s  = 0.0171906693045
# diff = 1.58224876667e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8706  0.0488  0.0064  0.3053
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0713  0.0093  0.0113  0.6770
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3546
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9194  0.0806
# pop2        0.3117  0.6883
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9999  0.0001   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9419  0.0581
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3546
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10539
# pr = 0.909302120904
# s  = 0.00760026830988
# diff = -0.000100903389342
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8604  0.0520  0.0114  0.6044
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0802  0.0075  0.0064  0.3778
#       P1             0.0     0.0     ---     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6260
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9123  0.0877
# pop2        0.6158  0.3842
# Name: trait
#
# preference  P0  P1  P2
# population
# pop1         1   0   0
# pop2         1   0   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9405  0.0595
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 6260
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00063
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10540
# pr = 0.380339559946
# s  = 0.032707136733
# diff = 0.000660446055346
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8980  0.0470  0.0042  0.1694
#       P1          0.0008     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0454  0.0087  0.0134  0.8128
#       P1             0.0     0.0     0.0  0.0001
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9459  0.0541
# pop2        0.1736  0.8264
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9991  0.0009   0
# pop2        0.9998  0.0002   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9443  0.0557
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10541
# pr = 0.341744357853
# s  = 0.0704817445599
# diff = 0.242314127559
#
# population          pop1            pop2
# ...
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10986
# pr = 0.45265588463
# s  = 0.0935081283026
# diff = 0.42802513097
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4461  0.0214  0.0023  0.0797
#       P1          0.5001  0.0196  0.0007  0.0111
#       P2             ---     ---     ---     ---
# T2    P0          0.0037  0.0041  0.0132  0.8261
#       P1          0.0027  0.0022  0.0014  0.0656
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 13921
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9873  0.0127
# pop2        0.0938  0.9062
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4754  0.5246   0
# pop2        0.9213  0.0787   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9527  0.0473
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 13921
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.00064
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10987
# pr = 0.357018209992
# s  = 0.0239231213686
# diff = 0.000186189041355
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8848  0.0480  0.0051  0.2266
#       P1          0.0003     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0578  0.0090  0.0125  0.7557
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2943
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9331  0.0669
# pop2        0.2318  0.7682
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9997  0.0003   0
# pop2        0.9999  0.0001   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9430  0.0570
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 2943
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10988
# pr = 0.592630749717
# s  = 0.0096059219148
# diff = -7.08621855243e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8558  0.0506  0.0096  0.5010
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0850  0.0086  0.0081  0.4813
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4667
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9064  0.0936
# pop2        0.5106  0.4894
# Name: trait
#
# preference  P0  P1  P2
# population
# pop1         1   0   0
# pop2         1   0   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9408  0.0592
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4667
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10989
# pr = 0.385448682837
# s  = 0.0466589044934
# diff = 0.177038376289
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6392  0.0336  0.0043  0.1902
#       P1          0.2950  0.0136  0.0007  0.0182
#       P2             ---     ---     ---     ---
# T2    P0          0.0091  0.0050  0.0118  0.7238
#       P1          0.0032  0.0014  0.0010  0.0502
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 30749
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9814  0.0186
# pop2        0.2134  0.7866
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6869  0.3131   0
# pop2        0.9300  0.0700   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9464  0.0536
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 30749
# Elapsed Time (hours:minutes:seconds): 0:00:19
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10990
# pr = 0.348599888917
# s  = 0.0202951357158
# diff = 6.08041506545e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8776  0.0484  0.0057  0.2632
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0646  0.0092  0.0119  0.7191
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3247
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9262  0.0738
# pop2        0.2689  0.7311
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9998  0.0002   0
# pop2        1.0000  0.0000   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9424  0.0576
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3247
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10991
# pr = 0.855100936082
# s  = 0.0801418921708
# diff = 0.593168826354
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2433  0.0144  0.0036  0.1704
#       P1          0.7064  0.0281  0.0012  0.0183
#       P2             ---     ---     ---     ---
# T2    P0          0.0011  0.0029  0.0120  0.7674
#       P1          0.0012  0.0025  0.0007  0.0263
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5310
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9922  0.0078
# pop2        0.1936  0.8064
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2618  0.7382   0
# pop2        0.9535  0.0465   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9521  0.0479
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 5310
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10992
# pr = 0.72640626466
# s  = 0.0973906082191
# diff = 0.639247967754
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2593  0.0141  0.0024  0.0943
#       P1          0.6917  0.0260  0.0010  0.0118
#       P2             ---     ---     ---     ---
# T2    P0          0.0015  0.0032  0.0132  0.8394
#       P1          0.0016  0.0027  0.0010  0.0370
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6925
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9911  0.0089
# pop2        0.1095  0.8905
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.2781  0.7219   0
# pop2        0.9493  0.0507   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9540  0.0460
# pop2        0.0175  0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 6925
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10993
# pr = 0.86052834861
# s  = 0.0324198759772
# diff = -0.774642859316
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.7185  0.0457  0.0136  0.7507
#       P1          0.2217  0.0141  0.0042  0.2316
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5684
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.7642  0.2358   0
# pop2        0.7642  0.2358   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5684
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10994
# pr = 0.598981891646
# s  = 0.0117717851579
# diff = -5.29388935111e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8580  0.0498  0.0084  0.4234
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0831  0.0091  0.0093  0.5589
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3894
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9078  0.0922
# pop2        0.4317  0.5683
# Name: trait
#
# preference  P0  P1  P2
# population
# pop1         1   0   0
# pop2         1   0   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9411  0.0589
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3894
# Elapsed Time (hours:minutes:seconds): 0:00:02
# Time per generation (seconds): 0.00066
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10995
# pr = 0.659730477697
# s  = 0.0880428805344
# diff = 0.571840063016
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3018  0.0161  0.0027  0.1107
#       P1          0.6472  0.0252  0.0010  0.0142
#       P2             ---     ---     ---     ---
# T2    P0          0.0018  0.0034  0.0129  0.8126
#       P1          0.0018  0.0026  0.0011  0.0450
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 7805
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9904  0.0096
# pop2        0.1285  0.8715
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.3231  0.6769   0
# pop2        0.9388  0.0612   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9527  0.0473
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 7805
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10996
# pr = 0.916948678695
# s  = 0.063740212211
# diff = -0.883585309625
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4692  0.0299  0.0089  0.4903
#       P1          0.4709  0.0300  0.0089  0.4920
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4911
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.4991  0.5009   0
# pop2        0.4991  0.5009   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4911
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10997
# pr = 0.402363555748
# s  = 0.0271540857114
# diff = 0.000413514827416
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8903  0.0476  0.0047  0.2016
#       P1          0.0005     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0526  0.0089  0.0129  0.7806
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2671
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9385  0.0615
# pop2        0.2064  0.7936
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9994  0.0006   0
# pop2        0.9999  0.0001   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9435  0.0565
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 2671
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10998
# pr = 0.317625024245
# s  = 0.0486843473448
# diff = 0.000796617488263
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9132  0.0453  0.0033  0.1157
#       P1          0.0010     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0324  0.0081  0.0143  0.8665
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait           T1      T2
# population
# pop1        0.9595  0.0405
# pop2        0.1191  0.8809
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.9990  0.0010   0
# pop2        0.9998  0.0002   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9465  0.0535
# pop2        0.0176  0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:01
# Time per generation (seconds): 0.00065
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10999
# pr = 0.769030073093
# s  = 0.0426615351855
# diff = -0.825884931106
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6370  0.0406  0.0120  0.6656
#       P1          0.3031  0.0193  0.0057  0.3167
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5840
# EQ: True
#
# trait       T1  T2
# population
# pop1         1   0
# pop2         1   0
# Name: trait
#
# preference      P0      P1  P2
# population
# pop1        0.6776  0.3224   0
# pop2        0.6776  0.3224   0
# Name: preference
#
# cytotype         U       W
# population
# pop1        0.9401  0.0599
# pop2        0.0177  0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5840
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.00064

# %%
c = scenario['counter'][()]
diffs = np.array( [[x,y,z] for (x,y,z) in scenario['screening'][:c]] )    # convert lenght n array of 3-tuples to array of shape (n,3)
print '   pr      s       diff   '
print '--------------------------'
print diffs
# Out:
#    pr      s       diff
# --------------------------
# [[ 0.15784141  0.98174948  0.00072793]
#  [ 0.35697407  0.77765834  0.41325319]
#  [ 0.27522349  0.99282277  0.25436258]
#  ...,
#  [ 0.40236357  0.02715409  0.00041351]
#  [ 0.31762502  0.04868435  0.00079662]
#  [ 0.76903009  0.04266154 -0.82588494]]

# %% [markdown]
# We use a custom colormap which changes from dark to light red, then from light to dark blue, and which has a small segment of white where red and blue touch each other.

# %%
from matplotlib.colors import LinearSegmentedColormap, hex2color

rd = hex2color('#960F27')   # dark red
rl = hex2color('#FBE6DA')   # light red
bl = hex2color('#DEEBF2')   # light blue
bd = hex2color('#15508D')   # dark blue

cdict = {'red':   [(0.,    rd[0], rd[0]),
                   (0.495, rl[0],    1.),
                   (0.505,    1., bl[0]),
                   (1.,    bd[0], bd[0])],
         'green': [(0.,    rd[1], rd[1]),
                   (0.495, rl[1],    1.),
                   (0.505,    1., bl[1]),
                   (1.,    bd[1], bd[1])],
         'blue':  [(0.,    rd[2], rd[2]),
                   (0.495, rl[2],    1.),
                   (0.505,    1., bl[2]),
                   (1.,    bd[2], bd[2])]}
mycmap = LinearSegmentedColormap('MyCmap', cdict)

# %%
# set up figure environment:
fig_width_pt = 500.0                    # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height =fig_width *0.75             # height in inches
fig_size = [fig_width,fig_height]
params = {'backend': 'ps',
          'text.usetex': True,
          'text.family': 'sans-serif',
          'text.latex.preamble': [r"\usepackage{mathtools}"],   # we need this for the \mathmakebox command
          'axes.labelsize': 10,
          'text.fontsize': 12,
          'legend.fontsize': 10,
          'xtick.labelsize': 10,
          'ytick.labelsize': 10,
          'figure.figsize': fig_size}
plt.rcParams.update(params)
ticks_font = font_manager.FontProperties(
    family='Helvetica',
    style='normal',
    size=10,
    weight='normal',
    stretch='normal')

# actual data:
X = diffs[:,0]
Y = diffs[:,1]
Z = diffs[:,2]

xmin, xmax = 0., 1.
ymin, ymax = 0., 1.

# generate griddata for contour plot:
numspaces = int(math.sqrt(n))
xi = linspace(xmin, xmax, numspaces)
yi = linspace(ymin, ymax, numspaces)
zi = griddata((X, Y), Z, (xi[None,:], yi[:,None]), method='nearest')

figure(1, figsize=fig_size)
plt.imshow(zi, extent=(xmin,xmax,ymin,ymax), 
    cmap=mycmap, 
    norm = matplotlib.colors.Normalize(vmin = -1.0, vmax = 1.0, clip = False), 
    vmin=-1., vmax=1., 
    origin='lower', 
    aspect='auto', 
    interpolation=None)  # use default interpolation
plt.clim(-1., 1.)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
ax = gca()
ax.grid(False)
ax.set_aspect(1.)

# add a colorbar:
cbar = plt.colorbar(ticks=[-1., -0.75, -0.5, -0.25, -0.01, 0.01, 0.25, 0.5, 0.75, 1.])
cax = cbar.ax
cax.set_yticklabels(['--1.0', '--0.75', '--0.5', '--0.25', '0.0', '', '0.25', '0.5', '0.75', '1.0'])
cax.set_ylabel(r'$\xleftarrow{\mathmakebox[8em]{\textstyle\text{decreasing}}}$ {\large Divergence} $\xrightarrow{\mathmakebox[8em]{\textstyle\text{increasing}}}$')
plt.setp(cax.yaxis.get_ticklines(minor=False), markersize=0)

# uncomment the following line to show screening data points:
#plt.scatter(X, Y, marker='o', color='k', alpha=0.2, s=0.5)

plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
ax.xaxis.labelpad = 17
ax.yaxis.labelpad = 17
ax.set_xticklabels(ax.get_xticks(), ticks_font)
ax.set_yticklabels(ax.get_yticks(), ticks_font)
plt.xlabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{weak}}}$ {\large Mating preference} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{strong}}}$',
    multialignment='left')
plt.ylabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{weak}}}$ {\large Viability selection} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{strong}}}$',
    multialignment='center')
plt.text(0.13, 0.5, r'No spread of\\mating preferences', color='0.4', size=12, ha='center', va='center', multialignment='center', rotation='vertical')
plt.text(0.63, 0.55, r'\textbf{Reinforcement}', color='w', size=14, ha='center', va='center')
plt.text(0.99, 0.03, r'\textbf{Runaway}', color='w', size=14, ha='right', va='bottom')
plt.text(0., -0.05, r'Rejection probability', ha='left', va='top')
plt.text(-0.1, 0., r'Selection coefficient', ha='left', va='bottom', rotation='vertical')
plt.savefig('images/Screening_viabilityselection_vs_preferencestrength.pdf')

# %%
len(diffs)
# Out:
# 11000

# %%
rstore.close()
