# %% [markdown]
# # Scenario 2

# %%
import sys, types, time, os, inspect, shutil, pprint, cPickle, gzip, tarfile, pprint, datetime, pdb, copy
import numpy as np
import numpy.random as npr
import pandas as pd
from matplotlib.mlab import griddata
from matplotlib import rc, font_manager
import matplotlib.pyplot as plt
from IPython.core.display import Image
# wspec moduls:
import core, storage, analytical
import visualization as viz
import utilities as utils
for mod in [core,storage,analytical,utils,viz]:     # reload the wspec modules in case the code has changed
    reload(mod)
    
#np.set_printoptions(precision=4, suppress=True, linewidth=100)
np.set_printoptions(suppress=True, linewidth=100)
npr.seed(94832)

# %% [markdown]
# ## 1. Scenario features
#
# * Two populations linked by migration
#
# * Initial state:
#
#     * Trait T1 adaptive and fixed in population 1, T2 in population 2
#
#     * Preference allele P0 (non-discriminating) fixed in both populations
#
# * Population 1 is uninfected, *Wolbachia* infection in population 2
#
# * Order of events:
#
#     1.  Secondary contact
#         $\rightarrow$  selection-migration equilibrium
#
#     2.  Introduction of a preference for T1 in population 1, P1 (T1), and of a preference for T2 in population 2, P2 (T2)
#         $\rightarrow$  new equilibrium
#
# <img src="https://docs.google.com/drawings/d/1PI65vCcdE8Yv5Sa5cS_NrZ3QZzjU8nMVnLLMJycal04/pub?w=691&h=577">

# %% [markdown]
# ## 2. Configuration
#
# To configure the simulation scenario, we need to specify gene loci, alleles, and parameters.
#
# ### 2.1 Loci and alleles
#
# Populations are treated as loci, as would be the cytotype. In numpy terms, each locus is represented by an array axis.
#
# We keep separate lists rather than a dictionary because we need to preserve the locus and allele orders.

# %%
LOCI = ['population', 'trait', 'preference', 'cytotype']
ALLELES = [['pop1', 'pop2'],
           ['T1', 'T2'],
           ['P0', 'P1', 'P2'],
           ['U', 'W']
          ]
print utils.loci2string(LOCI, ALLELES)
# Out:
# locus           alleles
# --------------------------
# population      pop1, pop2
# trait           T1, T2
# preference      P0, P1, P2
# cytotype        U, W

# %%
def popdiff(metapop):
    """
    Measure frequency differences between populations. This function returns a NxN matrix containing 
    values between 0 and L-1 where N is the number of populations and L is the number of loci.
    """
    n = metapop.n_pops
    d = np.zeros((n,n), float)
    for i in range(n):
        for j in range(i,n):
            for loc in metapop.loci[1:]:
                sums = metapop.get_sums(loc)
                d[i,j] += np.max( np.abs(sums[i] - sums[j]) )
                d[j,i] = d[i,j]
    return d

# %% [markdown]
# ### 2.2 Parameters

# %% [markdown]
# Beware of the `step` parameter as the size of the HDF5 database is strongly affected by its value. If we are not interested in every single dynamical process but rather in the final outcome then might set `step = 1e6` which will only record special states like initial frequencies, equilibria, or when new alleles have been introduced.

# %%
sid = '2screen1b'     # scenario id
PARAMETERS = {
    'lCI': (0.9, 'CI level'),                   # level of cytoplasmic incompatibility
    't': (0.87, 'transmission rate'),            # transmission of Wolbachia
    'f': (0., 'fecundity reduction'),          # Wolbachia-infected females are less fecund
    'm': (0.006, 'migration rate'),              # symmetric migration
    's': (0.1, 'selection coefficient'),        # selection advantage for adaptive trait
    'intro': (0.01, 'introduction frequency'), # introduction frequency of preference mutant allele
    'eq': (1e-6, 'equilibrium threshold'),      # equilibrium threshold (total frequency change)
    'nmin': (1000, 'min generation'),            # run at least `nmin` generations in search of equilibrium
    'nmax': (300000, 'max generation'),         # max number of generations to iterate for each stage of the simulation
    'step': (20, 'storage stepsize')            # store metapopulation state every `step` generations
}
config = utils.configure_locals(LOCI, ALLELES, PARAMETERS)
locals().update(config)
print 'Parameters that are the same for all runs in the screening:\n'
print utils.params2string(PARAMETERS)
# Out:
# Parameters that are the same for all runs in the screening:
#
# parameter    value       description
# -----------------------------------------------
# eq           1e-06       equilibrium threshold
# f            0.0         fecundity reduction
# intro        0.01        introduction frequency
# lCI          0.9         CI level
# m            0.006       migration rate
# nmax         300000      max generation
# nmin         1000        min generation
# s            0.1         selection coefficient
# step         20          storage stepsize
# t            0.87        transmission rate

# %% [markdown]
# Critical migration rate for these Wolbachia parameters:

# %%
print 'm_crit =', np.min(analytical.mcrit_IMA(f, lCI, s, t), analytical.mcrit_UMA(f, lCI, s, t))
# Out:
# m_crit = 0.006613766428

# %% [markdown]
# We'll generate random transition and rejection probabilities, run the simulation, and check the outcome via the `popdiff` function the results of which are stored as well.

# %%
n = 2000

screening_dtype = np.dtype([('pr', 'f'), ('pt', 'f'), ('diff', 'f')])
#rstore = storage.RunStore('/extra/flor/data/notebook_data/scenario_{0}.h5'.format(sid))
rstore = storage.RunStore('data/scenario_{0}.h5'.format(sid))
# select existing scenario, initialize a new one if this fails:
try:
    scenario = rstore.select_scenario(sid, verbose=False)
    count = scenario['counter'][()]
    maxcount = len(scenario['screening'])
except:
    scenario = rstore.create_scenario(sid, labels=(LOCI,ALLELES))
    # scenario = rstore['current']['scenario']
    scenario.create_dataset('counter', (), 'i')    # integer counter for the screening runs; initialized at 0
    count = 0
    maxcount = max(n, 10)
    scenario.create_dataset('screening', (maxcount,), screening_dtype, maxshape=(None,))
    
if n >= maxcount:
    scenario['screening'].resize((n,))

# %% [markdown]
# The actual screening:

# %%
for i in range(n):
    #pr = 0.8 + 0.2*npr.random()                     # draw from a uniform distribution over [0,1)
    #pt = 0.8 + 0.2*npr.random()                     # draw from a uniform distribution over [0,1)
    # we use a U-shaped beta function (low and high values more likely than intermediate ones)
    # to better explore the corners:
    pr = npr.beta(a=0.7, b=0.7)
    pt = npr.beta(a=0.7, b=0.7)
    
    PARAMETERS['pt'] = (pt, 'transition probability')       # probability of transition into another mating round
    PARAMETERS['pr'] = (pr, 'rejection probability')
    # For mating preference parameters, we use a different notation:
    trait_preferences = {                        # female mating preferences (rejection probabilities)
        'P0': {'baseline': 0.},
        'P1': {'baseline': pr, 'T1': 0.},
        'P2': {'baseline': pr, 'T2': 0.}
    }
    rid = 'pr{0:.12f}_pt{1:.12f}'.format(pr,pt)      # generate id of simulation run based on pr and pt values
    PARAMETERS = utils.add_preferences(PARAMETERS, trait_preferences)
    # make parameter names locally available:
    config = utils.configure_locals(LOCI, ALLELES, PARAMETERS)
    locals().update(config)

    max_figwidth = 15
    figheight = 5
    w = min( N_POPS*(N_LOCI-1), max_figwidth )    # figure width: npops*(nloci-1) but at most 15
    figsize = [w, figheight]
    show_progressbar = False          # BEWARE: enabling progressbar slows down the simulation significantly!
    
    overwrite_run = False
    data_available = False
    
    # select existing run, initialize a new one if this fails:
    try:   
        rstore.select_run(rid, verbose=False)
        data_available = True
        special_states = list( rstore.get_special_states()[::-1] )
    except:
        rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    # check whether parameters are identical:
    pars = rstore.get_parameters()
    if not utils.parameters_equal(pars, PARAMETERS, verbose=False):
        data_available = False
        if not overwrite_run:
            raise ValueError('parameter values differ from stored values; set `overwrite_run` to `True` in order to overwrite run')
        else:
            # print 'overwriting run...'
            rstore.remove_run(rid, sid)
            rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    
    if data_available:
        pass
        #specialstates = rstore.get_special_states()
        #generation = rstore.get_last_generation()
        #print i, pr, pt, generation, specialstates
    else:
        weights = {
            'migration': None,
            'viability_selection': None,
            'constant_reproduction': None,
            'dynamic_reproduction': []
        }
        mig = np.array(
            [[1-m,      m ],
             [  m,    1-m ]], float)
        M = core.MigrationWeight(
            name='migration',
            axes=['target', 'source'],
            config=config,
            arr=mig,
            m=m
        )
        weights['migration'] = M.extended()
        # print M
        
        vsarr = np.array(
            [[ 1+s,  1  ],
             [   1,  1+s]], float
        )
        VS = core.ViabilityWeight(
            name='viability selection',
            axes=['population','trait'],
            config=config,
            arr=vsarr,
            s=s
        )
        weights['viability_selection'] = VS.extended()
        # print VS
        
        TP = core.GeneralizedPreferenceWeight(
            name='trait preference',
            axes=['population', 'female_preference', 'male_trait'],
            pref_desc = trait_preferences,
            config=config,
            unstack_levels=[2],
            pt=pt
        )
        weights['dynamic_reproduction'].append( (TP, ['trait']) )
        # print TP
        
        CI = core.ReproductionWeight(
            name='cytoplasmic incompatibility',
            axes=['male_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            lCI=lCI
        )
        CI.set( np.array([[1, 1], [1-lCI, 1]], float ) )
        CI_ = CI.extended()
        # print CI
    
        T = core.ReproductionWeight(
            name='cytotype inheritance',
            axes=['female_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            t=t
        )
        T.set( np.array( [[1, 0], [1-t, t]], float ) )
        T_ = T.extended()
        # print T
        
        F = core.ReproductionWeight(
            name='fecundity reduction',
            axes=['female_cytotype'],
            config=config,
            f=f
        )
        F.set( np.array([1, 1-f], float) )
        F_ = F.extended()
        # print F
        
        IP = core.ReproductionWeight(
            name='preference inheritance',
            axes=['female_preference', 'male_preference', 'offspring_preference'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('preference')])
        IP.set( utils.nuclear_inheritance(n_alleles) )
        IP_ = IP.extended()
        # print IP
        
        IT = core.ReproductionWeight(
            name='trait inheritance',
            axes=['female_trait', 'male_trait', 'offspring_trait'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('trait')])
        IT.set( utils.nuclear_inheritance(n_alleles) )
        IT_ = IT.extended()
        # print IT
        
        R_ = CI_ * T_ * F_ * IP_ * IT_
        weights['constant_reproduction'] = R_
        
        # INITIAL STATE:
        starttime = time.time()                  # take time for timing report after simulation run
        startfreqs = np.zeros(FSHAPE)
        startfreqs[0,0,0,0] = 1.                   # pop1-T1-P0-U
        startfreqs[1,1,0,1] = 1.                   # pop2-T2-P0-W
        metapop = core.MetaPopulation(
            startfreqs,
            config=config,
            generation=0,
            name='metapopulation'
        )
        rstore.record_special_state(metapop.generation, 'start')
        rstore.dump_data(metapop)
        
        # MIGRATION-SELECTION EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        # make a copy of the metapopulation for later calculation of frequency differences:
        #initial = copy.copy(metapop)
        # frequency difference score before introduction of preference alleles:
        base_diff = popdiff(metapop)[0,1]
        
        # INTRODUCTION OF PREFERENCE MUTANTS:
        intro_allele = 'P1'
        metapop.introduce_allele('pop1', intro_allele, intro_freq=intro, advance_generation_count=False)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        intro_allele = 'P2'
        metapop.introduce_allele('pop2', intro_allele, intro_freq=intro, advance_generation_count=True)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        # FINAL EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        
        #diff = popdiff2(metapop, initial)[0,1]
        diff = popdiff(metapop)[0,1] - base_diff
        scenario['screening'][i] = (pr, pt, diff)
        scenario['counter'][()] += 1
        
        print '\n^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^'
        print 'i = {0}\npr = {1}\npt = {2}\ndiff = {3}\n'.format(i,pr,pt,diff)
        print metapop
        print metapop.overview()
        print
        print utils.timing_report(starttime, metapop.generation)
        rstore.flush()
        
        # fig = viz.plot_overview(metapop, show_generation=False, figsize=figsize)
        # fig = rstore.plot_sums(figsize=[max_figwidth, figheight])
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 0
# pr = 0.981749445848
# pt = 0.157841410405
# diff = 3.39492419716e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2045
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2045
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 1
# pr = 0.777658319275
# pt = 0.356974072872
# diff = 6.14206121123e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2718
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2718
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 2
# pr = 0.992822763151
# pt = 0.275223479263
# diff = 4.31019764051e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2273
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2273
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 3
# pr = 0.136687657426
# pt = 0.17295013007
# diff = 9.59995131724e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 3624
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3624
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 4
# pr = 0.137156153107
# pt = 0.356887371962
# diff = 0.000112654136864
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1          0.0001     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 4003
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 4003
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 5
# pr = 0.0613926488664
# pt = 0.0895675679392
# diff = 0.000111018797519
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9381  0.0442  0.0016  0.0346
#       P1          0.0001     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     0.0     0.0     0.0
# Name: metapopulation
# Generation: 4082
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 4082
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 6
# pr = 0.285738089405
# pt = 0.965436614764
# diff = 0.223606521579
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6040  0.0289  0.0016  0.0405
#       P1          0.3396  0.0151  0.0004  0.0077
#       P2             ---     ---     ---     ---
# T2    P0          0.0054  0.0033  0.0175  0.8140
#       P1          0.0024  0.0012  0.0026  0.1157
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 33283
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9876 0.0124
# pop2       0.0501 0.9499
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.6417 0.3583     ---
# pop2       0.8736 0.1264     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9514 0.0486
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 33283
# Elapsed Time (hours:minutes:seconds): 0:00:54
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 7
# pr = 0.255838599193
# pt = 0.402468774736
# diff = 0.000104221174042
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 3742
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3742
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 8
# pr = 0.676189748745
# pt = 0.0360208656611
# diff = 3.6289202912e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2123
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2123
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 9
# pr = 0.90065817264
# pt = 0.454703367124
# diff = 7.89968269752e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3092
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3092
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 10
# pr = 0.762205144137
# pt = 0.889948304647
# diff = 0.670730523538
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2975  0.0151  0.0014  0.0387
#       P1          0.6539  0.0268  0.0004  0.0032
#       P2             ---     ---     ---     ---
# T2    P0          0.0014  0.0024  0.0196  0.9210
#       P1          0.0013  0.0018  0.0006  0.0151
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 9040
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9932 0.0068
# pop2       0.0437 0.9563
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.3163 0.6837     ---
# pop2       0.9806 0.0194     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9540 0.0460
# pop2       0.0220 0.9780
# Name: cytotype
#
# Simulation run completed.
# Generation: 9040
# Elapsed Time (hours:minutes:seconds): 0:00:14
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 11
# pr = 0.800045450487
# pt = 0.277479204131
# diff = 4.96177149618e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2443
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2443
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 12
# pr = 0.567903128762
# pt = 0.0535411716733
# diff = 4.18462503202e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2273
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2273
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 13
# pr = 0.769360089924
# pt = 0.960226493659
# diff = 0.582639899437
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2779  0.0147  0.0026  0.0945
#       P1          0.6727  0.0285  0.0008  0.0137
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0012  0.0021  0.0176  0.8260
#       P1          0.0012  0.0018  0.0012  0.0435
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 7017
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9938 0.0062
# pop2       0.1117 0.8883
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2959 0.7041     0.0
# pop2       0.9408 0.0592     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9530 0.0470
# pop2       0.0222 0.9778
# Name: cytotype
#
# Simulation run completed.
# Generation: 7017
# Elapsed Time (hours:minutes:seconds): 0:00:11
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 14
# pr = 0.154624761285
# pt = 0.0537375274618
# diff = 8.36830733995e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 3333
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3333
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 15
# pr = 0.145782516551
# pt = 0.745760533921
# diff = 0.000189935825498
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9381  0.0442  0.0016  0.0346
#       P1          0.0002     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 5725
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 5725
# Elapsed Time (hours:minutes:seconds): 0:00:09
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 16
# pr = 0.478241060005
# pt = 0.623437260168
# diff = 0.000185460892999
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9381  0.0442  0.0016  0.0346
#       P1          0.0002     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5190
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 5190
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 17
# pr = 0.278855985233
# pt = 0.753044991307
# diff = 0.000266359965108
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9380  0.0442  0.0016  0.0346
#       P1          0.0003     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6695
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9997  0.0003     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 6695
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 18
# pr = 0.938978623335
# pt = 0.00402239531325
# diff = 1.13688943315e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9383  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0017
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 19
# pr = 0.776763606561
# pt = 0.506971387005
# diff = 0.000103829710099
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3622
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3622
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0017
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 20
# pr = 0.782587858046
# pt = 0.887886060275
# diff = 0.683238642228
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2875  0.0147  0.0014  0.0383
#       P1          0.6641  0.0271  0.0004  0.0031
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0024  0.0196  0.9227
#       P1          0.0012  0.0018  0.0006  0.0139
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 8767
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9933 0.0067
# pop2       0.0433 0.9567
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.3058 0.6942     ---
# pop2       0.9820 0.0180     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9541 0.0459
# pop2       0.0220 0.9780
# Name: cytotype
#
# Simulation run completed.
# Generation: 8767
# Elapsed Time (hours:minutes:seconds): 0:00:14
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 21
# pr = 0.506290465522
# pt = 0.33694430617
# diff = 7.2389348708e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2996
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2996
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0017
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 22
# pr = 0.230547731424
# pt = 0.238204892805
# diff = 8.58508200119e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 3353
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3353
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0017
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 23
# pr = 0.528260247534
# pt = 0.0856235754189
# diff = 4.59085855735e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2376
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2376
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 24
# pr = 0.58574167536
# pt = 0.507985560579
# diff = 0.000111061381326
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3795
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3795
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 25
# pr = 0.221528825834
# pt = 0.953323250057
# diff = 0.0426375828221
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.8795  0.0415  0.0016  0.0349
#       P1          0.0598  0.0027     0.0  0.0009
#       P2             ---     ---     ---     ---
# T2    P0          0.0111  0.0046  0.0200  0.9230
#       P1          0.0006  0.0002  0.0004  0.0191
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 109902
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9835 0.0165
# pop2       0.0375 0.9625
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.9366 0.0634     ---
# pop2       0.9795 0.0205     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9510 0.0490
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 109902
# Elapsed Time (hours:minutes:seconds): 0:03:06
# Time per generation (seconds): 0.0017
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 26
# pr = 0.241205498909
# pt = 0.123330444219
# diff = 7.40597225402e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 3083
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3083
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0017
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 27
# pr = 0.302896617928
# pt = 0.831427372511
# diff = 0.000531790732021
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9377  0.0442  0.0016  0.0346
#       P1          0.0005     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 10253
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9994  0.0006     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 10253
# Elapsed Time (hours:minutes:seconds): 0:00:16
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 28
# pr = 5.90887587074e-05
# pt = 0.538888229619
# diff = 6.90910368126e-05
#
# population          pop1            pop2
# cytotype               U       W       U      W
# trait preference
# T1    P0          0.9289  0.0438  0.0016 0.0342
#       P1          0.0067  0.0003     0.0 0.0002
#       P2          0.0027  0.0001     0.0 0.0001
# T2    P0          0.0125  0.0048  0.0202 0.9340
#       P1             0.0     0.0  0.0001 0.0066
#       P2             0.0     0.0     0.0 0.0027
# Name: metapopulation
# Generation: 2240
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0     P1     P2
# population
# pop1       0.9901 0.0071 0.0028
# pop2       0.9901 0.0070 0.0029
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2240
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0017
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 29
# pr = 0.404270183757
# pt = 0.87822212167
# diff = 0.209784249611
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.7298  0.0346  0.0016  0.0355
#       P1          0.2135  0.0093  0.0001  0.0014
#       P2             ---     ---     ---     ---
# T2    P0          0.0068  0.0040  0.0199  0.9250
#       P1          0.0015  0.0007  0.0004  0.0161
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 45955
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9871 0.0129
# pop2       0.0386 0.9614
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.7751 0.2249     ---
# pop2       0.9820 0.0180     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9515 0.0485
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 45955
# Elapsed Time (hours:minutes:seconds): 0:01:14
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 30
# pr = 0.674184146832
# pt = 0.389467629465
# diff = 7.20258300753e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2968
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2968
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 31
# pr = 0.490236470622
# pt = 0.995116616416
# diff = -0.97341522904
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5369  0.0443  0.0129  0.5682
#       P1          0.3870  0.0319  0.0093  0.4095
#       P2             0.0     0.0     0.0     0.0
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5986
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     0.0
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.5811 0.4189     0.0
# pop2       0.5812 0.4188     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9239 0.0761
# pop2       0.0222 0.9778
# Name: cytotype
#
# Simulation run completed.
# Generation: 5986
# Elapsed Time (hours:minutes:seconds): 0:00:09
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 32
# pr = 0.574081138924
# pt = 0.949052169581
# diff = 0.521206698351
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3749  0.0187  0.0017  0.0524
#       P1          0.5741  0.0244  0.0005  0.0073
#       P2             ---     ---     ---     ---
# T2    P0          0.0020  0.0025  0.0184  0.8613
#       P1          0.0017  0.0017  0.0015  0.0568
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 11111
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9920 0.0080
# pop2       0.0620 0.9380
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.3982 0.6018     ---
# pop2       0.9339 0.0661     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9527 0.0473
# pop2       0.0222 0.9778
# Name: cytotype
#
# Simulation run completed.
# Generation: 11111
# Elapsed Time (hours:minutes:seconds): 0:00:17
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 33
# pr = 0.100905745059
# pt = 0.0216494698144
# diff = 9.4930966265e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 3625
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3625
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 34
# pr = 0.35250538188
# pt = 0.577358933062
# diff = 0.000147186489488
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9381  0.0442  0.0016  0.0346
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4555
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 4555
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 35
# pr = 0.764495207134
# pt = 0.336996386175
# diff = 5.87177883975e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2660
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2660
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 36
# pr = 0.365422359098
# pt = 0.0542755056021
# diff = 5.5098446831e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2621
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2621
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 37
# pr = 0.979135847701
# pt = 0.0761419918486
# diff = 1.88551321103e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 38
# pr = 0.430708377751
# pt = 0.422631951219
# diff = 9.35349328306e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 3467
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3467
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 39
# pr = 0.513968419336
# pt = 0.0352029522788
# diff = 4.36210126578e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2322
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2322
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 40
# pr = 0.0830634502923
# pt = 0.817745315153
# diff = 0.000188335542859
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9380  0.0442  0.0016  0.0346
#       P1          0.0003     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 6433
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9997  0.0003     0.0
# pop2       0.9999     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 6433
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 41
# pr = 0.628391038249
# pt = 0.945380735865
# diff = 0.567121259408
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3431  0.0173  0.0017  0.0526
#       P1          0.6066  0.0255  0.0005  0.0068
#       P2             ---     ---     ---     ---
# T2    P0          0.0017  0.0025  0.0186  0.8721
#       P1          0.0016  0.0017  0.0013  0.0464
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 9938
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9925 0.0075
# pop2       0.0616 0.9384
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.3646 0.6354     ---
# pop2       0.9450 0.0550     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9530 0.0470
# pop2       0.0222 0.9778
# Name: cytotype
#
# Simulation run completed.
# Generation: 9938
# Elapsed Time (hours:minutes:seconds): 0:00:15
# Time per generation (seconds): 0.0016
#
# ...
# i = 986
# pr = 0.585776518402
# pt = 0.0256727750495
# diff = 3.94274608071e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2212
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2212
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0017
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 987
# pr = 0.316572380831
# pt = 0.0163598521434
# diff = 5.74012619607e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 2681
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2681
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 988
# pr = 0.128269899745
# pt = 0.352436835365
# diff = 0.000113705792013
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1          0.0001     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 4033
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 4033
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 989
# pr = 0.877310010719
# pt = 0.312709527671
# diff = 5.10649417576e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2471
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2471
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 990
# pr = 0.0390846474957
# pt = 0.0104917209418
# diff = 0.000116663931129
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9381  0.0442  0.0016  0.0346
#       P1          0.0001     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 4323
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 4323
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 991
# pr = 0.508838005771
# pt = 0.196802890413
# diff = 5.55817433381e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2611
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2611
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 992
# pr = 0.891822405863
# pt = 0.434730537023
# diff = 7.35258508009e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2973
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2973
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 993
# pr = 0.354905588911
# pt = 0.0740881223573
# diff = 5.75064155997e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2676
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2676
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 994
# pr = 0.822670383839
# pt = 0.98586892516
# diff = -0.97341530231
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5682  0.0468  0.0137  0.6014
#       P1          0.3557  0.0293  0.0086  0.3764
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4699
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     ---
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.6150 0.3850     ---
# pop2       0.6150 0.3850     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9239 0.0761
# pop2       0.0222 0.9778
# Name: cytotype
#
# Simulation run completed.
# Generation: 4699
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 995
# pr = 0.718181454698
# pt = 0.395150744484
# diff = 7.11822882857e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2942
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 2942
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 996
# pr = 0.827973187752
# pt = 0.483389971112
# diff = 9.18927818725e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9382  0.0442  0.0016  0.0346
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3369
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 3369
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 997
# pr = 0.0523429776879
# pt = 0.382065543096
# diff = 0.00012909380501
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9381  0.0442  0.0016  0.0346
#       P1          0.0001     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 4657
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 4657
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 998
# pr = 0.137926788991
# pt = 0.636030130653
# diff = 0.000155889997453
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9381  0.0442  0.0016  0.0346
#       P1          0.0002     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0126  0.0049  0.0204  0.9433
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 4977
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 4977
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.0016
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 999
# pr = 0.129358873078
# pt = 0.913031584479
# diff = 0.000326878073751
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9378  0.0442  0.0016  0.0346
#       P1          0.0005     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0126  0.0049  0.0204  0.9432
#       P1             0.0     0.0     0.0  0.0002
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 9291
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9825 0.0175
# pop2       0.0362 0.9638
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.9995 0.0005     ---
# pop2       0.9998 0.0002     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9509 0.0491
# pop2       0.0221 0.9779
# Name: cytotype
#
# Simulation run completed.
# Generation: 9291
# Elapsed Time (hours:minutes:seconds): 0:00:14
# Time per generation (seconds): 0.0016

# %% [markdown]
# Collecting and printing outcomes for all parameter combinations:

# %%
c = scenario['counter'][()]
diffs = np.array( [[x,y,z] for (x,y,z) in scenario['screening'][:c]] )    # convert lenght n array of 3-tuples to array of shape (n,3)
print '   pr      pt      diff   '
print '--------------------------'
print diffs
# Out:
#    pr      pt      diff
# --------------------------
# [[ 0.98174948  0.15784141  0.00003395]
#  [ 0.77765834  0.35697407  0.00006142]
#  [ 0.99282277  0.27522349  0.0000431 ]
#  ...,
#  [ 0.05234298  0.38206553  0.00012909]
#  [ 0.13792679  0.63603014  0.00015589]
#  [ 0.12935887  0.91303158  0.00032688]]

# %% [markdown]
# ## Plot

# %%
# set up figure environment:
fig_width_pt = 500.0                    # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height =fig_width *0.75             # height in inches
fig_size = [fig_width,fig_height]
params = {'backend': 'ps',
          'text.usetex': True,
          'text.family': 'sans-serif',
          'text.latex.preamble': [r"\usepackage{mathtools}"],
          'axes.labelsize': 10,
          'text.fontsize': 12,
          'legend.fontsize': 10,
          'xtick.labelsize': 10,
          'ytick.labelsize': 10,
          'figure.figsize': fig_size}
plt.rcParams.update(params)
ticks_font = font_manager.FontProperties(
    family='Helvetica',
    style='normal',
    size=10,
    weight='normal',
    stretch='normal')

# actual data:
X = diffs[:,0]
Y = diffs[:,1]
Z = diffs[:,2]

from scipy.interpolate import griddata
xmin, xmax = 0., 1.
ymin, ymax = 0., 1.
# generate griddata for contour plot:
numspaces = int(math.sqrt(n))
xi = linspace(xmin, xmax, 100)
yi = linspace(ymin, ymax, 100)
#zi = griddata(X, Y, Z, xi, yi, interp='nn')
zi = griddata((X, Y), Z, (xi[None,:], yi[:,None]), method='nearest')

figure(1, figsize=fig_size)
cmap = plt.cm.PRGn
cmap.set_bad('w',0.)
# uncomment the following two lines in order to add contoor lines:
#levels = [0., 0.05]
#plt.contour(xi, yi, zi, levels, linewidths=0.5, colors='k')
#plt.contourf(xi, yi, zi, cmap=cmap, vmin=-1., vmax=1.)
#plt.pcolormesh(xi, yi, zi, cmap=cmap, vmin=-1., vmax=1.)
plt.imshow(zi, extent=(xmin,xmax,ymin,ymax), cmap=cmap, origin='lower', vmin=-1., vmax=1., aspect='auto', interpolation=None)
plt.clim(-1., 1.)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
ax = gca()
ax.grid(False)
ax.set_aspect(1.)
ax.xaxis.labelpad = 17
ax.yaxis.labelpad = 17
ax.set_xticklabels(ax.get_xticks(), ticks_font)
ax.set_yticklabels(ax.get_yticks(), ticks_font)

# add a colorbar:
cbar = plt.colorbar(ticks=[-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1.])
cax = cbar.ax
cax.set_yticklabels(['--1.0', '--0.75', '--0.5', '--0.25', '0.0', '0.25', '0.5', '0.75', '1.0'])
cax.set_ylabel(r'$\xleftarrow{\mathmakebox[8em]{\textstyle\text{decreasing}}}$ {\large Divergence} $\xrightarrow{\mathmakebox[8em]{\textstyle\text{increasing}}}$')
plt.setp(cax.yaxis.get_ticklines(minor=False), markersize=0)

# uncomment the following line to show screening data points:
#plt.scatter(X, Y, marker='o', c='0.2', s=2)

plt.xlabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{weak}}}$ {\large Mating preference} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{strong}}}$',
    multialignment='left')
plt.ylabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{high}}}$ {\large Preference costs} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{low}}}$',
    multialignment='center')
plt.text(0.5, 0.4, r'No spread of\\mating preferences', color='0.4', size=12, ha='center', multialignment='center')
plt.text(0.93, 0.81, r'\textbf{Reinforcement}', color='w', size=14, ha='right')
plt.text(0.97, 0.985, r'\textbf{Runaway}', color='w', size=14, ha='right', va='top')
plt.text(0., -0.05, r'Rejection probability', ha='left', va='top')
plt.text(-0.1, 0., r'Transition probability', ha='left', va='bottom', rotation='vertical')
#plt.savefig('/home/flor/Documents/Manuscripts/Runaways and reinforcement/Screening_costs_vs_preferencestrength.pdf')
plt.savefig('images/Screening_costs_vs_preferencestrength.pdf')

# %%
len(diffs)
# Out:
# 1000

# %%
rstore.close()

# %%
plt.scatter(X, Y, marker='x', c='0.2', s=1)
plt.xlim(0,1)
plt.ylim(0,1)
ax = gca()
ax.grid(False)
ax.set_aspect(1.)
ax.set_xticklabels(ax.get_xticks(), ticks_font)
ax.set_yticklabels(ax.get_yticks(), ticks_font)
plt.xlabel(r'Rejection probability')
plt.ylabel(r'Transition probability')
