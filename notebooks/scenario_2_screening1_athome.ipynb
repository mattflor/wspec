# %% [markdown]
# # Scenario 2

# %%
import sys, types, time, os, inspect, shutil, pprint, cPickle, gzip, tarfile, pprint, datetime, pdb, copy
import numpy as np
import numpy.random as npr
import pandas as pd
from matplotlib.mlab import griddata
from matplotlib import rc, font_manager
import matplotlib.pyplot as plt
from IPython.core.display import Image
# wspec moduls:
import core, storage, analytical
import visualization as viz
import utilities as utils
for mod in [core,storage,analytical,utils,viz]:     # reload the wspec modules in case the code has changed
    reload(mod)
    
#np.set_printoptions(precision=4, suppress=True, linewidth=100)
np.set_printoptions(suppress=True, linewidth=100)
npr.seed(94832)

# %% [markdown]
# ## 1. Scenario features
#
# * Two populations linked by migration
#
# * Initial state:
#
#     * Trait T1 adaptive and fixed in population 1, T2 in population 2
#
#     * Preference allele P0 (non-discriminating) fixed in both populations
#
# * Population 1 is uninfected, *Wolbachia* infection in population 2
#
# * Order of events:
#
#     1.  Secondary contact
#         $\rightarrow$  selection-migration equilibrium
#
#     2.  Introduction of a preference for T1 in population 1, P1 (T1), and of a preference for T2 in population 2, P2 (T2)
#         $\rightarrow$  new equilibrium
#
# <img src="https://docs.google.com/drawings/d/1PI65vCcdE8Yv5Sa5cS_NrZ3QZzjU8nMVnLLMJycal04/pub?w=691&h=577">

# %% [markdown]
# ## 2. Configuration
#
# To configure the simulation scenario, we need to specify gene loci, alleles, and parameters.
#
# ### 2.1 Loci and alleles
#
# Populations are treated as loci, as would be the cytotype. In numpy terms, each locus is represented by an array axis.
#
# We keep separate lists rather than a dictionary because we need to preserve the locus and allele orders.

# %%
LOCI = ['population', 'trait', 'preference', 'cytotype']
ALLELES = [['pop1', 'pop2'],
           ['T1', 'T2'],
           ['P0', 'P1', 'P2'],
           ['U', 'W']
          ]
print utils.loci2string(LOCI, ALLELES)
# Out:
# locus           alleles
# --------------------------
# population      pop1, pop2
# trait           T1, T2
# preference      P0, P1, P2
# cytotype        U, W

# %%
def popdiff(metapop):
    """
    Measure frequency differences between populations. This function returns a NxN matrix containing 
    values between 0 and L-1 where N is the number of populations and L is the number of loci.
    """
    n = metapop.n_pops
    d = np.zeros((n,n), float)
    for i in range(n):
        for j in range(i,n):
            for loc in metapop.loci[1:]:
                sums = metapop.get_sums(loc)
                d[i,j] += np.max( np.abs(sums[i] - sums[j]) )
                d[j,i] = d[i,j]
    return d

# %% [markdown]
# ### 2.2 Parameters

# %% [markdown]
# Beware of the `step` parameter as the size of the HDF5 database is strongly affected by its value. If we are not interested in every single dynamical process but rather in the final outcome then might set `step = 1e6` which will only record special states like initial frequencies, equilibria, or when new alleles have been introduced.

# %%
sid = '2screen1'     # scenario id
PARAMETERS = {
    'lCI': (0.9, 'CI level'),                   # level of cytoplasmic incompatibility
    't': (0.9, 'transmission rate'),            # transmission of Wolbachia
    'f': (0.1, 'fecundity reduction'),          # Wolbachia-infected females are less fecund
    'm': (0.01, 'migration rate'),              # symmetric migration
    's': (0.1, 'selection coefficient'),        # selection advantage for adaptive trait
    'intro': (0.001, 'introduction frequency'), # introduction frequency of preference mutant allele
    'eq': (1e-6, 'equilibrium threshold'),      # equilibrium threshold (total frequency change)
    'nmin': (1000, 'min generation'),            # run at least `nmin` generations in search of equilibrium
    'nmax': (300000, 'max generation'),         # max number of generations to iterate for each stage of the simulation
    'step': (10, 'storage stepsize')            # store metapopulation state every `step` generations
}
print 'Parameters that are the same for all runs in the screening:\n'
print utils.params2string(PARAMETERS)
# Out:
# Parameters that are the same for all runs in the screening:
#
# parameter    value       description
# -----------------------------------------------
# eq           1e-06       equilibrium threshold
# f            0.1         fecundity reduction
# intro        0.001       introduction frequency
# lCI          0.9         CI level
# m            0.01        migration rate
# nmax         300000      max generation
# nmin         1000        min generation
# s            0.1         selection coefficient
# step         10          storage stepsize
# t            0.9         transmission rate

# %% [markdown]
# We'll generate random transition and rejection probabilities, run the simulation, and check the outcome via the `popdiff` function the results of which are stored as well.

# %%
n = 500

screening_dtype = np.dtype([('pr', 'f'), ('pt', 'f'), ('diff', 'f')])
#rstore = storage.RunStore('/extra/flor/data/notebook_data/scenario_{0}.h5'.format(sid))
rstore = storage.RunStore('data/scenario_{0}.h5'.format(sid))
# select existing scenario, initialize a new one if this fails:
try:
    scenario = rstore.select_scenario(sid, verbose=False)
    count = scenario['counter'][()]
    maxcount = len(scenario['screening'])
except:
    scenario = rstore.create_scenario(sid, labels=(LOCI,ALLELES))
    # scenario = rstore['current']['scenario']
    scenario.create_dataset('counter', (), 'i')    # integer counter for the screening runs; initialized at 0
    count = 0
    maxcount = max(n, 10)
    scenario.create_dataset('screening', (maxcount,), screening_dtype, maxshape=(None,))
    
if n >= maxcount:
    scenario['screening'].resize((n,))

# %% [markdown]
# The actual screening:

# %%
for i in range(n):
    #pr = 0.8 + 0.2*npr.random()                     # draw from a uniform distribution over [0,1)
    #pt = 0.8 + 0.2*npr.random()                     # draw from a uniform distribution over [0,1)
    # we use a U-shaped beta function (low and high values more likely than intermediate ones)
    # to better explore the corners:
    pr = npr.beta(a=0.7, b=0.7)
    pt = npr.beta(a=0.7, b=0.7)
    
    PARAMETERS['pt'] = (pt, 'transition probability')       # probability of transition into another mating round
    PARAMETERS['pr'] = (pr, 'rejection probability')
    # For mating preference parameters, we use a different notation:
    trait_preferences = {                        # female mating preferences (rejection probabilities)
        'P0': {'baseline': 0.},
        'P1': {'baseline': pr, 'T1': 0.},
        'P2': {'baseline': pr, 'T2': 0.}
    }
    rid = 'pr{0:.12f}_pt{1:.12f}'.format(pr,pt)      # generate id of simulation run based on pr and pt values
    PARAMETERS = utils.add_preferences(PARAMETERS, trait_preferences)
    # make parameter names locally available:
    config = utils.configure_locals(LOCI, ALLELES, PARAMETERS)
    locals().update(config)

    max_figwidth = 15
    figheight = 5
    w = min( N_POPS*(N_LOCI-1), max_figwidth )    # figure width: npops*(nloci-1) but at most 15
    figsize = [w, figheight]
    show_progressbar = False          # BEWARE: enabling progressbar slows down the simulation significantly!
    
    overwrite_run = False
    data_available = False
    
    # select existing run, initialize a new one if this fails:
    try:   
        rstore.select_run(rid, verbose=False)
        data_available = True
        special_states = list( rstore.get_special_states()[::-1] )
    except:
        rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    # check whether parameters are identical:
    pars = rstore.get_parameters()
    if not utils.parameters_equal(pars, PARAMETERS, verbose=False):
        data_available = False
        if not overwrite_run:
            raise ValueError('parameter values differ from stored values; set `overwrite_run` to `True` in order to overwrite run')
        else:
            # print 'overwriting run...'
            rstore.remove_run(rid, sid)
            rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    
    if data_available:
        pass
        #specialstates = rstore.get_special_states()
        #generation = rstore.get_last_generation()
        #print i, pr, pt, generation, specialstates
    else:
        weights = {
            'migration': None,
            'viability_selection': None,
            'constant_reproduction': None,
            'dynamic_reproduction': []
        }
        mig = np.array(
            [[1-m,      m ],
             [  m,    1-m ]], float)
        M = core.MigrationWeight(
            name='migration',
            axes=['target', 'source'],
            config=config,
            arr=mig,
            m=m
        )
        weights['migration'] = M.extended()
        # print M
        
        vsarr = np.array(
            [[ 1+s,  1  ],
             [   1,  1+s]], float
        )
        VS = core.ViabilityWeight(
            name='viability selection',
            axes=['population','trait'],
            config=config,
            arr=vsarr,
            s=s
        )
        weights['viability_selection'] = VS.extended()
        # print VS
        
        TP = core.GeneralizedPreferenceWeight(
            name='trait preference',
            axes=['population', 'female_preference', 'male_trait'],
            pref_desc = trait_preferences,
            config=config,
            unstack_levels=[2],
            pt=pt
        )
        weights['dynamic_reproduction'].append( (TP, ['trait']) )
        # print TP
        
        CI = core.ReproductionWeight(
            name='cytoplasmic incompatibility',
            axes=['male_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            lCI=lCI
        )
        CI.set( np.array([[1, 1], [1-lCI, 1]], float ) )
        CI_ = CI.extended()
        # print CI
    
        T = core.ReproductionWeight(
            name='cytotype inheritance',
            axes=['female_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            t=t
        )
        T.set( np.array( [[1, 0], [1-t, t]], float ) )
        T_ = T.extended()
        # print T
        
        F = core.ReproductionWeight(
            name='fecundity reduction',
            axes=['female_cytotype'],
            config=config,
            f=f
        )
        F.set( np.array([1, 1-f], float) )
        F_ = F.extended()
        # print F
        
        IP = core.ReproductionWeight(
            name='preference inheritance',
            axes=['female_preference', 'male_preference', 'offspring_preference'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('preference')])
        IP.set( utils.nuclear_inheritance(n_alleles) )
        IP_ = IP.extended()
        # print IP
        
        IT = core.ReproductionWeight(
            name='trait inheritance',
            axes=['female_trait', 'male_trait', 'offspring_trait'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('trait')])
        IT.set( utils.nuclear_inheritance(n_alleles) )
        IT_ = IT.extended()
        # print IT
        
        R_ = CI_ * T_ * F_ * IP_ * IT_
        weights['constant_reproduction'] = R_
        
        # INITIAL STATE:
        starttime = time.time()                  # take time for timing report after simulation run
        startfreqs = np.zeros(FSHAPE)
        startfreqs[0,0,0,0] = 1.                   # pop1-T1-P0-U
        startfreqs[1,1,0,1] = 1.                   # pop2-T2-P0-W
        metapop = core.MetaPopulation(
            startfreqs,
            config=config,
            generation=0,
            name='metapopulation'
        )
        rstore.record_special_state(metapop.generation, 'start')
        rstore.dump_data(metapop)
        
        # MIGRATION-SELECTION EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        # make a copy of the metapopulation for later calculation of frequency differences:
        #initial = copy.copy(metapop)
        # frequency difference score before introduction of preference alleles:
        base_diff = popdiff(metapop)[0,1]
        
        # INTRODUCTION OF PREFERENCE MUTANTS:
        intro_allele = 'P1'
        metapop.introduce_allele('pop1', intro_allele, intro_freq=intro, advance_generation_count=False)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        intro_allele = 'P2'
        metapop.introduce_allele('pop2', intro_allele, intro_freq=intro, advance_generation_count=True)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        # FINAL EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        
        #diff = popdiff2(metapop, initial)[0,1]
        diff = popdiff(metapop)[0,1] - base_diff
        scenario['screening'][i] = (pr, pt, diff)
        scenario['counter'][()] += 1
        
        print '\n^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^'
        print 'i = {0}\npr = {1}\npt = {2}\ndiff = {3}\n'.format(i,pr,pt,diff)
        print metapop
        print metapop.overview()
        print
        print utils.timing_report(starttime, metapop.generation)
        rstore.flush()
        
        # fig = viz.plot_overview(metapop, show_generation=False, figsize=figsize)
        # fig = rstore.plot_sums(figsize=[max_figwidth, figheight])
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 300
# pr = 0.807175997132
# pt = 0.25744348736
# diff = 7.49049521165e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 301
# pr = 0.051886895279
# pt = 0.0139948102354
# diff = 8.30694267391e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2308
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2308
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 302
# pr = 0.823875413531
# pt = 0.62272942274
# diff = 0.000357277596051
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9358  0.0405  0.0023  0.0569
#       P1          0.0003     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3089
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9767 0.0233
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9997  0.0003     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 3089
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 303
# pr = 0.993366313763
# pt = 0.299184560809
# diff = 6.48719383012e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 304
# pr = 0.616041959615
# pt = 0.901363224792
# diff = 0.576988763225
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3129  0.0160  0.0022  0.0845
#       P1          0.6371  0.0241  0.0009  0.0116
#       P2             ---     ---     ---     ---
# T2    P0          0.0020  0.0035  0.0132  0.8365
#       P1          0.0020  0.0026  0.0012  0.0499
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 8523
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9901 0.0099
# pop2       0.0992 0.9008
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.3343 0.6657     ---
# pop2       0.9365 0.0635     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9539 0.0461
# pop2       0.0175 0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 8523
# Elapsed Time (hours:minutes:seconds): 0:00:15
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 305
# pr = 0.625068763734
# pt = 0.307635219344
# diff = 2.50762013541e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 306
# pr = 0.897498415786
# pt = 0.891369409889
# diff = 0.743647149858
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1930  0.0114  0.0022  0.0846
#       P1          0.7601  0.0277  0.0011  0.0090
#       P2             ---     ---     ---     ---
# T2    P0          0.0010  0.0030  0.0135  0.8711
#       P1          0.0011  0.0028  0.0006  0.0179
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5564
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9921 0.0079
# pop2       0.0968 0.9032
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2084 0.7916     ---
# pop2       0.9714 0.0286     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9552 0.0448
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 5564
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 307
# pr = 0.833207414866
# pt = 0.353267765892
# diff = 2.20983711554e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 308
# pr = 0.948518270297
# pt = 0.436977343492
# diff = 5.3354603212e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 309
# pr = 0.888342123829
# pt = 0.608170775007
# diff = 0.000296574569691
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0003     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3028
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9767 0.0233
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9997  0.0003     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 3028
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 310
# pr = 0.323367754304
# pt = 0.278405813812
# diff = 5.95751200525e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 311
# pr = 0.536717979276
# pt = 0.968190843228
# diff = -0.929983582461
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4899  0.0312  0.0092  0.5119
#       P1          0.4502  0.0287  0.0085  0.4704
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5916
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     ---
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.5211 0.4789     ---
# pop2       0.5211 0.4789     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5916
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 312
# pr = 0.14394280005
# pt = 0.180779561411
# diff = 7.23289374149e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2128
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2128
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 313
# pr = 0.0528179418748
# pt = 0.361980975441
# diff = 9.70639785129e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1          0.0001     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2484
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2484
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 314
# pr = 0.344085263363
# pt = 0.925015705385
# diff = 0.317192709966
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5138  0.0237  0.0021  0.0708
#       P1          0.4310  0.0170  0.0007  0.0132
#       P2             ---     ---     ---     ---
# T2    P0          0.0050  0.0043  0.0128  0.7967
#       P1          0.0031  0.0021  0.0019  0.1018
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 19476
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9855 0.0145
# pop2       0.0868 0.9132
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.5469 0.4531     ---
# pop2       0.8824 0.1176     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9529 0.0471
# pop2       0.0175 0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 19476
# Elapsed Time (hours:minutes:seconds): 0:00:35
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 315
# pr = 0.0309093519918
# pt = 0.754183816786
# diff = 0.00012328799142
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9358  0.0405  0.0023  0.0569
#       P1          0.0003     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9255
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2901
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.9997 0.0003     0.0
# pop2       0.9998 0.0002     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2901
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 316
# pr = 0.194359228397
# pt = 0.13141919026
# diff = 6.23287332391e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2009
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2009
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 317
# pr = 0.0528482766465
# pt = 0.762544809901
# diff = 0.000135019336536
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9255
#       P1             0.0     0.0     0.0  0.0001
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2871
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.9997 0.0003     0.0
# pop2       0.9999 0.0001     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2871
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 318
# pr = 0.660710775107
# pt = 0.0776450131581
# diff = 2.34374323971e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 319
# pr = 0.175012389892
# pt = 0.0583017304185
# diff = 5.91510143462e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 320
# pr = 0.684125105959
# pt = 0.490710841394
# diff = 8.94264820586e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2195
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2195
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 321
# pr = 0.820593982838
# pt = 0.936402534396
# diff = -0.929983483178
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4154  0.0264  0.0078  0.4341
#       P1          0.5247  0.0334  0.0099  0.5482
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5175
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     ---
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.4419 0.5581     ---
# pop2       0.4419 0.5581     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 5175
# Elapsed Time (hours:minutes:seconds): 0:00:09
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 322
# pr = 0.980950892928
# pt = 0.403403621368
# diff = 3.11486305911e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 323
# pr = 0.537073342585
# pt = 0.352751037307
# diff = 4.8180588867e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 324
# pr = 0.256357138107
# pt = 0.225626107255
# diff = 6.26721720616e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 2002
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2002
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 325
# pr = 0.759873080901
# pt = 0.909553753328
# diff = 0.643994833931
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2432  0.0134  0.0025  0.1016
#       P1          0.7084  0.0265  0.0010  0.0133
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0031  0.0131  0.8305
#       P1          0.0014  0.0027  0.0010  0.0370
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6375
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9915 0.0085
# pop2       0.1185 0.8815
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2610 0.7390     ---
# pop2       0.9477 0.0523     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9543 0.0457
# pop2       0.0176 0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 6375
# Elapsed Time (hours:minutes:seconds): 0:00:11
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 326
# pr = 0.492645110006
# pt = 0.998808289894
# diff = -0.929983507746
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5644  0.0359  0.0106  0.5897
#       P1          0.3758  0.0239  0.0071  0.3926
#       P2             0.0     0.0     0.0     0.0
# T2    P0             0.0     0.0     0.0     0.0
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4789
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     0.0
# pop2       1.0000     0.0
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.6003 0.3997     0.0
# pop2       0.6003 0.3997     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4789
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 327
# pr = 0.720853188183
# pt = 0.458197710899
# diff = 7.60303953888e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2079
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2079
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 328
# pr = 0.598677096793
# pt = 0.144317251033
# diff = 6.42047156596e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 329
# pr = 0.00374390711975
# pt = 0.822085803943
# diff = 3.55619100079e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9352  0.0405  0.0023  0.0569
#       P1          0.0007     0.0     0.0     0.0
#       P2          0.0002     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9248
#       P1             0.0     0.0     0.0  0.0006
#       P2             0.0     0.0     0.0  0.0002
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1     P2
# population
# pop1       0.9991 0.0007 0.0002
# pop2       0.9991 0.0007 0.0002
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 330
# pr = 0.820257929085
# pt = 0.755256666367
# diff = 0.708648749588
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2693  0.0141  0.0017  0.0559
#       P1          0.6828  0.0248  0.0006  0.0043
#       P2             ---     ---     ---     ---
# T2    P0          0.0014  0.0035  0.0142  0.9112
#       P1          0.0013  0.0027  0.0005  0.0116
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 9850
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9911 0.0089
# pop2       0.0625 0.9375
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2883 0.7117     ---
# pop2       0.9829 0.0171     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9549 0.0451
# pop2       0.0170 0.9830
# Name: cytotype
#
# Simulation run completed.
# Generation: 9850
# Elapsed Time (hours:minutes:seconds): 0:00:17
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 331
# pr = 0.133387040772
# pt = 0.689427053441
# diff = 0.000140882101226
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2711
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2711
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 332
# pr = 0.236920247283
# pt = 0.28403009067
# diff = 6.99144868237e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 2079
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2079
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 333
# pr = 0.0254132024591
# pt = 0.440792847425
# diff = 0.000102850836046
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2723
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     0.0
# pop2       0.9999     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2723
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 334
# pr = 0.377139991227
# pt = 0.397789976365
# diff = 7.46153158016e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2104
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2104
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 335
# pr = 0.273587706059
# pt = 0.8631685271
# diff = 0.000807903227355
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9352  0.0405  0.0023  0.0569
#       P1          0.0009     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9255
#       P1             0.0     0.0     0.0  0.0002
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9767 0.0233
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.9990 0.0010     0.0
# pop2       0.9998 0.0002     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 336
# pr = 0.779831338849
# pt = 0.620287115327
# diff = 0.000305429310862
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0003     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3043
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9767 0.0233
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9997  0.0003     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 3043
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 337
# pr = 0.155488766557
# pt = 0.678370742696
# diff = 0.000143005396206
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2697
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2697
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 338
# pr = 0.626593173327
# pt = 0.0425945185504
# diff = 2.13229457713e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 339
# pr = 0.195830059315
# pt = 0.789650028843
# diff = 0.000243129995374
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9358  0.0405  0.0023  0.0569
#       P1          0.0003     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 3016
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9997  0.0003     0.0
# pop2       0.9999     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 3016
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 340
# pr = 0.577727767471
# pt = 0.986884089023
# diff = -0.929983631187
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5643  0.0359  0.0106  0.5896
#       P1          0.3759  0.0239  0.0071  0.3927
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4743
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     ---
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.6002 0.3998     ---
# pop2       0.6002 0.3998     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4743
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 341
# pr = 0.652551148219
# pt = 0.555925395796
# diff = 0.000130819228232
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2484
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2484
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ...
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 486
# pr = 0.144385602218
# pt = 0.290479656751
# diff = 8.03809863377e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2209
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2209
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 487
# pr = 0.366895419932
# pt = 0.257719639059
# diff = 4.51365066472e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 488
# pr = 0.962336465488
# pt = 0.690014733147
# diff = 0.763187029067
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2330  0.0127  0.0014  0.0487
#       P1          0.7204  0.0257  0.0006  0.0035
#       P2             ---     ---     ---     ---
# T2    P0          0.0011  0.0033  0.0142  0.9249
#       P1          0.0010  0.0028  0.0003  0.0063
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 11627
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9918 0.0082
# pop2       0.0542 0.9458
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2501 0.7499     ---
# pop2       0.9893 0.0107     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9555 0.0445
# pop2       0.0166 0.9834
# Name: cytotype
#
# Simulation run completed.
# Generation: 11627
# Elapsed Time (hours:minutes:seconds): 0:00:21
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 489
# pr = 0.0676695081817
# pt = 0.997472730242
# diff = -0.0340697596119
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.0006     0.0     0.0     0.0
#       P1          0.9405  0.0411  0.0030  0.0957
#       P2             ---     ---     ---     ---
# T2    P0             0.0     0.0     0.0  0.0006
#       P1          0.0112  0.0065  0.0145  0.8861
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 50720
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9823 0.0177
# pop2       0.0988 0.9012
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.0006 0.9994     ---
# pop2       0.0007 0.9993     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9523 0.0477
# pop2       0.0176 0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 50720
# Elapsed Time (hours:minutes:seconds): 0:01:32
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 490
# pr = 0.999867133168
# pt = 0.173280461935
# diff = 9.78380144678e-07
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 491
# pr = 0.739691499751
# pt = 0.951604140991
# diff = -0.929983623032
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4571  0.0291  0.0086  0.4776
#       P1          0.4831  0.0308  0.0091  0.5047
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4968
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     ---
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.4862 0.5138     ---
# pop2       0.4862 0.5138     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4968
# Elapsed Time (hours:minutes:seconds): 0:00:09
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 492
# pr = 0.0376334645935
# pt = 0.589060881641
# diff = 0.00011087937299
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2741
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     0.0
# pop2       0.9999     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2741
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 493
# pr = 0.918649312448
# pt = 0.478350288288
# diff = 7.91794790305e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2091
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2091
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 494
# pr = 0.888999481049
# pt = 0.276610203369
# diff = 6.90929702807e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 495
# pr = 0.182032076016
# pt = 0.640047020047
# diff = 0.000135829618626
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1          0.0001     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 2628
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2628
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 496
# pr = 0.199326120393
# pt = 0.0816556842913
# diff = 5.33120471022e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 497
# pr = 0.41769293757
# pt = 0.20906799061
# diff = 2.7133999992e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 498
# pr = 0.481109928393
# pt = 0.99975852422
# diff = -0.929983271642
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5597  0.0356  0.0106  0.5847
#       P1          0.3805  0.0242  0.0072  0.3975
#       P2             0.0     0.0     0.0     0.0
# T2    P0             0.0     0.0     0.0     0.0
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4835
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     0.0
# pop2       1.0000     0.0
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.5953 0.4047     0.0
# pop2       0.5953 0.4047     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4835
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 499
# pr = 0.686058111346
# pt = 0.906189394112
# diff = 0.613312371529
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2746  0.0146  0.0024  0.0929
#       P1          0.6762  0.0254  0.0010  0.0126
#       P2             ---     ---     ---     ---
# T2    P0          0.0016  0.0033  0.0131  0.8328
#       P1          0.0017  0.0026  0.0011  0.0441
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 7292
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9908 0.0092
# pop2       0.1088 0.8912
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2940 0.7060     ---
# pop2       0.9412 0.0588     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9541 0.0459
# pop2       0.0175 0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 7292
# Elapsed Time (hours:minutes:seconds): 0:00:13
# Time per generation (seconds): 0.0018

# %% [markdown]
# Collecting and printing outcomes for all parameter combinations:

# %%
c = scenario['counter'][()]
diffs = np.array( [[x,y,z] for (x,y,z) in scenario['screening'][:c]] )    # convert lenght n array of 3-tuples to array of shape (n,3)
print '   pr      pt      diff   '
print '--------------------------'
print diffs
# Out:
#    pr      pt      diff
# --------------------------
# [[ 0.84268355  0.99148446 -0.92998362]
#  [ 0.84729743  0.80290622  0.74022162]
#  [ 0.82166594  0.86995178  0.72323036]
#  ...,
#  [ 0.41769293  0.20906799  0.00002713]
#  [ 0.48110992  0.99975854 -0.92998326]
#  [ 0.6860581   0.90618938  0.61331236]]

# %% [markdown]
# ## Plot

# %%
# set up figure environment:
fig_width_pt = 500.0                    # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height =fig_width *0.75             # height in inches
fig_size = [fig_width,fig_height]
params = {'backend': 'ps',
          'text.usetex': True,
          'text.family': 'sans-serif',
          'text.latex.preamble': [r"\usepackage{mathtools}"],
          'axes.labelsize': 10,
          'text.fontsize': 12,
          'legend.fontsize': 10,
          'xtick.labelsize': 10,
          'ytick.labelsize': 10,
          'figure.figsize': fig_size}
plt.rcParams.update(params)
ticks_font = font_manager.FontProperties(
    family='Helvetica',
    style='normal',
    size=10,
    weight='normal',
    stretch='normal')

# actual data:
X = diffs[:,0]
Y = diffs[:,1]
Z = diffs[:,2]

from scipy.interpolate import griddata
xmin, xmax = 0., 1.
ymin, ymax = 0., 1.
# generate griddata for contour plot:
numspaces = int(math.sqrt(n))
xi = linspace(xmin, xmax, 100)
yi = linspace(ymin, ymax, 100)
#zi = griddata(X, Y, Z, xi, yi, interp='nn')
zi = griddata((X, Y), Z, (xi[None,:], yi[:,None]), method='nearest')

figure(1, figsize=fig_size)
cmap = plt.cm.PRGn
cmap.set_bad('w',0.)
# uncomment the following two lines in order to add contoor lines:
#levels = [0., 0.05]
#plt.contour(xi, yi, zi, levels, linewidths=0.5, colors='k')
#plt.contourf(xi, yi, zi, cmap=cmap, vmin=-1., vmax=1.)
#plt.pcolormesh(xi, yi, zi, cmap=cmap, vmin=-1., vmax=1.)
plt.imshow(zi, extent=(xmin,xmax,ymin,ymax), cmap=cmap, origin='lower', vmin=-1., vmax=1., aspect='auto', interpolation=None)
plt.clim(-1., 1.)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
ax = gca()
ax.grid(False)
ax.set_aspect(1.)
ax.xaxis.labelpad = 17
ax.yaxis.labelpad = 17
ax.set_xticklabels(ax.get_xticks(), ticks_font)
ax.set_yticklabels(ax.get_yticks(), ticks_font)

# add a colorbar:
cbar = plt.colorbar(ticks=[-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1.])
cax = cbar.ax
cax.set_yticklabels(['--1.0', '--0.75', '--0.5', '--0.25', '0.0', '0.25', '0.5', '0.75', '1.0'])
cax.set_ylabel(r'$\xleftarrow{\mathmakebox[8em]{\textstyle\text{decreasing}}}$ {\large Divergence} $\xrightarrow{\mathmakebox[8em]{\textstyle\text{increasing}}}$')
plt.setp(cax.yaxis.get_ticklines(minor=False), markersize=0)

# uncomment the following line to show screening data points:
#plt.scatter(X, Y, marker='x', c='0.2', s=1)

plt.xlabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{weak}}}$ {\large Mating preference} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{strong}}}$',
    multialignment='left')
plt.ylabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{high}}}$ {\large Preference costs} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{low}}}$',
    multialignment='center')
plt.text(0.5, 0.4, r'No spread of\\mating preferences', color='0.4', size=12, ha='center', multialignment='center')
plt.text(0.93, 0.81, r'\textbf{Reinforcement}', color='w', size=14, ha='right')
plt.text(0.97, 0.985, r'\textbf{Runaway}', color='w', size=14, ha='right', va='top')
plt.text(0., -0.05, r'Rejection probability', ha='left', va='top')
plt.text(-0.1, 0., r'Transition probability', ha='left', va='bottom', rotation='vertical')
#plt.savefig('/home/flor/Documents/Manuscripts/Runaways and reinforcement/Screening_costs_vs_preferencestrength.pdf')
plt.savefig('images/Screening_costs_vs_preferencestrength.pdf')

# %%
len(diffs)
# Out:
# 500

# %%
rstore.close()

# %%
plt.scatter(X, Y, marker='x', c='0.2', s=1)
plt.xlim(0,1)
plt.ylim(0,1)
ax = gca()
ax.grid(False)
ax.set_aspect(1.)
ax.set_xticklabels(ax.get_xticks(), ticks_font)
ax.set_yticklabels(ax.get_yticks(), ticks_font)
plt.xlabel(r'Rejection probability')
plt.ylabel(r'Transition probability')
