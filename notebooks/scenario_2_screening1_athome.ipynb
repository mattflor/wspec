# %% [markdown]
# # Scenario 2

# %%
import sys, types, time, os, inspect, shutil, pprint, cPickle, gzip, tarfile, pprint, datetime, pdb, copy
import numpy as np
import numpy.random as npr
import pandas as pd
from matplotlib.mlab import griddata
from matplotlib import rc, font_manager
import matplotlib.pyplot as plt
from IPython.core.display import Image
# wspec moduls:
import core, storage, analytical
import visualization as viz
import utilities as utils
for mod in [core,storage,analytical,utils,viz]:     # reload the wspec modules in case the code has changed
    reload(mod)
    
#np.set_printoptions(precision=4, suppress=True, linewidth=100)
np.set_printoptions(suppress=True, linewidth=100)
npr.seed(94832)

# %% [markdown]
# ## 1. Scenario features
#
# * Two populations linked by migration
#
# * Initial state:
#
#     * Trait T1 adaptive and fixed in population 1, T2 in population 2
#
#     * Preference allele P0 (non-discriminating) fixed in both populations
#
# * Population 1 is uninfected, *Wolbachia* infection in population 2
#
# * Order of events:
#
#     1.  Secondary contact
#         $\rightarrow$  selection-migration equilibrium
#
#     2.  Introduction of a preference for T1 in population 1, P1 (T1), and of a preference for T2 in population 2, P2 (T2)
#         $\rightarrow$  new equilibrium
#
# <img src="https://docs.google.com/drawings/d/1PI65vCcdE8Yv5Sa5cS_NrZ3QZzjU8nMVnLLMJycal04/pub?w=691&h=577">

# %% [markdown]
# ## 2. Configuration
#
# To configure the simulation scenario, we need to specify gene loci, alleles, and parameters.
#
# ### 2.1 Loci and alleles
#
# Populations are treated as loci, as would be the cytotype. In numpy terms, each locus is represented by an array axis.
#
# We keep separate lists rather than a dictionary because we need to preserve the locus and allele orders.

# %%
LOCI = ['population', 'trait', 'preference', 'cytotype']
ALLELES = [['pop1', 'pop2'],
           ['T1', 'T2'],
           ['P0', 'P1', 'P2'],
           ['U', 'W']
          ]
print utils.loci2string(LOCI, ALLELES)
# Out:
# locus           alleles
# --------------------------
# population      pop1, pop2
# trait           T1, T2
# preference      P0, P1, P2
# cytotype        U, W

# %%
def popdiff(metapop):
    """
    Measure frequency differences between populations. This function returns a NxN matrix containing 
    values between 0 and L-1 where N is the number of populations and L is the number of loci.
    """
    n = metapop.n_pops
    d = np.zeros((n,n), float)
    for i in range(n):
        for j in range(i,n):
            for loc in metapop.loci[1:]:
                sums = metapop.get_sums(loc)
                d[i,j] += np.max( np.abs(sums[i] - sums[j]) )
                d[j,i] = d[i,j]
    return d

# %% [markdown]
# ### 2.2 Parameters

# %% [markdown]
# Beware of the `step` parameter as the size of the HDF5 database is strongly affected by its value. If we are not interested in every single dynamical process but rather in the final outcome then might set `step = 1e6` which will only record special states like initial frequencies, equilibria, or when new alleles have been introduced.

# %%
sid = '2screen1'     # scenario id
PARAMETERS = {
    'lCI': (0.9, 'CI level'),                   # level of cytoplasmic incompatibility
    't': (0.9, 'transmission rate'),            # transmission of Wolbachia
    'f': (0.1, 'fecundity reduction'),          # Wolbachia-infected females are less fecund
    'm': (0.01, 'migration rate'),              # symmetric migration
    's': (0.1, 'selection coefficient'),        # selection advantage for adaptive trait
    'intro': (0.001, 'introduction frequency'), # introduction frequency of preference mutant allele
    'eq': (1e-6, 'equilibrium threshold'),      # equilibrium threshold (total frequency change)
    'nmin': (1000, 'min generation'),            # run at least `nmin` generations in search of equilibrium
    'nmax': (300000, 'max generation'),         # max number of generations to iterate for each stage of the simulation
    'step': (10, 'storage stepsize')            # store metapopulation state every `step` generations
}
print 'Parameters that are the same for all runs in the screening:\n'
print utils.params2string(PARAMETERS)
# Out:
# Parameters that are the same for all runs in the screening:
#
# parameter    value       description
# -----------------------------------------------
# eq           1e-06       equilibrium threshold
# f            0.1         fecundity reduction
# intro        0.001       introduction frequency
# lCI          0.9         CI level
# m            0.01        migration rate
# nmax         300000      max generation
# nmin         1000        min generation
# s            0.1         selection coefficient
# step         10          storage stepsize
# t            0.9         transmission rate

# %% [markdown]
# We'll generate random transition and rejection probabilities, run the simulation, and check the outcome via the `popdiff` function the results of which are stored as well.

# %%
n = 500

screening_dtype = np.dtype([('pr', 'f'), ('pt', 'f'), ('diff', 'f')])
#rstore = storage.RunStore('/extra/flor/data/notebook_data/scenario_{0}.h5'.format(sid))
rstore = storage.RunStore('data/scenario_{0}.h5'.format(sid))
# select existing scenario, initialize a new one if this fails:
try:
    scenario = rstore.select_scenario(sid, verbose=False)
    count = scenario['counter'][()]
    maxcount = len(scenario['screening'])
except:
    scenario = rstore.create_scenario(sid, labels=(LOCI,ALLELES))
    # scenario = rstore['current']['scenario']
    scenario.create_dataset('counter', (), 'i')    # integer counter for the screening runs; initialized at 0
    count = 0
    maxcount = max(n, 10)
    scenario.create_dataset('screening', (maxcount,), screening_dtype, maxshape=(None,))
    
if n >= maxcount:
    scenario['screening'].resize((n,))

# %% [markdown]
# The actual screening:

# %%
for i in range(n):
    #pr = 0.8 + 0.2*npr.random()                     # draw from a uniform distribution over [0,1)
    #pt = 0.8 + 0.2*npr.random()                     # draw from a uniform distribution over [0,1)
    # we use a U-shaped beta function (low and high values more likely than intermediate ones)
    # to better explore the corners:
    pr = npr.beta(a=0.7, b=0.7)
    pt = npr.beta(a=0.7, b=0.7)
    
    PARAMETERS['pt'] = (pt, 'transition probability')       # probability of transition into another mating round
    PARAMETERS['pr'] = (pr, 'rejection probability')
    # For mating preference parameters, we use a different notation:
    trait_preferences = {                        # female mating preferences (rejection probabilities)
        'P0': {'baseline': 0.},
        'P1': {'baseline': pr, 'T1': 0.},
        'P2': {'baseline': pr, 'T2': 0.}
    }
    rid = 'pr{0:.12f}_pt{1:.12f}'.format(pr,pt)      # generate id of simulation run based on pr and pt values
    PARAMETERS = utils.add_preferences(PARAMETERS, trait_preferences)
    # make parameter names locally available:
    config = utils.configure_locals(LOCI, ALLELES, PARAMETERS)
    locals().update(config)

    max_figwidth = 15
    figheight = 5
    w = min( N_POPS*(N_LOCI-1), max_figwidth )    # figure width: npops*(nloci-1) but at most 15
    figsize = [w, figheight]
    show_progressbar = False          # BEWARE: enabling progressbar slows down the simulation significantly!
    
    overwrite_run = False
    data_available = False
    
    # select existing run, initialize a new one if this fails:
    try:   
        rstore.select_run(rid, verbose=False)
        data_available = True
        special_states = list( rstore.get_special_states()[::-1] )
    except:
        rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    # check whether parameters are identical:
    pars = rstore.get_parameters()
    if not utils.parameters_equal(pars, PARAMETERS, verbose=False):
        data_available = False
        if not overwrite_run:
            raise ValueError('parameter values differ from stored values; set `overwrite_run` to `True` in order to overwrite run')
        else:
            # print 'overwriting run...'
            rstore.remove_run(rid, sid)
            rstore.init_run(rid, PARAMETERS, FSHAPE, init_len=100)
    
    if data_available:
        pass
        #specialstates = rstore.get_special_states()
        #generation = rstore.get_last_generation()
        #print i, pr, pt, generation, specialstates
    else:
        weights = {
            'migration': None,
            'viability_selection': None,
            'constant_reproduction': None,
            'dynamic_reproduction': []
        }
        mig = np.array(
            [[1-m,      m ],
             [  m,    1-m ]], float)
        M = core.MigrationWeight(
            name='migration',
            axes=['target', 'source'],
            config=config,
            arr=mig,
            m=m
        )
        weights['migration'] = M.extended()
        # print M
        
        vsarr = np.array(
            [[ 1+s,  1  ],
             [   1,  1+s]], float
        )
        VS = core.ViabilityWeight(
            name='viability selection',
            axes=['population','trait'],
            config=config,
            arr=vsarr,
            s=s
        )
        weights['viability_selection'] = VS.extended()
        # print VS
        
        TP = core.GeneralizedPreferenceWeight(
            name='trait preference',
            axes=['population', 'female_preference', 'male_trait'],
            pref_desc = trait_preferences,
            config=config,
            unstack_levels=[2],
            pt=pt
        )
        weights['dynamic_reproduction'].append( (TP, ['trait']) )
        # print TP
        
        CI = core.ReproductionWeight(
            name='cytoplasmic incompatibility',
            axes=['male_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            lCI=lCI
        )
        CI.set( np.array([[1, 1], [1-lCI, 1]], float ) )
        CI_ = CI.extended()
        # print CI
    
        T = core.ReproductionWeight(
            name='cytotype inheritance',
            axes=['female_cytotype', 'offspring_cytotype'],
            config=config,
            unstack_levels=[1],
            t=t
        )
        T.set( np.array( [[1, 0], [1-t, t]], float ) )
        T_ = T.extended()
        # print T
        
        F = core.ReproductionWeight(
            name='fecundity reduction',
            axes=['female_cytotype'],
            config=config,
            f=f
        )
        F.set( np.array([1, 1-f], float) )
        F_ = F.extended()
        # print F
        
        IP = core.ReproductionWeight(
            name='preference inheritance',
            axes=['female_preference', 'male_preference', 'offspring_preference'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('preference')])
        IP.set( utils.nuclear_inheritance(n_alleles) )
        IP_ = IP.extended()
        # print IP
        
        IT = core.ReproductionWeight(
            name='trait inheritance',
            axes=['female_trait', 'male_trait', 'offspring_trait'],
            config=config,
            unstack_levels=[2]
        )
        n_alleles = len(ALLELES[LOCI.index('trait')])
        IT.set( utils.nuclear_inheritance(n_alleles) )
        IT_ = IT.extended()
        # print IT
        
        R_ = CI_ * T_ * F_ * IP_ * IT_
        weights['constant_reproduction'] = R_
        
        # INITIAL STATE:
        starttime = time.time()                  # take time for timing report after simulation run
        startfreqs = np.zeros(FSHAPE)
        startfreqs[0,0,0,0] = 1.                   # pop1-T1-P0-U
        startfreqs[1,1,0,1] = 1.                   # pop2-T2-P0-W
        metapop = core.MetaPopulation(
            startfreqs,
            config=config,
            generation=0,
            name='metapopulation'
        )
        rstore.record_special_state(metapop.generation, 'start')
        rstore.dump_data(metapop)
        
        # MIGRATION-SELECTION EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        # make a copy of the metapopulation for later calculation of frequency differences:
        #initial = copy.copy(metapop)
        # frequency difference score before introduction of preference alleles:
        base_diff = popdiff(metapop)[0,1]
        
        # INTRODUCTION OF PREFERENCE MUTANTS:
        intro_allele = 'P1'
        metapop.introduce_allele('pop1', intro_allele, intro_freq=intro, advance_generation_count=False)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        intro_allele = 'P2'
        metapop.introduce_allele('pop2', intro_allele, intro_freq=intro, advance_generation_count=True)
        rstore.dump_data(metapop)
        rstore.record_special_state(metapop.generation, 'intro {0}'.format(intro_allele))
        
        # FINAL EQUILIBRIUM:
        metapop.run(
            nmax,
            weights,
            thresh_total=eq,
            n_min=nmin,
            step=step,
            runstore=rstore,
            progress_bar=show_progressbar,
            verbose=False
        )
        
        #diff = popdiff2(metapop, initial)[0,1]
        diff = popdiff(metapop)[0,1] - base_diff
        scenario['screening'][i] = (pr, pt, diff)
        scenario['counter'][()] += 1
        
        print '\n^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^'
        print 'i = {0}\npr = {1}\npt = {2}\ndiff = {3}\n'.format(i,pr,pt,diff)
        print metapop
        print metapop.overview()
        print
        print utils.timing_report(starttime, metapop.generation)
        rstore.flush()
        
        # fig = viz.plot_overview(metapop, show_generation=False, figsize=figsize)
        # fig = rstore.plot_sums(figsize=[max_figwidth, figheight])
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 200
# pr = 0.659498739721
# pt = 0.303446117017
# diff = 2.14629778021e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 201
# pr = 0.0747349606009
# pt = 0.146619898817
# diff = 8.252581521e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2276
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2276
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 202
# pr = 0.93855373546
# pt = 0.922756290011
# diff = 0.625190833408
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2041  0.0123  0.0035  0.1611
#       P1          0.7481  0.0284  0.0014  0.0203
#       P2             ---     ---     ---     ---
# T2    P0          0.0009  0.0027  0.0121  0.7779
#       P1          0.0009  0.0025  0.0007  0.0231
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4808
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9930 0.0070
# pop2       0.1863 0.8137
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2200 0.7800     ---
# pop2       0.9546 0.0454     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9540 0.0460
# pop2       0.0177 0.9823
# Name: cytotype
# Simulation run completed.
# Generation: 4808
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 203
# pr = 0.552428822028
# pt = 0.742000458146
# diff = 0.412653385447
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5408  0.0247  0.0020  0.0579
#       P1          0.4062  0.0153  0.0004  0.0032
#       P2             ---     ---     ---     ---
# T2    P0          0.0044  0.0047  0.0145  0.9057
#       P1          0.0020  0.0017  0.0005  0.0158
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 41636
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9871 0.0129
# pop2       0.0635 0.9365
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.5748 0.4252     ---
# pop2       0.9801 0.0199     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9535 0.0465
# pop2       0.0173 0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 41636
# Elapsed Time (hours:minutes:seconds): 0:01:16
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 204
# pr = 0.747106675571
# pt = 0.410597181717
# diff = 5.25693418145e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 205
# pr = 0.991656968547
# pt = 0.860412346724
# diff = 0.809941135489
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1662  0.0102  0.0017  0.0641
#       P1          0.7878  0.0280  0.0010  0.0058
#       P2             ---     ---     ---     ---
# T2    P0          0.0008  0.0030  0.0139  0.9045
#       P1          0.0009  0.0029  0.0004  0.0085
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5339
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9923 0.0077
# pop2       0.0727 0.9273
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.1802 0.8198     ---
# pop2       0.9842 0.0158     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9558 0.0442
# pop2       0.0171 0.9829
# Name: cytotype
#
# Simulation run completed.
# Generation: 5339
# Elapsed Time (hours:minutes:seconds): 0:00:09
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 206
# pr = 0.335323048308
# pt = 0.58889593391
# diff = 0.000133828871658
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2552
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2552
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 207
# pr = 0.463852527433
# pt = 0.228596238202
# diff = 2.48754658787e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 208
# pr = 0.829330041133
# pt = 0.430886833845
# diff = 5.83712032571e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.002
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 209
# pr = 0.469060236519
# pt = 0.330483243385
# diff = 4.9419350058e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0023
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 210
# pr = 0.495742777453
# pt = 0.0794533588273
# diff = 7.20893349682e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0021
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 211
# pr = 0.481417688992
# pt = 0.815337625442
# diff = 0.409521138356
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5261  0.0242  0.0020  0.0608
#       P1          0.4204  0.0160  0.0004  0.0045
#       P2             ---     ---     ---     ---
# T2    P0          0.0046  0.0046  0.0142  0.8896
#       P1          0.0023  0.0018  0.0007  0.0277
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 21949
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9867 0.0133
# pop2       0.0678 0.9322
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.5595 0.4405     ---
# pop2       0.9666 0.0334     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9534 0.0466
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 21949
# Elapsed Time (hours:minutes:seconds): 0:00:40
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 212
# pr = 0.325122047878
# pt = 0.707536219844
# diff = 0.000247659022012
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2985
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9997  0.0003     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2985
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 213
# pr = 0.996019617177
# pt = 0.950470211279
# diff = -0.929983470309
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4486  0.0286  0.0085  0.4688
#       P1          0.4915  0.0313  0.0093  0.5135
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4010
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     ---
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.4772 0.5228     ---
# pop2       0.4772 0.5228     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4010
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 214
# pr = 0.798212852844
# pt = 0.0487475796056
# diff = 6.6064419757e-07
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 215
# pr = 0.543153568225
# pt = 0.0826288333862
# diff = 5.38167484199e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 216
# pr = 0.0296049844817
# pt = 0.984407457034
# diff = 5.47859905446e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9351  0.0405  0.0023  0.0569
#       P1          0.0008     0.0     0.0     0.0
#       P2          0.0002     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9247
#       P1             0.0     0.0     0.0  0.0007
#       P2             0.0     0.0     0.0  0.0002
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1     P2
# population
# pop1       0.9990 0.0008 0.0002
# pop2       0.9990 0.0008 0.0002
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 217
# pr = 0.438306439451
# pt = 0.0712785857473
# diff = 1.00484711378e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 218
# pr = 0.45524984138
# pt = 0.951158930239
# diff = 0.237519356951
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3798  0.0192  0.0035  0.1644
#       P1          0.5671  0.0237  0.0017  0.0556
#       P2             ---     ---     ---     ---
# T2    P0          0.0025  0.0030  0.0099  0.6179
#       P1          0.0024  0.0023  0.0026  0.1445
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 9194
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9899 0.0101
# pop2       0.2251 0.7749
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.4045 0.5955     ---
# pop2       0.7957 0.2043     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9517 0.0483
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 9194
# Elapsed Time (hours:minutes:seconds): 0:00:16
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 219
# pr = 0.741415955068
# pt = 0.917736571654
# diff = 0.607800425071
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.2527  0.0139  0.0027  0.1144
#       P1          0.6984  0.0264  0.0011  0.0164
#       P2             ---     ---     ---     ---
# T2    P0          0.0013  0.0031  0.0127  0.8081
#       P1          0.0015  0.0026  0.0011  0.0435
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6343
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9915 0.0085
# pop2       0.1346 0.8654
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2710 0.7290     ---
# pop2       0.9379 0.0621     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9540 0.0460
# pop2       0.0176 0.9824
# Name: cytotype
#
# Simulation run completed.
# Generation: 6343
# Elapsed Time (hours:minutes:seconds): 0:00:11
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 220
# pr = 0.0867893410953
# pt = 0.94342985653
# diff = 0.000280455092771
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9353  0.0405  0.0023  0.0569
#       P1          0.0008     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9251
#       P1             0.0     0.0     0.0  0.0005
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.9991 0.0008     0.0
# pop2       0.9994 0.0006     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 221
# pr = 0.990093672708
# pt = 0.92857080085
# diff = -0.929983643683
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3808  0.0242  0.0072  0.3978
#       P1          0.5594  0.0356  0.0106  0.5844
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4769
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     ---
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.4050 0.5950     ---
# pop2       0.4050 0.5950     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4769
# Elapsed Time (hours:minutes:seconds): 0:00:08
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 222
# pr = 0.00353370252326
# pt = 0.729246932171
# diff = 4.70887875146e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9353  0.0405  0.0023  0.0569
#       P1          0.0007     0.0     0.0     0.0
#       P2          0.0002     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9249
#       P1             0.0     0.0     0.0  0.0006
#       P2             0.0     0.0     0.0  0.0002
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1     P2
# population
# pop1       0.9991 0.0007 0.0002
# pop2       0.9992 0.0007 0.0002
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 223
# pr = 0.338772991919
# pt = 0.491939031773
# diff = 9.70756563499e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2301
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2301
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 224
# pr = 0.669097845217
# pt = 0.714487974037
# diff = 0.545852607687
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4208  0.0200  0.0018  0.0564
#       P1          0.5288  0.0196  0.0005  0.0036
#       P2             ---     ---     ---     ---
# T2    P0          0.0028  0.0042  0.0144  0.9096
#       P1          0.0017  0.0021  0.0005  0.0132
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 27530
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9892 0.0108
# pop2       0.0623 0.9377
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.4477 0.5523     ---
# pop2       0.9823 0.0177     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9541 0.0459
# pop2       0.0172 0.9828
# Name: cytotype
#
# Simulation run completed.
# Generation: 27530
# Elapsed Time (hours:minutes:seconds): 0:00:49
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 225
# pr = 0.602353389465
# pt = 0.735323495195
# diff = 0.48431646984
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.4744  0.0221  0.0019  0.0576
#       P1          0.4739  0.0177  0.0004  0.0036
#       P2             ---     ---     ---     ---
# T2    P0          0.0035  0.0044  0.0144  0.9061
#       P1          0.0019  0.0020  0.0005  0.0154
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 29076
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9882 0.0118
# pop2       0.0636 0.9364
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.5045 0.4955     ---
# pop2       0.9801 0.0199     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9538 0.0462
# pop2       0.0173 0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 29076
# Elapsed Time (hours:minutes:seconds): 0:00:53
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 226
# pr = 0.15699342736
# pt = 0.322474301479
# diff = 8.17201641687e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2217
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2217
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 227
# pr = 0.511390833357
# pt = 0.49146692074
# diff = 9.30793695542e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2244
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2244
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.002
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 228
# pr = 0.85508419451
# pt = 0.543968465181
# diff = 0.00012537857104
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2432
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2432
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 229
# pr = 0.903149675286
# pt = 0.235826995686
# diff = 3.78826004188e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0018
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 230
# pr = 0.731695934293
# pt = 0.222254966925
# diff = 6.95413244789e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 231
# pr = 0.899821236126
# pt = 0.890801152855
# diff = 0.74545471509
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1923  0.0113  0.0022  0.0841
#       P1          0.7608  0.0277  0.0011  0.0089
#       P2             ---     ---     ---     ---
# T2    P0          0.0010  0.0030  0.0135  0.8720
#       P1          0.0011  0.0028  0.0006  0.0176
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 5555
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9921 0.0079
# pop2       0.0962 0.9038
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2076 0.7924     ---
# pop2       0.9718 0.0282     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9552 0.0448
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 5555
# Elapsed Time (hours:minutes:seconds): 0:00:10
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 232
# pr = 0.573364780603
# pt = 0.482476856731
# diff = 8.84135212678e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2199
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2199
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 233
# pr = 0.989448660271
# pt = 0.0569156271198
# diff = 1.88939045742e-07
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     ---     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     ---     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 234
# pr = 0.0107556394786
# pt = 0.176842264399
# diff = 9.63888722314e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9255
#       P1             0.0     0.0     0.0  0.0001
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2830
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.9998 0.0002     0.0
# pop2       0.9999 0.0001     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2830
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 235
# pr = 0.404974551807
# pt = 0.672872706851
# diff = 0.000240987183216
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2956
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2956
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 236
# pr = 0.0222601285686
# pt = 0.960517191363
# diff = 6.47077415437e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9352  0.0405  0.0023  0.0569
#       P1          0.0007     0.0     0.0     0.0
#       P2          0.0002     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9248
#       P1             0.0     0.0     0.0  0.0007
#       P2             0.0     0.0     0.0  0.0002
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1     P2
# population
# pop1       0.9990 0.0008 0.0002
# pop2       0.9991 0.0007 0.0002
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 237
# pr = 0.50336082762
# pt = 0.15370303504
# diff = 1.19084709918e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 238
# pr = 0.965475778968
# pt = 0.800203597661
# diff = 0.800183405045
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1881  0.0110  0.0015  0.0547
#       P1          0.7657  0.0273  0.0008  0.0045
#       P2             ---     ---     ---     ---
# T2    P0          0.0009  0.0031  0.0141  0.9160
#       P1          0.0010  0.0029  0.0004  0.0079
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6421
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9921 0.0079
# pop2       0.0616 0.9384
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2031 0.7969     ---
# pop2       0.9863 0.0137     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9557 0.0443
# pop2       0.0168 0.9832
# Name: cytotype
#
# Simulation run completed.
# Generation: 6421
# Elapsed Time (hours:minutes:seconds): 0:00:12
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 239
# pr = 0.887380220149
# pt = 0.861483958088
# diff = 0.759754863858
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.1999  0.0116  0.0019  0.0696
#       P1          0.7532  0.0272  0.0009  0.0067
#       P2             ---     ---     ---     ---
# T2    P0          0.0010  0.0031  0.0138  0.8916
#       P1          0.0012  0.0028  0.0006  0.0149
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 6037
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9919 0.0081
# pop2       0.0791 0.9209
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.2155 0.7845     ---
# pop2       0.9769 0.0231     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9553 0.0447
# pop2       0.0173 0.9827
# Name: cytotype
#
# Simulation run completed.
# Generation: 6037
# Elapsed Time (hours:minutes:seconds): 0:00:11
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 240
# pr = 0.962582187329
# pt = 0.992970172163
# diff = -0.929983575498
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.6871  0.0437  0.0130  0.7179
#       P1          0.2531  0.0161  0.0048  0.2644
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 3334
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     ---
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.7308 0.2692     ---
# pop2       0.7308 0.2692     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 3334
# Elapsed Time (hours:minutes:seconds): 0:00:06
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 241
# pr = 0.24752793489
# pt = 0.723948508331
# diff = 0.000210227640593
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             0.0     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2918
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2918
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.002
#
# ...
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 286
# pr = 0.622404171638
# pt = 0.556284909566
# diff = 0.000129846267853
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2482
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2482
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 287
# pr = 0.694486543765
# pt = 0.532839476068
# diff = 0.000113006172681
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2368
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2368
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 288
# pr = 0.379533141703
# pt = 0.587100851307
# diff = 0.000137010655249
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2559
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2559
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 289
# pr = 0.992514321983
# pt = 0.38076099834
# diff = 2.17739860373e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 290
# pr = 0.131791717025
# pt = 0.768499770092
# diff = 0.000171301354659
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0002     0.0     0.0     0.0
#       P2             0.0     0.0     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2877
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9998  0.0002     0.0
# pop2       0.9999     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2877
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 291
# pr = 0.251017167877
# pt = 0.011196727695
# diff = 2.89361442798e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 292
# pr = 0.921461889237
# pt = 0.143720957682
# diff = 9.93775502334e-07
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 293
# pr = 0.88809207168
# pt = 0.534168412459
# diff = 0.000116056636337
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1          0.0001     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2370
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999  0.0001     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2370
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 294
# pr = 0.631362178482
# pt = 0.902930476387
# diff = 0.585303724975
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.3035  0.0156  0.0023  0.0866
#       P1          0.6467  0.0244  0.0009  0.0119
#       P2             ---     ---     ---     ---
# T2    P0          0.0019  0.0034  0.0132  0.8350
#       P1          0.0019  0.0026  0.0012  0.0489
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 8203
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9902 0.0098
# pop2       0.1016 0.8984
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.3244 0.6756     ---
# pop2       0.9371 0.0629     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9539 0.0461
# pop2       0.0175 0.9825
# Name: cytotype
#
# Simulation run completed.
# Generation: 8203
# Elapsed Time (hours:minutes:seconds): 0:00:15
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 295
# pr = 0.943375980958
# pt = 0.22953604327
# diff = 2.90512713175e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9361  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       1.0000     0.0     ---
# pop2       1.0000     0.0     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 296
# pr = 0.0891762570878
# pt = 0.804526489594
# diff = 0.000164769196127
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9359  0.0405  0.0023  0.0569
#       P1          0.0003     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9255
#       P1             0.0     0.0     0.0     0.0
#       P2             0.0     0.0     0.0     0.0
# Name: metapopulation
# Generation: 2920
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.9997 0.0003     0.0
# pop2       0.9999 0.0001     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2920
# Elapsed Time (hours:minutes:seconds): 0:00:05
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 297
# pr = 0.69455851033
# pt = 0.983587725336
# diff = -0.929983512193
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.5829  0.0371  0.0110  0.6090
#       P1          0.3572  0.0227  0.0067  0.3732
#       P2             ---     ---     ---     ---
# T2    P0             ---     ---     ---     ---
#       P1             ---     ---     ---     ---
#       P2             ---     ---     ---     ---
# Name: metapopulation
# Generation: 4256
# EQ: True
#
# trait          T1      T2
# population
# pop1       1.0000     ---
# pop2       1.0000     ---
# Name: trait
#
# preference     P0     P1      P2
# population
# pop1       0.6200 0.3800     ---
# pop2       0.6200 0.3800     ---
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9401 0.0599
# pop2       0.0177 0.9823
# Name: cytotype
#
# Simulation run completed.
# Generation: 4256
# Elapsed Time (hours:minutes:seconds): 0:00:07
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 298
# pr = 0.000123772701192
# pt = 0.421387761419
# diff = 4.93849989058e-06
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9352  0.0405  0.0023  0.0569
#       P1          0.0007     0.0     0.0     0.0
#       P2          0.0002     0.0     0.0     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9247
#       P1             0.0     0.0     0.0  0.0007
#       P2             0.0     0.0     0.0  0.0002
# Name: metapopulation
# Generation: 2001
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0     P1     P2
# population
# pop1       0.9990 0.0008 0.0002
# pop2       0.9990 0.0007 0.0002
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2001
# Elapsed Time (hours:minutes:seconds): 0:00:03
# Time per generation (seconds): 0.0019
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# i = 299
# pr = 0.321217716534
# pt = 0.385346092134
# diff = 7.58813636585e-05
#
# population          pop1            pop2
# cytotype               U       W       U       W
# trait preference
# T1    P0          0.9360  0.0405  0.0023  0.0569
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     ---     0.0
# T2    P0          0.0163  0.0070  0.0151  0.9256
#       P1             0.0     0.0     0.0     0.0
#       P2             ---     ---     0.0     0.0
# Name: metapopulation
# Generation: 2123
# EQ: True
#
# trait          T1     T2
# population
# pop1       0.9766 0.0234
# pop2       0.0592 0.9408
# Name: trait
#
# preference     P0      P1      P2
# population
# pop1       0.9999     0.0     0.0
# pop2       1.0000     0.0     0.0
# Name: preference
#
# cytotype        U      W
# population
# pop1       0.9524 0.0476
# pop2       0.0174 0.9826
# Name: cytotype
#
# Simulation run completed.
# Generation: 2123
# Elapsed Time (hours:minutes:seconds): 0:00:04
# Time per generation (seconds): 0.0019

# %% [markdown]
# Collecting and printing outcomes for all parameter combinations:

# %%
c = scenario['counter'][()]
diffs = np.array( [[x,y,z] for (x,y,z) in scenario['screening'][:c]] )    # convert lenght n array of 3-tuples to array of shape (n,3)
print '   pr      pt      diff   '
print '--------------------------'
print diffs
# Out:
#    pr      pt      diff
# --------------------------
# [[ 0.84268355  0.99148446 -0.92998362]
#  [ 0.84729743  0.80290622  0.74022162]
#  [ 0.82166594  0.86995178  0.72323036]
#  [ 0.86730742  0.82801723  0.75392598]
#  [ 0.89893049  0.95005119 -0.92998362]
#  [ 0.99923283  0.90939265  0.75209236]
#  [ 0.88753152  0.93215352 -0.92998356]
#  [ 0.96229064  0.98174345 -0.92998362]
#  [ 0.67618972  0.03602086  0.00000139]
#  [ 0.90065819  0.45470336  0.0000701 ]
#  [ 0.76220512  0.88994831  0.67776144]
#  [ 0.80004543  0.2774792   0.00000979]
#  [ 0.5679031   0.05354117  0.00000358]
#  [ 0.76936007  0.96022648 -0.92998356]
#  [ 0.15462476  0.05373753  0.00006326]
#  [ 0.14578252  0.74576056  0.00016703]
#  [ 0.47824106  0.62343729  0.00018722]
#  [ 0.27885598  0.75304496  0.00028941]
#  [ 0.93897861  0.0040224   0.00000013]
#  [ 0.77676362  0.50697136  0.00009609]
#  [ 0.78258789  0.88788605  0.69069129]
#  [ 0.50629044  0.33694431  0.00004642]
#  [ 0.23054773  0.2382049   0.0000662 ]
#  [ 0.52826023  0.08562358  0.00000608]
#  [ 0.5857417   0.50798553  0.00009887]
#  [ 0.22152883  0.95332325  0.18729784]
#  [ 0.2412055   0.12333044  0.00004667]
#  [ 0.30289662  0.8314274   0.00080195]
#  [ 0.00005909  0.53888822  0.00000267]
#  [ 0.40427017  0.87822211  0.36410096]
#  [ 0.67418414  0.38946763  0.00004842]
#  [ 0.49023646  0.99511659 -0.92998368]
#  [ 0.57408112  0.94905216 -0.92998368]
#  [ 0.10090575  0.02164947  0.00007118]
#  [ 0.35250539  0.57735896  0.00012927]
#  [ 0.76449519  0.33699638  0.00002202]
#  [ 0.36542237  0.05427551  0.00001508]
#  [ 0.97913587  0.07614199  0.00000027]
#  [ 0.43070838  0.42263195  0.0000768 ]
#  [ 0.51396841  0.03520295  0.00000456]
#  [ 0.08306345  0.81774533  0.00016778]
#  [ 0.62839103  0.94538075 -0.9299835 ]
#  [ 0.35851243  0.524369    0.00010689]
#  [ 0.01472963  0.64056718  0.00010331]
#  [ 0.66169059  0.99280757 -0.9299835 ]
#  [ 0.41079822  0.03811946  0.00000991]
#  [ 0.8936137   0.89893401  0.73025453]
#  [ 0.99441671  0.24998342  0.00000312]
#  [ 0.03226743  0.95680273  0.00009753]
#  [ 0.6643551   0.70364451  0.52559447]
#  [ 0.32408288  0.11337879  0.00002685]
#  [ 0.32576612  0.67030686  0.00019425]
0                    # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height =fig_width *0.75             # height in inches
fig_size = [fig_width,fig_height]
params = {'backend': 'ps',
          'text.usetex': True,
          'text.family': 'sans-serif',
          'text.latex.preamble': [r"\usepackage{mathtools}"],
          'axes.labelsize': 10,
          'text.fontsize': 12,
          'legend.fontsize': 10,
          'xtick.labelsize': 10,
          'ytick.labelsize': 10,
          'figure.figsize': fig_size}
plt.rcParams.update(params)
ticks_font = font_manager.FontProperties(
    family='Helvetica',
    style='normal',
    size=10,
    weight='normal',
    stretch='normal')

# actual data:
X = diffs[:,0]
Y = diffs[:,1]
Z = diffs[:,2]

from scipy.interpolate import griddata
xmin, xmax = 0., 1.
ymin, ymax = 0., 1.
# generate griddata for contour plot:
numspaces = int(math.sqrt(n))
xi = linspace(xmin, xmax, 100)
yi = linspace(ymin, ymax, 100)
#zi = griddata(X, Y, Z, xi, yi, interp='nn')
zi = griddata((X, Y), Z, (xi[None,:], yi[:,None]), method='nearest')

figure(1, figsize=fig_size)
cmap = plt.cm.PRGn
cmap.set_bad('w',0.)
# uncomment the following two lines in order to add contoor lines:
#levels = [0., 0.05]
#plt.contour(xi, yi, zi, levels, linewidths=0.5, colors='k')
#plt.contourf(xi, yi, zi, cmap=cmap, vmin=-1., vmax=1.)
#plt.pcolormesh(xi, yi, zi, cmap=cmap, vmin=-1., vmax=1.)
plt.imshow(zi, extent=(xmin,xmax,ymin,ymax), cmap=cmap, origin='lower', vmin=-1., vmax=1., aspect='auto', interpolation=None)
plt.clim(-1., 1.)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
ax = gca()
ax.grid(False)
ax.set_aspect(1.)
ax.xaxis.labelpad = 17
ax.yaxis.labelpad = 17
ax.set_xticklabels(ax.get_xticks(), ticks_font)
ax.set_yticklabels(ax.get_yticks(), ticks_font)

# add a colorbar:
cbar = plt.colorbar(ticks=[-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1.])
cax = cbar.ax
cax.set_yticklabels(['--1.0', '--0.75', '--0.5', '--0.25', '0.0', '0.25', '0.5', '0.75', '1.0'])
cax.set_ylabel(r'$\xleftarrow{\mathmakebox[8em]{\textstyle\text{decreasing}}}$ {\large Divergence} $\xrightarrow{\mathmakebox[8em]{\textstyle\text{increasing}}}$')
plt.setp(cax.yaxis.get_ticklines(minor=False), markersize=0)

plt.scatter(X, Y, marker='x', c='0.2', s=1)

plt.xlabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{weak}}}$ {\large Mating preference} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{strong}}}$',
    multialignment='left')
plt.ylabel(r'$\xleftarrow{\mathmakebox[6em]{\textstyle\text{high}}}$ {\large Preference costs} $\xrightarrow{\mathmakebox[6em]{\textstyle\text{low}}}$',
    multialignment='center')
plt.text(0.5, 0.4, r'No spread of\\mating preferences', color='0.4', size=12, ha='center', multialignment='center')
plt.text(0.93, 0.81, r'\textbf{Reinforcement}', color='w', size=14, ha='right')
plt.text(0.97, 0.985, r'\textbf{Runaway}', color='w', size=14, ha='right', va='top')
plt.text(0., -0.05, r'Rejection probability', ha='left', va='top')
plt.text(-0.1, 0., r'Transition probability', ha='left', va='bottom', rotation='vertical')
#plt.savefig('/home/flor/Documents/Manuscripts/Runaways and reinforcement/Screening_costs_vs_preferencestrength.pdf')
plt.savefig('images/Screening_costs_vs_preferencestrength.pdf')

# %%
len(diffs)
# Out:
# 300

# %%
rstore.close()

# %%
plt.scatter(X, Y, marker='x', c='0.2', s=1)
plt.xlim(0,1)
plt.ylim(0,1)
ax = gca()
ax.grid(False)
ax.set_aspect(1.)
ax.set_xticklabels(ax.get_xticks(), ticks_font)
ax.set_yticklabels(ax.get_yticks(), ticks_font)
plt.xlabel(r'Rejection probability')
plt.ylabel(r'Transition probability')
